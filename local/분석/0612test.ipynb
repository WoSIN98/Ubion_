# %%
import pandas as pd

# %%
test = pd.read_csv('../data/경기도/원본/지역화폐로 할게요/2023 지역화폐 전국 현황표 (2023년 10월 기준) - Basic of MAP.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   순번                                      226 non-null    int64
#  1   행정구역 표준코드                               226 non-null    int64
#  2   구분                                      226 non-null    object
#  3   광역 이름                                   226 non-null    object
#  4   기초 이름                                   226 non-null    object
#  5   경도                                      226 non-null    float64
#  6   위도                                      226 non-null    float64
#  7   발행명                                     226 non-null    object
#  8   활성지수                                    226 non-null    object
#  9   전년 대비 2023년 발행액 증감                      226 non-null    object
# ...

# %%
test.columns
# Out:
# Index(['순번', '행정구역 표준코드', '구분', '광역 이름', '기초 이름', '경도', '위도', '발행명', '활성지수',
#        '전년 대비 2023년 발행액 증감', '활성 순위', '비활성 순위 (역순)', '이용자 제공혜택 개요',
#        '올해 대비 2024년 사업 예산 계획', '최초 발행 시작일', '최종 발행 중지/종료일', '발행 유형',
#        '이용자 제공혜택 기간', '이용자 제공혜택 대상', '운영사',
#        '2023년 연중 1인당 월 최대 구매/충전액 (만 원, 10월 기준)',
#        '2023년 연중 최대 할인/적립률 (%, 10월 기준)', '2023년 발행액 (억 원, 1년간)',
#        '2023년 누적 이용자 수 (명, 10월 기준)', '2023년 가맹점 수 (곳, 10월 기준)', '더 알아보기 URL',
#        '비고'],
#       dtype='object')

# %%
test = test.loc[test['광역 이름'] == '경기도']

# %%
test.drop(['순번','행정구역 표준코드','구분', '광역 이름', '경도', '위도','최종 발행 중지/종료일', '더 알아보기 URL','비고' ], axis=1, inplace=True)
test
# Out:
#     기초 이름              발행명  활성지수 전년 대비 2023년 발행액 증감 활성 순위 비활성 순위 (역순)  \
# 74    수원시             수원페이  0.80                 축소   113          72
# 75    성남시          성남사랑상품권  0.73                 축소   132          53
# 76   의정부시          의정부사랑카드  0.55                 축소   164          21
# 77    안양시  안양사랑상품권, 안양사랑페이  1.03                 확대    52         133
# 78    부천시             부천페이  0.69                 축소   140          45
# 79    광명시           광명사랑화폐  1.08                 확대    41         144
# 80    평택시          평택사랑상품권  1.11                 확대    34         151
# 81   동두천시          동두천사랑카드  0.78                 축소   120          66
# 82    안산시          안산화폐 다온  0.55                 축소   163          22
# 83    고양시             고양페이  0.68                 축소   146          39
# 84    과천시             과천토리  0.81                 축소   110          75
# 85    구리시          구리사랑상품권  0.99                 축소    65         120
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 74 to 104
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   기초 이름                                   31 non-null     object
#  1   발행명                                     31 non-null     object
#  2   활성지수                                    31 non-null     object
#  3   전년 대비 2023년 발행액 증감                      31 non-null     object
#  4   활성 순위                                   31 non-null     object
#  5   비활성 순위 (역순)                             31 non-null     object
#  6   이용자 제공혜택 개요                             31 non-null     object
#  7   올해 대비 2024년 사업 예산 계획                    31 non-null     object
#  8   최초 발행 시작일                               31 non-null     object
#  9   발행 유형                                   31 non-null     object
# ...

# %%
test.to_excel('../data/경기도/원본/지역화폐로 할게요/경기도.xlsx',index=False)
