# %% [markdown]
# ### 데이터 원본
# - 지역화폐발행및이용현황(19~23)
# - 지역화폐연령별성별이용현황(21-23)
# - 지역화폐가맹점현황
# - 지역화폐 가맹점_20240331
# - 지역별지역화폐사용량및지역별소상공인분포
# - 지역별지역화폐결제금액및결제변화율
# - 주민등록인구집계현황

# %%
import pandas as pd

# %%
## 연령별 성별 지역화폐 이용현황

a = pd.read_csv('../data/경기도/원본/지역화폐연령별성별이용현황.csv',encoding='cp949')
a
# Out:
#       기준연도  시군명 연령대 성별     결제건수         결제금액   결제취소건수       결제취소금액  1회평균결제금액
# 0     2023  가평군  10  남     8409    188845090     46.0    4871840.0   22457.0
# 1     2023  가평군  10  여     6584    176605435     68.0    1841390.0   26823.0
# 2     2023  가평군  20  남    70363   1545018255    728.0   37559999.0   21958.0
# 3     2023  가평군  20  여    55118   1332506645    681.0   27996349.0   24176.0
# 4     2023  가평군  30  남   110968   2682234965   1382.0   84476317.0   24171.0
# ...    ...  ...  .. ..      ...          ...      ...          ...       ...
# 1532  2021  화성시  70  남    93924   2016728621    878.0   36744696.0   21472.0
# 1533  2021  화성시  70  여    94936   2113136980    948.0   31082093.0   22259.0
# 1534  2021  화성시  80  남    14820    296063119    128.0    3424209.0   19977.0
# 1535  2021  화성시  80  여    19625    441991314    191.0    6208072.0   22522.0
# 1536  2021  화성시  기타  -  1245634  29800946270  11553.0  415381458.0   23924.0
#
# [1537 rows x 9 columns]

# %%
## 가맹점 현황

b = pd.read_csv('../data/경기도/원본/지역화폐가맹점현황.csv',encoding='cp949')
b
# Out:
# C:\Users\yoo05\AppData\Local\Temp\ipykernel_144\2744830629.py:3: DtypeWarning: Columns (10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   b = pd.read_csv('../data/경기도/원본/지역화폐가맹점현황.csv',encoding='cp949')
#         시군명              상호명          업종명                     정제도로명주소  \
# 0       가평군          (북면)짜짜루        일반음식점         경기도 가평군 북면 화악산로 203
# 1       가평군   (사)가평음악문화발전협의회       영화.공연장         경기도 가평군 가평읍 석봉로 100
# 2       가평군  (재)가평군장애인복지관(가평   오양.보육.복지시설  경기도 가평군 가평읍 석봉로191번길 65-19
# 3       가평군       (재)에덴스포츠타운  기타취미.레저.스포츠          경기도 가평군 청평면 초옥길 13
# 4       가평군        (주)  진루아쏘        일반음식점         경기도 가평군 청평면 경춘로 763
# ...     ...              ...          ...                         ...
# 418745  화성시             힘쎈수학   기타교육.교습.학원     경기도 화성시 남양읍 시청로102번길 51
# 418746  화성시           힘찬수학과학    입시학원,보습학원          경기도 화성시 동탄순환대로 704
# 418747  화성시           힘찬수학학원    입시학원,보습학원          경기도 화성시 동탄순환대로 696
# ...

# %%
## 24년 기준 가맹점 현황

c = pd.read_csv('../data/경기도/원본/지역화폐 가맹점_20240331.csv',encoding='cp949')
c
# Out:
# C:\Users\yoo05\AppData\Local\Temp\ipykernel_144\4056954098.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   c = pd.read_csv('../data/경기도/원본/지역화폐 가맹점_20240331.csv',encoding='cp949')
#         시군명          상호명    업종명(종목명)                     소재지도로명주소  \
# 0       고양시      까망노래연습장         노래방         경기도 고양시 일산동구 탄중로 322
# 1       고양시     일산좋은치과의원          치과         경기도 고양시 일산동구 일산로 441
# 2       고양시          잉크존     문구,사무용품        경기도 고양시 일산서구 중앙로 1388
# 3       고양시         참좋은집  오양.보육.복지시설  경기도 고양시 일산동구 고봉로770번길 211-1
# 4       고양시      (주)팩토리빈       커피전문점     경기도 고양시 일산동구 멱절길 368-104
# ...     ...          ...         ...                          ...
# 418745  화성시      킹(KING)     차량부품.용품                경기도 화성시 융건로 9
# 418746  화성시  아리가또맘마 중동탄점       일식전문점         경기도 화성시 동탄대로14길 5-25
# 418747  화성시       아이티씨영어  기타교육.교습.학원              경기도 화성시 서동탄로 53
# 418748  화성시        다함 목재      기타건축자재        경기도 화성시 비봉면 현대기아로 840
# ...

# %%
d = pd.read_csv('../data/경기도/원본/지역별지역화폐사용량및지역별소상공인분포.csv')
d
# Out:
# C:\Users\yoo05\AppData\Local\Temp\ipykernel_144\2457156374.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   d = pd.read_csv('../data/경기도/원본/지역별지역화폐사용량및지역별소상공인분포.csv')
#          분석인덱스  가맹점우편번호 성별코드 연령대코드  결제수                업종대분류명  상가수
# 0            0    10125    M    40    1                  C제조업   15
# 1            1    10125    M    40    1  E하수·폐기물처리;원료재생및환경복원업    1
# 2            2    10125    M    40    1                  F건설업    5
# 3            3    10125    M    40    1               G도매및소매업   52
# 4            4    10125    M    40    1                  H운수업    9
# ...        ...      ...  ...   ...  ...                   ...  ...
# 531771  531771    18635    M    60    2               G도매및소매업   12
# 531772  531772    18635    M    60    2                  H운수업    1
# 531773  531773    18635    M    60    2              I숙박및음식점업    4
# 531774  531774    18635    M    60    2         Q보건업및사회복지서비스업    1
# ...

# %%
e = pd.read_csv('../data/경기도/원본/지역별지역화폐결제금액및결제변화율.csv')
e
# Out:
#       분석인덱스    시도명 시군구명 행정동명   일반결제년월      결제금액    전월결제금액  결제변화비율
# 0         0    경기도  가평군  가평읍  2019-09  19073066  19073066    0.00
# 1         1    경기도  가평군  가평읍  2019-10  68118300  19073066  257.14
# 2         2    경기도  가평군  가평읍  2019-11  54758044  68118300  -19.61
# 3         3    경기도  가평군  가평읍  2019-12  77461979  54758044   41.46
# 4         4    경기도  가평군  가평읍  2020-01  88133670  77461979   13.78
# ...     ...    ...  ...  ...      ...       ...       ...     ...
# 3085   3085  서울특별시   중구  소공동  2019-11  21605760  14472650   49.29
# 3086   3086  서울특별시   중구  소공동  2019-12  55619190  21605760  157.43
# 3087   3087  서울특별시   중구  소공동  2020-01  56547370  55619190    1.67
# 3088   3088  서울특별시   중구  소공동  2020-02  30188690  56547370  -46.61
# 3089   3089  서울특별시   중구  소공동  2020-03   1486980  30188690  -95.07
#
# [3090 rows x 8 columns]

# %%
e['일반결제년월'].unique()
# Out:
# array(['2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02',
#        '2020-03', '2020-05', '2020-06'], dtype=object)

# %%
d = pd.read_csv('../data/경기도/원본/주민등록인구집계현황.csv',encoding="cp949")
d
# Out:
#           연도  월 행정구역구분명        행정구역명     총 인구수    0~9세   10~19세   20~29세  \
# 0       2024  4       도        경기도    13648156  970596  1317378  1661407
# 1       2024  4      시군     경기도 가평군      62281    2686     4276     5620
# 2       2024  4     읍면동  경기도 가평군 가평읍     21038    1096     1754     2155
# 3       2024  4     읍면동   경기도 가평군 북면      3604      84      165      190
# 4       2024  4     읍면동   경기도 가평군 상면      5420     114      197      377
# ...      ... ..     ...          ...       ...     ...      ...      ...
# 119477  2008  1     읍면동  경기도 화성시 팔탄면      9900     869      869     1694
# 119478  2008  1     읍면동  경기도 화성시 향남읍     21100    2828     2288     3151
# 119479  2008  1     읍면동  경기도 화성시 향남읍     21100    2828     2288     3151
# 119480  2008  1     읍면동  경기도 화성시 화산동     23684    3727     2793     3515
# 119481  2008  1     읍면동  경기도 화성시 화산동     23684    3727     2793     3515
#
#          30~39세   40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  \
# ...
