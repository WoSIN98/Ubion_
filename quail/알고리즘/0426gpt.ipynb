# %%
import pandas as pd

# %%
total_df = pd.read_csv('../data1/total_df.csv')
review_df = pd.read_csv('../data2/review_df.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   merchant     225 non-null    object
#  1   category     225 non-null    object
#  2   star         225 non-null    float64
#  3   address      225 non-null    object
#  4   oper_time    225 non-null    object
#  5   starCount    225 non-null    int64
#  6   reviewCount  225 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 12.4+ KB

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22383 entries, 0 to 22382
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   merchant      22383 non-null  object
#  1   user_name     22361 non-null  object
#  2   user_rank     22383 non-null  int64
#  3   num_response  22383 non-null  object
#  4   user_star     22383 non-null  float64
#  5   time          22383 non-null  object
#  6   rating        22383 non-null  float64
#  7   content       18674 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
# 결측치 제거 및 전처리
review_df = review_df.dropna(subset=['content'])
review_df['cleaned_content'] = review_df['content'].str.lower().replace('[^a-zA-Z가-힣]', ' ', regex=True)

# %%
# TF-IDF 벡터화
vectorizer = TfidfVectorizer(max_features=1000, min_df=5)
X_tfidf = vectorizer.fit_transform(review_df['cleaned_content'])

# %%
# 군집화
kmeans = KMeans(n_clusters=8, random_state=42)
clusters = kmeans.fit_predict(X_tfidf)

# %%
# 클러스터 결과를 리뷰 데이터프레임에 추가
review_df['cluster'] = clusters

# %%
# 음식점별로 가장 많이 속한 클러스터의 가중치를 계산
cluster_weights = review_df.groupby(['merchant', 'cluster']).size().unstack(fill_value=0)
cluster_weights = normalize(cluster_weights, norm='l1')

# %%
# 가중치 데이터프레임 생성
cluster_weights_df = pd.DataFrame(cluster_weights, index=cluster_weights.index, columns=kmeans.cluster_centers_.argsort()[:, ::-1][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # 가중치 데이터프레임 생성
# ----> 2 cluster_weights_df = pd.DataFrame(cluster_weights, index=cluster_weights.index, columns=kmeans.cluster_centers_.argsort()[:, ::-1][0])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
# 가중치 데이터프레임 생성
cluster_indices = review_df.groupby(['merchant', 'cluster']).size().unstack(fill_value=0).index
cluster_columns = ['cluster_' + str(i) for i in range(kmeans.n_clusters)]
cluster_weights_df = pd.DataFrame(cluster_weights, index=cluster_indices, columns=cluster_columns)

# total_df에 가중치 정보를 병합
total_df = total_df.merge(cluster_weights_df, how='left', on='merchant')

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   merchant     225 non-null    object
#  1   category     225 non-null    object
#  2   star         225 non-null    float64
#  3   address      225 non-null    object
#  4   oper_time    225 non-null    object
#  5   starCount    225 non-null    int64
#  6   reviewCount  225 non-null    int64
#  7   cluster_0    198 non-null    float64
#  8   cluster_1    198 non-null    float64
#  9   cluster_2    198 non-null    float64
#  10  cluster_3    198 non-null    float64
#  11  cluster_4    198 non-null    float64
#  12  cluster_5    198 non-null    float64
#  13  cluster_6    198 non-null    float64
#  14  cluster_7    198 non-null    float64
# dtypes: float64(9), int64(2), object(4)
# memory usage: 26.5+ KB

# %%
total_df['cluster_1'].unique()
# Out:
# array([0.80751174, 0.76708075, 0.80645161, 0.79577465, 0.73469388,
#        0.80357143, 0.6875    , 0.61555076, 0.67283951,        nan,
#        0.83333333, 0.69      , 0.89449541, 0.68342857, 0.81549815,
#        0.74311927, 0.75460123, 0.73873874, 0.7593985 , 0.65753425,
#        0.82278481, 0.78776978, 0.80962343, 0.63157895, 0.82758621,
#        0.85106383, 0.82142857, 0.52893082, 0.80952381, 0.90697674,
#        0.79183673, 0.75510204, 0.79054054, 0.79569892, 0.70955882,
#        0.86764706, 0.74611399, 0.81818182, 0.85294118, 0.85714286,
#        0.86585366, 0.86206897, 0.84042553, 1.        , 0.68181818,
#        0.8030303 , 0.67924528, 0.78787879, 0.72727273, 0.8       ,
#        0.8028169 , 0.7578125 , 0.89230769, 0.85416667, 0.78688525,
#        0.54716981, 0.73333333, 0.86956522, 0.625     , 0.87179487,
#        0.9       , 0.8677686 , 0.66666667, 0.94270833, 0.63114754,
#        0.74380165, 0.75      , 0.82051282, 0.7699115 , 0.7027027 ,
#        0.64951768, 0.75609756, 0.88636364, 0.76666667, 0.69565217,
#        0.89655172, 0.57142857, 0.81132075, 0.80916031, 0.82089552,
#        0.62068966, 0.78378378, 0.70833333, 0.77777778, 0.70967742,
#        0.71428571, 0.46153846, 0.8125    , 0.60674157, 0.81212121,
#        0.86666667, 0.8359375 , 0.6       , 0.66153846, 0.65517241,
#        0.84848485, 0.88888889, 0.78881988, 0.74626866, 0.88571429,
#        0.86792453, 0.728     , 0.83168317, 0.875     , 0.78737542,
#        0.87878788, 0.76023392, 0.75675676, 0.82608696, 0.79166667,
#        0.7816092 , 0.7195122 , 0.65      , 0.90909091, 0.82352941,
#        0.80769231, 0.73684211, 0.76923077, 0.69620253, 0.53846154,
#        0.70810811, 0.8372093 , 0.80555556, 0.79310345, 0.72121212,
#        0.88095238, 0.84210526, 0.7826087 , 0.81506849, 0.81666667,
#        0.92307692, 0.93650794, 0.7375    , 0.3125    , 0.76595745,
#        0.77083333, 0.79487179, 0.81967213, 0.69491525, 0.77952756,
#        0.95652174, 0.81355932, 0.91666667, 0.77272727, 0.76      ,
#        0.60714286, 0.65116279, 0.83673469, 0.78333333, 0.87323944,
#        0.78846154, 0.75438596, 0.68421053])

# %%
cluster_indices
# Out:
# Index(['1984', '21세기 우리바다수산', '38도씨식당', '943킹스크로스', '가로수포차', '가미우동', '가비애',
#        '감성타코 홍대점', '강강술래 홍대점', '개화기요정',
#        ...
#        '홍대씨부엉', '홍대인파스타', '홍대조폭떡볶이 홍대2호점', '홍대차칸곱창', '홍스쭈꾸미 홍대본점',
#        '홍익닭한마리 홍대본점', '황곱 홍대점', '효봉포차', '후라토식당 상수직영점', '훠궈나라 홍대점'],
#       dtype='object', name='merchant', length=198)

# %%
# 각 클러스터 중심점에 대해 가장 높은 TF-IDF 값을 가진 단어 추출
feature_names = vectorizer.get_feature_names_out()
top_n = 10  # 각 클러스터별로 추출할 상위 단어 수

cluster_terms = {}
for i, centroid in enumerate(kmeans.cluster_centers_):
    sorted_indices = centroid.argsort()[::-1][:top_n]
    cluster_terms[f'Cluster {i}'] = [feature_names[idx] for idx in sorted_indices]

# DataFrame 생성
cluster_terms_df = pd.DataFrame(cluster_terms)
cluster_terms_df
# Out:
#   Cluster 0 Cluster 1 Cluster 2 Cluster 3 Cluster 4 Cluster 5 Cluster 6  \
# 0        너무       좋아요      맛있어요        곱창        진짜      같습니다        맛은
# 1      맛있어요        정말        너무      맛있어요      맛있어요        너무        그냥
# 2       맛있고      맛있어요      친절하고        너무        너무        좋은        너무
# 3       좋아요       맛있고        완전        홍대        여기        정말       있는데
# 4        좋고        그냥        좋고        대창       맛있음        조금        근데
# 5       맛있게       맛있음        정말        진짜       맛있고        좋을        조금
# 6      분위기도       사장님      너무너무       나오는        최고        그냥        비해
# 7      맛있어서        맛이       츠케멘      해물탕도     맛있었어요        가게        양이
# 8     친절하시고       분위기       다음에      홍대에서        엄청     맛있었어요        정말
# 9        정말        좋고       좋아요        막창        그냥        맛은        진짜
#
#   Cluster 7
# 0       파스타
# 1        피자
# 2      스테이크
# 3        모두
# 4        맛집
# 5     맛있었어요
# 6        크림
# 7       맛있고
# 8      맛있어요
# 9        너무

# %%
review_df
# Out:
#        merchant   user_name  user_rank num_response  user_star         time  \
# 0          1984  2018.05.10         22           58        2.5  2024.04.21.
# 2          1984      맛난곳만리뷰          7            7        5.0  2024.02.10.
# 3          1984          진아         25           58        4.6  2024.02.05.
# 4          1984         박찬찬         27           71        3.9  2023.12.16.
# 5          1984       프로페셔널         16           37        2.7  2023.12.04.
# ...         ...         ...        ...          ...        ...          ...
# 22378  훠궈나라 홍대점         ㅇㅅㅇ         31          122        4.0  2019.12.28.
# 22379  훠궈나라 홍대점          상준          3            2        5.0  2019.12.14.
# 22380  훠궈나라 홍대점           .          9           15        4.3  2019.11.18.
# 22381  훠궈나라 홍대점         김후연          2            1        1.0  2019.11.03.
# 22382  훠궈나라 홍대점          아임         10           16        4.1  2019.10.01.
#
#        rating                                            content  \
# 0         5.0  까페에서 책 읽기를 좋아하는 사람인데요. 매우 쾌적하고 음악으로, 다른 손님 때문에...
# 2         5.0                         다양한 볼거리들 있어서 좋아요 분위기도 괜찮구여
# 3         4.0                           넓고 음료 ㄱㅊ앉아있기 좋음뭐 살 것도 있음
# 4         1.0  분위기는 좋으나, 장사할 생각 없어보임커피값도 비싼 편인데 돈값 못함카페는 부수적인...
# 5         1.0  작년까지 아메리카노도 수준급으로 맛있었는데 왜이리 변했나요 .. 손님이 오면 인사는...
# ...       ...                                                ...
# 22378     5.0                                     역대급 최고인데여?????
# 22379     5.0                                                굿굿굿
# 22380     5.0                           맛있어요. 몇번왔어요. 생각나는 맛이에요ㅜㅠ
# 22381     1.0                                                맛없음
# 22382     4.0  백탕, 홍탕으로 먹었는데, 홍탕은 매운 레벨 낮춰서 드시길..생각보다 혀가 얼얼해요...
#
#                                          cleaned_content  cluster
# 0      까페에서 책 읽기를 좋아하는 사람인데요  매우 쾌적하고 음악으로  다른 손님 때문에...        1
# 2                             다양한 볼거리들 있어서 좋아요 분위기도 괜찮구여        1
# 3                               넓고 음료   앉아있기 좋음뭐 살 것도 있음        1
# 4      분위기는 좋으나  장사할 생각 없어보임커피값도 비싼 편인데 돈값 못함카페는 부수적인...        1
# 5      작년까지 아메리카노도 수준급으로 맛있었는데 왜이리 변했나요    손님이 오면 인사는...        1
# ...                                                  ...      ...
# 22378                                     역대급 최고인데여             1
# 22379                                                굿굿굿        1
# 22380                           맛있어요  몇번왔어요  생각나는 맛이에요          1
# 22381                                                맛없음        1
# 22382  백탕  홍탕으로 먹었는데  홍탕은 매운 레벨 낮춰서 드시길  생각보다 혀가 얼얼해요...        6
#
# [18674 rows x 10 columns]

# %%
# ------------------------------------------------------

# %%
import pandas as pd

# %%
total_df = pd.read_csv('../data1/total_df.csv')
review_df = pd.read_csv('../data2/review_df.csv')

# %%
# !pip install konlpy

# %%
from konlpy.tag import Okt
import re

## 단어 추출
# Initialize the Okt object
okt = Okt()

# Remove rows where 'content' is NaN
review_df_clean = review_df.dropna(subset=['content'])

# Function to preprocess and extract keywords from text
def preprocess_text(text):
    # Normalize and remove non-alphabetic characters
    text = re.sub("[^가-힣a-zA-Z ]", "", text)
    # Tokenize and filter out stopwords and extract nouns
    tokens = okt.nouns(text)  # Focusing on nouns for keyword extraction
    tokens = [n for n in tokens if len(n) > 1]
    return tokens

# Apply text processing to the reviews
review_df_clean['keywords'] = review_df_clean['content'].apply(preprocess_text)

# Display the processed keywords
review_df_clean[['content', 'keywords']].head()
# Out:
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\2900134844.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean['keywords'] = review_df_clean['content'].apply(preprocess_text)
#                                              content  \
# 0  까페에서 책 읽기를 좋아하는 사람인데요. 매우 쾌적하고 음악으로, 다른 손님 때문에...
# 2                         다양한 볼거리들 있어서 좋아요 분위기도 괜찮구여
# 3                           넓고 음료 ㄱㅊ앉아있기 좋음뭐 살 것도 있음
# 4  분위기는 좋으나, 장사할 생각 없어보임커피값도 비싼 편인데 돈값 못함카페는 부수적인...
# 5  작년까지 아메리카노도 수준급으로 맛있었는데 왜이리 변했나요 .. 손님이 오면 인사는...
#
#                                             keywords
# 0  [까페, 사람, 매우, 음악, 다른, 손님, 때문, 방해, 한번, 커피, 메뉴, 리...
# 2                                         [볼거리, 분위기]
# 3                                               [음료]
# 4              [분위기, 장사, 생각, 보임, 커피, 돈값, 카페, 부수, 수입]
# 5        [작년, 아메리카노, 수준, 손님, 인사, 커녕, 인사, 해도, 대충, 사장]

# %%
review_df_clean
# Out:
#        merchant   user_name  user_rank num_response  user_star         time  \
# 0          1984  2018.05.10         22           58        2.5  2024.04.21.
# 2          1984      맛난곳만리뷰          7            7        5.0  2024.02.10.
# 3          1984          진아         25           58        4.6  2024.02.05.
# 4          1984         박찬찬         27           71        3.9  2023.12.16.
# 5          1984       프로페셔널         16           37        2.7  2023.12.04.
# ...         ...         ...        ...          ...        ...          ...
# 22378  훠궈나라 홍대점         ㅇㅅㅇ         31          122        4.0  2019.12.28.
# 22379  훠궈나라 홍대점          상준          3            2        5.0  2019.12.14.
# 22380  훠궈나라 홍대점           .          9           15        4.3  2019.11.18.
# 22381  훠궈나라 홍대점         김후연          2            1        1.0  2019.11.03.
# 22382  훠궈나라 홍대점          아임         10           16        4.1  2019.10.01.
#
#        rating                                            content  \
# 0         5.0  까페에서 책 읽기를 좋아하는 사람인데요. 매우 쾌적하고 음악으로, 다른 손님 때문에...
# 2         5.0                         다양한 볼거리들 있어서 좋아요 분위기도 괜찮구여
# 3         4.0                           넓고 음료 ㄱㅊ앉아있기 좋음뭐 살 것도 있음
# 4         1.0  분위기는 좋으나, 장사할 생각 없어보임커피값도 비싼 편인데 돈값 못함카페는 부수적인...
# 5         1.0  작년까지 아메리카노도 수준급으로 맛있었는데 왜이리 변했나요 .. 손님이 오면 인사는...
# ...       ...                                                ...
# 22378     5.0                                     역대급 최고인데여?????
# 22379     5.0                                                굿굿굿
# 22380     5.0                           맛있어요. 몇번왔어요. 생각나는 맛이에요ㅜㅠ
# 22381     1.0                                                맛없음
# 22382     4.0  백탕, 홍탕으로 먹었는데, 홍탕은 매운 레벨 낮춰서 드시길..생각보다 혀가 얼얼해요...
#
#                                                 keywords
# 0      [까페, 사람, 매우, 음악, 다른, 손님, 때문, 방해, 한번, 커피, 메뉴, 리...
# 2                                             [볼거리, 분위기]
# 3                                                   [음료]
# 4                  [분위기, 장사, 생각, 보임, 커피, 돈값, 카페, 부수, 수입]
# 5            [작년, 아메리카노, 수준, 손님, 인사, 커녕, 인사, 해도, 대충, 사장]
# ...                                                  ...
# 22378                                           [역대, 최고]
# 22379                                              [굿굿굿]
# 22380                                               [몇번]
# 22381                                                 []
# 22382               [백탕, 홍탕, 홍탕, 레벨, 생각, 고추, 마비, 느낌, 전체]
#
# [18674 rows x 9 columns]

# %%
from collections import Counter
# Flatten the list of words and count frequencies
all_words = [word for sublist in review_df_clean['keywords'] for word in sublist]


word_counts = Counter(all_words)

# Display the most common words
word_counts.most_common(20)
# Out:
# [('진짜', 1822),
#  ('직원', 1740),
#  ('분위기', 1550),
#  ('방문', 1327),
#  ('가격', 1287),
#  ('정말', 1082),
#  ('음식', 1002),
#  ('사장', 972),
#  ('홍대', 958),
#  ('피자', 956),
#  ('맛집', 933),
#  ('사람', 908),
#  ('라멘', 887),
#  ('그냥', 877),
#  ('정도', 875),
#  ('여기', 874),
#  ('서비스', 819),
#  ('최고', 816),
#  ('추천', 807),
#  ('생각', 802)]

# %%
a = '아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓'

# %%
a = a.replace(" ", ",")

# %%
## 불용어 제거
# Define a list of common Korean stopwords
stopwords = [a,'맛있어요', '맛있고', '좋아요', '맛', '맛은', '맛이', '좋고', '안', '엄청', '맛있게', '맛도', '다른', '먹고', 
    '분위기', '맛있음', '맛있었어요', '같아요', '여기', '그리고','여기', '맛', '너무', '진짜', '다', '좀', '정말', '잘', '더', '그냥', '또', '것', '수', '많이', '꼭', '이', '거', '것은', '에서', '에는', 
    '있습니다', '있어', '있는', '입니다', '하는', '하기', '하고', '했어요', '했습니다', '한', '할', '합니다', '해', '해요', 
    '으로', '로는', '와', '과', '도', '고', '에', '에게', '와서', '와의', '으로부터', '이다', '있다', '되다', '같다']

# Filter out stopwords from the word lists
review_df_clean['filtered_words'] = review_df_clean['keywords'].apply(lambda words: [word for word in words if word not in stopwords])

# Recalculate word frequencies without stopwords
filtered_words = [word for sublist in review_df_clean['filtered_words'] for word in sublist]
filtered_word_counts = Counter(filtered_words)

# Display the most common words after removing stopwords
filtered_word_counts.most_common(20)
# Out:
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\3635285602.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean['filtered_words'] = review_df_clean['keywords'].apply(lambda words: [word for word in words if word not in stopwords])
# [('직원', 1740),
#  ('방문', 1327),
#  ('가격', 1287),
#  ('음식', 1002),
#  ('사장', 972),
#  ('홍대', 958),
#  ('피자', 956),
#  ('맛집', 933),
#  ('사람', 908),
#  ('라멘', 887),
#  ('정도', 875),
#  ('서비스', 819),
#  ('최고', 816),
#  ('추천', 807),
#  ('생각', 802),
#  ('곱창', 708),
#  ('메뉴', 705),
#  ('시간', 692),
#  ('웨이', 680),
#  ('느낌', 669)]

# %%
filtered_word_counts
# Out:
# Counter({'직원': 1740,
#          '방문': 1327,
#          '가격': 1287,
#          '음식': 1002,
#          '사장': 972,
#          '홍대': 958,
#          '피자': 956,
#          '맛집': 933,
#          '사람': 908,
#          '라멘': 887,
#          '정도': 875,
#          '서비스': 819,
#          '최고': 816,
#          '추천': 807,
#          '생각': 802,
#          '곱창': 708,
#          '메뉴': 705,
#          '시간': 692,
#          '웨이': 680,
#          '느낌': 669,
#          '별로': 669,
#          '가게': 658,
#          '국물': 653,
#          '처음': 642,
#          '고기': 623,
#          '우동': 607,
#          '카페': 562,
#          '주문': 549,
#          '커피': 544,
#          '하나': 510,
#          '손님': 507,
#          '가성': 501,
#          '존맛': 501,
#          '조금': 496,
#          '테이블': 484,
#          '기분': 483,
#          '다음': 468,
#          '튀김': 442,
#          '치즈': 431,
#          '친구': 427,
#          '추가': 423,
#          '파스타': 415,
#          '리뷰': 406,
#          '다시': 404,
#          '자주': 386,
#          '딸기': 386,
#          '케이크': 383,
#          '음료': 381,
#          '양도': 378,
#          '소스': 375,
#          '완전': 360,
#          '냄새': 358,
#          '보고': 351,
#          '초밥': 339,
#          '무난': 337,
#          '매장': 334,
#          '크림': 331,
#          '한번': 329,
#          '자리': 324,
#          '카레': 320,
#          '웨이팅': 319,
#          '기본': 302,
#          '디저트': 300,
#          '안주': 300,
#          '일본': 299,
#          '제일': 295,
#          '아주': 280,
#          '먹기': 269,
#          '의사': 267,
#          '사진': 263,
#          '때문': 260,
#          '새우': 256,
#          '친절': 254,
#          '계속': 254,
#          '식사': 251,
#          '츠케멘': 250,
#          '매우': 246,
#          '인테리어': 243,
#          '볶음밥': 243,
#          '떡볶이': 242,
#          '모두': 239,
#          '가면': 236,
#          '개인': 235,
#          '치킨': 222,
#          '식당': 220,
#          '바로': 219,
#          '돈까스': 215,
#          '소바': 215,
#          '후기': 214,
#          '다만': 214,
#          '공간': 211,
#          '근처': 207,
#          '항상': 206,
#          '퀄리티': 205,
#          '위생': 205,
#          '이유': 203,
#          '예전': 200,
#          '가지': 196,
#          '세트': 195,
#          '버거': 195,
#          '최악': 194,
#          '라면': 193,
#          '차슈': 193,
#          '약간': 191,
#          '알바': 191,
#          '인생': 191,
#          '재료': 190,
#          '종류': 189,
#          '닭갈비': 188,
#          '역시': 187,
#          '예약': 184,
#          '입맛': 178,
#          '직접': 178,
#          '일단': 177,
#          '이상': 176,
#          '카츠': 176,
#          '마제': 173,
#          '마음': 172,
#          '자체': 172,
#          '육수': 170,
#          '꼬치': 170,
#          '보통': 168,
#          '대기': 167,
#          '김치': 165,
#          '알바생': 164,
#          '맥주': 163,
#          '오픈': 162,
#          '대비': 161,
#          '샐러드': 161,
#          '살짝': 160,
#          '불친절': 159,
#          '전체': 157,
#          '감동': 157,
#          '저녁': 155,
#          '화장실': 154,
#          '편이': 153,
#          '설명': 153,
#          '장사': 149,
#          '무조건': 149,
#          '지금': 149,
#          '제대로': 147,
#          '이제': 145,
#          '굳이': 145,
#          '가장': 143,
#          '주방': 143,
#          '기억': 141,
#          '포장': 141,
#          '한국': 141,
#          '여자': 139,
#          '오늘': 139,
#          '스테이크': 139,
#          '거의': 138,
#          '고양이': 138,
#          '원래': 137,
#          '절대': 135,
#          '계란': 135,
#          '요즘': 135,
#          '커리': 135,
#          '달라': 134,
#          '주말': 134,
#          '평일': 132,
#          '내부': 132,
#          '취향': 132,
#          '강추': 130,
#          '라떼': 129,
#          '감자': 129,
#          '평점': 127,
#          '서울': 126,
#          '해물탕': 125,
#          '번창': 124,
#          '돼지': 124,
#          '주시': 123,
#          '막걸리': 123,
#          '요리': 123,
#          '기름': 122,
#          '만원': 121,
#          '간이': 121,
#          '리필': 120,
#          '상태': 120,
#          '수준': 119,
#          '무엇': 119,
#          '기대': 119,
#          '남자': 118,
#          '도우': 118,
#          '전혀': 117,
#          '서빙': 117,
#          '모든': 117,
#          '바삭': 117,
#          '빙수': 117,
#          '소리': 116,
#          '응대': 115,
#          '뭔가': 115,
#          '대박': 115,
#          '저희': 114,
#          '쫄깃': 114,
#          '반찬': 113,
#          '실망': 113,
#          '최애': 112,
#          '관리': 111,
#          '장소': 110,
#          '지인': 109,
#          '그릇': 109,
#          '단골': 109,
#          '해리포터': 108,
#          '술집': 107,
#          '외국인': 107,
#          '야채': 106,
#          '계산': 106,
#          '얘기': 106,
#          '세상': 105,
#          '양념': 105,
#          '안나': 105,
#          '데이트': 104,
#          '단점': 103,
#          '이해': 102,
#          '선택': 102,
#          '혼자': 100,
#          '토마토': 100,
#          '돈쭐': 100,
#          '가끔': 99,
#          '참고': 99,
#          '그대로': 99,
#          '인분': 99,
#          '매콤': 99,
#          '대창': 99,
#          '토핑': 99,
#          '아이': 98,
#          '마늘': 98,
#          '우리': 98,
#          '황곱': 98,
#          '조합': 97,
#          '기준': 97,
#          '안내': 95,
#          '부분': 95,
#          '버터': 95,
#          '비주': 95,
#          '소금': 95,
#          '식감': 95,
#          '먹음': 94,
#          '타코': 94,
#          '스프': 94,
#          '안심': 94,
#          '천원': 93,
#          '신경': 93,
#          '만족': 93,
#          '미리': 93,
#          '방어': 92,
#          '의자': 91,
#          '위치': 91,
#          '짬뽕': 91,
#          '야끼소바': 91,
#          '마지막': 90,
#          '지점': 90,
#          '인정': 89,
#          '정신': 89,
#          '먼저': 89,
#          '아메리카노': 88,
#          '거리': 88,
#          '주차': 88,
#          '일반': 88,
#          '생크림': 88,
#          '서서': 88,
#          '육회': 88,
#          '주변': 87,
#          '사실': 86,
#          '케익': 86,
#          '칵테일': 86,
#          '스타일': 86,
#          '양은': 86,
#          '가세': 85,
#          '중간': 85,
#          '평범': 85,
#          '음악': 84,
#          '일행': 84,
#          '등심': 84,
#          '인상': 83,
#          '입장': 83,
#          '사랑': 83,
#          '경험': 83,
#          '자극': 83,
#          '포테이토': 83,
#          '돈코츠': 83,
#          '무슨': 82,
#          '연어': 82,
#          '이용': 81,
#          '이벤트': 81,
#          '수도': 80,
#          '사이드': 80,
#          '금방': 80,
#          '진심': 80,
#          '점심': 80,
#          '전부': 80,
#          '코로나': 80,
#          '좌석': 78,
#          '국밥': 78,
#          '기도': 77,
#          '혼밥': 77,
#          '갈비': 77,
#          '가기': 76,
#          '소주': 76,
#          '식물': 76,
#          '이름': 75,
#          '문제': 75,
#          '이번': 75,
#          '제발': 75,
#          '회전': 75,
#          '구이': 75,
#          '노래': 74,
#          '이건': 74,
#          '코스': 74,
#          '보기': 74,
#          '조만간': 74,
#          '전반': 73,
#          '나중': 73,
#          '돼지고기': 73,
#          '영업': 72,
#          '컨셉': 72,
#          '최근': 72,
#          '면발': 72,
#          '다쿠아즈': 72,
#          '조각': 71,
#          '팬케이크': 71,
#          '동네': 70,
#          '덕분': 70,
#          '호불호': 70,
#          '카라': 69,
#          '운영': 68,
#          '달달': 68,
#          '끼리': 68,
#          '필수': 68,
#          '소고기': 68,
#          '가능': 68,
#          '막창': 68,
#          '곰탕': 68,
#          '무료': 67,
#          '인스타': 67,
#          '구성': 67,
#          '전화': 67,
#          '추억': 67,
#          '거기': 67,
#          '태도': 67,
#          '경우': 67,
#          '가요': 66,
#          '접시': 66,
#          '가도': 66,
#          '갈릭': 66,
#          '탕수육': 66,
#          '종종': 65,
#          '배달': 65,
#          '크게': 65,
#          '차라리': 65,
#          '굿굿': 65,
#          '마스크': 65,
#          '로스': 65,
#          '해도': 64,
#          '그닥': 64,
#          '고민': 64,
#          '걱정': 64,
#          '가야': 64,
#          '멀리': 64,
#          '사용': 64,
#          '가라아게': 64,
#          '현지': 64,
#          '단계': 64,
#          '오히려': 63,
#          '크기': 63,
#          '옛날': 63,
#          '입구': 63,
#          '나름': 63,
#          '가득': 63,
#          '비교': 63,
#          '잘못': 62,
#          '인도': 62,
#          '공부': 61,
#          '이서': 61,
#          '확인': 61,
#          '개맛': 61,
#          '후회': 61,
#          '그것': 61,
#          '페퍼로니': 61,
#          '화덕': 61,
#          '밑반찬': 60,
#          '뇨끼': 60,
#          '인기': 60,
#          '어디': 60,
#          '이면': 60,
#          '스콘': 60,
#          '타르트': 60,
#          '태국': 60,
#          '대가': 59,
#          '특유': 59,
#          '두번째': 59,
#          '닭튀김': 59,
#          '간장': 59,
#          '무한리필': 59,
#          '서교동': 59,
#          '시카고피자': 59,
#          '한잔': 58,
#          '특색': 58,
#          '대화': 58,
#          '말씀': 58,
#          '초코': 58,
#          '그때': 58,
#          '면도': 58,
#          '교육': 58,
#          '바닥': 58,
#          '양고기': 58,
#          '평가': 58,
#          '이탄': 58,
#          '음식점': 57,
#          '짱짱': 57,
#          '자꾸': 57,
#          '구경': 56,
#          '다소': 56,
#          '심지어': 56,
#          '동안': 56,
#          '마포구': 56,
#          '비도': 55,
#          '싸가지': 55,
#          '한국인': 55,
#          '합정': 55,
#          '만두': 55,
#          '토리': 55,
#          '곱창전골': 55,
#          '눈치': 54,
#          '환기': 54,
#          '종업원': 54,
#          '평타': 54,
#          '메뉴판': 54,
#          '모습': 54,
#          '사과': 54,
#          '비쥬': 54,
#          '육즙': 54,
#          '닭고기': 54,
#          '매번': 54,
#          '하이': 54,
#          '이집': 54,
#          '번은': 54,
#          '눈물': 54,
#          '브런치': 54,
#          '밍밍': 53,
#          '본인': 53,
#          '강아지': 53,
#          '예정': 53,
#          '간다': 53,
#          '이야기': 53,
#          '마리': 53,
#          '장점': 53,
#          '언제': 53,
#          '해주시': 53,
#          '밀크': 53,
#          '베이컨': 53,
#          '카카오': 52,
#          '쿠키': 52,
#          '대답': 51,
#          '이후': 51,
#          '아쉬움': 51,
#          '과일': 51,
#          '명란': 51,
#          '매력': 50,
#          '버섯': 50,
#          '파블로바': 50,
#          '쭈꾸미': 50,
#          '충격': 49,
#          '평소': 49,
#          '재미': 49,
#          '당황': 49,
#          '감칠맛': 49,
#          '건가': 49,
#          '만큼': 49,
#          '원두': 49,
#          '타임': 49,
#          '수가': 49,
#          '파김치': 49,
#          '사리': 49,
#          '감성': 48,
#          '결제': 48,
#          '아무': 48,
#          '전골': 48,
#          '런가': 48,
#          '닭다리': 48,
#          '시스템': 48,
#          '이전': 48,
#          '세번': 48,
#          '조리': 48,
#          '소유': 48,
#          '응원': 48,
#          '번지': 48,
#          '메론빵': 48,
#          '셀프': 47,
#          '생일': 47,
#          '제공': 47,
#          '필요': 47,
#          '그거': 47,
#          '차이': 47,
#          '얼마나': 47,
#          '고객': 47,
#          '둘이서': 47,
#          '냉면': 47,
#          '마르': 47,
#          '서울시': 47,
#          '대충': 46,
#          '날씨': 46,
#          '맛남': 46,
#          '정성': 46,
#          '대한': 46,
#          '삼겹살': 46,
#          '와인': 46,
#          '쓰레기': 46,
#          '산미': 46,
#          '양배추': 46,
#          '닭발': 46,
#          '작업': 45,
#          '테라스': 45,
#          '말투': 45,
#          '사이즈': 45,
#          '데리': 45,
#          '점점': 45,
#          '퍽퍽': 45,
#          '청결': 45,
#          '주인': 45,
#          '겨울': 44,
#          '그게': 44,
#          '성비': 44,
#          '자기': 44,
#          '이정': 44,
#          '레스토랑': 44,
#          '마감': 44,
#          '준비': 43,
#          '오기': 43,
#          '위해': 43,
#          '여자친구': 43,
#          '가족': 43,
#          '모임': 43,
#          '부담': 43,
#          '요청': 43,
#          '듬뿍': 43,
#          '본점': 43,
#          '돈카츠': 43,
#          '히레': 43,
#          '인사': 42,
#          '또한': 42,
#          '아예': 42,
#          '고급': 42,
#          '개선': 42,
#          '맛임': 42,
#          '브레이크': 42,
#          '주심': 42,
#          '피클': 42,
#          '술술': 42,
#          '로우': 42,
#          '단체': 41,
#          '카운터': 41,
#          '가치': 41,
#          '대신': 41,
#          '조절': 41,
#          '조선시대': 41,
#          '후추': 41,
#          '평이': 41,
#          '집중': 41,
#          '찾기': 41,
#          '나머지': 41,
#          '고추': 41,
#          '살살': 41,
#          '일부러': 41,
#          '탈출': 41,
#          '해물': 41,
#          '민트': 41,
#          '순대': 41,
#          '햄버거': 41,
#          '노미': 41,
#          '오코노미야끼': 41,
#          '하니': 40,
#          '실내': 40,
#          '이드': 40,
#          '지하': 40,
#          '오뎅': 40,
#          '냉동': 40,
#          '가슴': 40,
#          '리조또': 40,
#          '미니': 40,
#          '푸딩': 40,
#          '우유': 39,
#          '갑자기': 39,
#          '짜증': 39,
#          '머리': 39,
#          '붓카케': 39,
#          '에어컨': 39,
#          '일찍': 39,
#          '표정': 39,
#          '오후': 39,
#          '협소': 39,
#          '간격': 38,
#          '얼음': 38,
#          '이색': 38,
#          '포함': 38,
#          '포토': 38,
#          '워낙': 38,
#          '시카고': 38,
#          '와사비': 38,
#          '일품': 38,
#          '대해': 38,
#          '여러': 38,
#          '목살': 38,
#          '혹시': 38,
#          '수제': 38,
#          '탕후루': 38,
#          '이탈리아': 38,
#          '빵집': 38,
#          '훠궈': 38,
#          '맑은': 38,
#          '베이글': 38,
#          '대부분': 37,
#          '젓가락': 37,
#          '년전': 37,
#          '단맛': 37,
#          '부위': 37,
#          '바질': 37,
#          '조작': 37,
#          '합리': 36,
#          '레몬': 36,
#          '말차': 36,
#          '테마': 36,
#          '지도': 36,
#          '도리': 36,
#          '플레이': 36,
#          '얼마': 36,
#          '몇번': 36,
#          '분명': 36,
#          '오징어': 36,
#          '한우': 36,
#          '미국': 36,
#          '하루': 36,
#          '된장찌개': 36,
#          '흑임자': 36,
#          '중식': 36,
#          '오래오래': 35,
#          '모양': 35,
#          '찍기': 35,
#          '은근': 35,
#          '토요일': 35,
#          '살이': 35,
#          '깜짝': 35,
#          '불구': 35,
#          '댓글': 35,
#          '동물': 35,
#          '대체': 35,
#          '게리': 35,
#          '돈가스': 35,
#          '케잌': 34,
#          '더욱': 34,
#          '밀가루': 34,
#          '간만': 34,
#          '여름': 34,
#          '조화': 34,
#          '내내': 34,
#          '향신료': 34,
#          '모듬': 34,
#          '스시': 34,
#          '함박스테이크': 34,
#          '음료수': 33,
#          '부터': 33,
#          '저번': 33,
#          '쫀득': 33,
#          '인지': 33,
#          '소진': 33,
#          '분도': 33,
#          '아래': 33,
#          '누가': 33,
#          '갈비탕': 33,
#          '보시': 33,
#          '아보카도': 33,
#          '더블': 33,
#          '베이스': 33,
#          '매일': 32,
#          '연어초밥': 32,
#          '청소': 32,
#          '조명': 32,
#          '먼지': 32,
#          '시작': 32,
#          '만하': 32,
#          '간도': 32,
#          '전문점': 32,
#          '발견': 32,
#          '장난': 32,
#          '피맥': 32,
#          '별개': 32,
#          '생맥주': 32,
#          '지방': 32,
#          '참치': 32,
#          '페어': 32,
#          '학생': 31,
#          '아부': 31,
#          '환상': 31,
#          '만해': 31,
#          '장갑': 31,
#          '창가': 31,
#          '양파': 31,
#          '커서': 31,
#          '순간': 31,
#          '방식': 31,
#          '장님': 31,
#          '유명': 31,
#          '상수': 31,
#          '식전': 31,
#          '엄마': 31,
#          '소문': 31,
#          '교자': 31,
#          '중국': 31,
#          '일식': 31,
#          '패티': 31,
#          '식초': 31,
#          '사이': 30,
#          '주스': 30,
#          '게다가': 30,
#          '무시': 30,
#          '우선': 30,
#          '초심': 30,
#          '개존맛': 30,
#          '안감': 30,
#          '서버': 30,
#          '한참': 30,
#          '미슐랭': 30,
#          '간식': 30,
#          '힐링': 30,
#          '의심': 30,
#          '네이버': 30,
#          '볶음': 30,
#          '짜장면': 30,
#          '테이크아웃': 29,
#          '센스': 29,
#          '영수증': 29,
#          '화가': 29,
#          '안쪽': 29,
#          '초반': 29,
#          '행복': 29,
#          '정리': 29,
#          '신촌': 29,
#          '결론': 29,
#          '방법': 29,
#          '불고기': 29,
#          '정돈': 29,
#          '츠쿠네': 29,
#          '여유': 28,
#          '판매': 28,
#          '거나': 28,
#          '실수': 28,
#          '밥알': 28,
#          '오시': 28,
#          '콜라': 28,
#          '상황': 28,
#          '오지': 28,
#          '이하': 28,
#          '예상': 28,
#          '한편': 28,
#          '된장': 28,
#          '수저': 28,
#          '난이': 28,
#          '방송': 28,
#          '품절': 28,
#          '오일': 28,
#          '보람': 28,
#          '숙성': 28,
#          '베이커리': 28,
#          '야외': 27,
#          '점도': 27,
#          '설탕': 27,
#          '메인': 27,
#          '검색': 27,
#          '는걸': 27,
#          '소개': 27,
#          '가까이': 27,
#          '꿀맛': 27,
#          '마치': 27,
#          '부모님': 27,
#          '명성': 27,
#          '리스트': 27,
#          '감안': 27,
#          '무한': 27,
#          '녹차': 27,
#          '좀더': 27,
#          '점심시간': 27,
#          '하이디': 27,
#          '화이팅': 27,
#          '애정': 26,
#          '아이스': 26,
#          '한마디': 26,
#          '다가': 26,
#          '건물': 26,
#          '일요일': 26,
#          '반죽': 26,
#          '시기': 26,
#          '시국': 26,
#          '바람': 26,
#          '바나나': 26,
#          '등등': 26,
#          '까눌레': 26,
#          '기고': 26,
#          '몇개': 26,
#          '깻잎': 26,
#          '공기': 26,
#          '평균': 26,
#          '금액': 26,
#          '벌레': 26,
#          '두툼': 26,
#          '여우': 26,
#          '뉴스': 26,
#          '보임': 25,
#          '하프': 25,
#          '점원': 25,
#          '예술': 25,
#          '도착': 25,
#          '엉망': 25,
#          '기적': 25,
#          '천장': 25,
#          '정식': 25,
#          '기름기': 25,
#          '후식': 25,
#          '벌써': 25,
#          '김치전': 25,
#          '신맛': 25,
#          '생선': 25,
#          '오렌지': 25,
#          '쇼유라멘': 25,
#          '노력': 24,
#          '샌드위치': 24,
#          '계단': 24,
#          '입장료': 24,
#          '요다음': 24,
#          '아마': 24,
#          '갈수록': 24,
#          '밸런스': 24,
#          '진짜진짜': 24,
#          '처럼': 24,
#          '가루': 24,
#          '구리': 24,
#          '신분': 24,
#          '간판': 24,
#          '불편': 24,
#          '강남': 24,
#          '번호': 24,
#          '숙주': 24,
#          '런치': 24,
#          '도전': 24,
#          '담배': 24,
#          '안남': 24,
#          '불맛': 24,
#          '쉐프': 24,
#          '고구마': 24,
#          '츠케': 24,
#          '공명': 24,
#          '컹컹': 24,
#          '레전드': 23,
#          '아주머니': 23,
#          '다행': 23,
#          '잔뜩': 23,
#          '여행': 23,
#          '잠깐': 23,
#          '아침': 23,
#          '주차장': 23,
#          '누구': 23,
#          '외국': 23,
#          '유지': 23,
#          '인원': 23,
#          '감탄': 23,
#          '시간대': 23,
#          '배려': 23,
#          '여직원': 23,
#          '구석': 23,
#          '작고': 23,
#          '나무': 23,
#          '마인드': 23,
#          '리지': 23,
#          '보이': 23,
#          '제한': 23,
#          '사르르': 23,
#          '나폴리': 23,
#          '풍기': 23,
#          '호점': 23,
#          '돼지국밥': 23,
#          '주신': 22,
#          '당신': 22,
#          '기사': 22,
#          '음식물': 22,
#          '아들': 22,
#          '안해': 22,
#          '아이스크림': 22,
#          '학교': 22,
#          '여성': 22,
#          '점수': 22,
#          '새벽': 22,
#          '술안주': 22,
#          '메리트': 22,
#          '채소': 22,
#          '평생': 22,
#          '선물': 22,
#          '쌀국수': 22,
#          '실패': 22,
#          '자몽': 22,
#          '요거트': 22,
#          '파리': 22,
#          '돈코츠라멘': 22,
#          '일본인': 22,
#          '오믈렛': 22,
#          '회사': 22,
#          '국수': 22,
#          '신미경': 22,
#          '찜닭': 22,
#          '돈쭐내러': 22,
#          '프랜차이즈': 21,
#          '아아': 21,
#          '체적': 21,
#          '부탁': 21,
#          '덕후': 21,
#          '금요일': 21,
#          '마냥': 21,
#          '대응': 21,
#          '아인': 21,
#          '슈페': 21,
#          '정통': 21,
#          '분만': 21,
#          '가시': 21,
#          '반숙': 21,
#          '얼굴': 21,
#          '나은': 21,
#          '협소해': 21,
#          '다리': 21,
#          '바닐라': 21,
#          '만족도': 21,
#          '포크': 21,
#          '의문': 21,
#          '제외': 21,
#          '수정': 21,
#          '브라운': 21,
#          '기다림': 21,
#          '오레': 21,
#          '셰프': 21,
#          '해산물': 21,
#          '삼계탕': 21,
#          '매쉬': 21,
#          '은행': 21,
#          '족발': 21,
#          '여태': 20,
#          '식기': 20,
#          '안함': 20,
#          '로서': 20,
#          '남아': 20,
#          '특징': 20,
#          '숟가락': 20,
#          '시반': 20,
#          '거지': 20,
#          '역대': 20,
#          '접객': 20,
#          '프로': 20,
#          '팅할': 20,
#          '전문': 20,
#          '끝판': 20,
#          '달리': 20,
#          '날치': 20,
#          '얼그레이': 20,
#          '공연': 20,
#          '한정': 20,
#          '연남동': 20,
#          '김말이': 20,
#          '완벽': 20,
#          '루프': 20,
#          '게임': 20,
#          '멘보샤': 20,
#          '감사': 20,
#          '깍두기': 20,
#          '당면': 20,
#          '중독': 20,
#          '매운탕': 19,
#          '전이': 19,
#          '체크': 19,
#          '낫다': 19,
#          '포기': 19,
#          '지고': 19,
#          '편입': 19,
#          '가라': 19,
#          '작성': 19,
#          '의미': 19,
#          '일주일': 19,
#          '짠맛': 19,
#          '나이': 19,
#          '삼겹': 19,
#          '만약': 19,
#          '불만': 19,
#          '트러플': 19,
#          '팥빙수': 19,
#          '양갱': 19,
#          '시트': 19,
#          '마카롱': 19,
#          '카드': 19,
#          '페페로니': 19,
#          '이상은': 19,
#          '탄두리': 19,
#          '베리': 19,
#          '고등어': 19,
#          '이태리': 19,
#          ...})

# %%
filtered_words
# Out:
# ['까페',
#  '사람',
#  '매우',
#  '음악',
#  '손님',
#  '때문',
#  '방해',
#  '한번',
#  '커피',
#  '메뉴',
#  '리필',
#  '때문',
#  '사실',
#  '시간',
#  '합리',
#  '가격',
#  '생각',
#  '직원',
#  '자주',
#  '생각',
#  '오히려',
#  '손님',
#  '방해',
#  '공간',
#  '문화',
#  '노력',
#  '세심',
#  '웃음',
#  '응대',
#  '프랜차이즈',
#  '공간',
#  '합리',
#  '가격',
#  '홍대',
#  '사색',
#  '공간',
#  '운영',
#  '전하',
#  '볼거리',
#  '음료',
#  '장사',
#  '생각',
#  '보임',
#  '커피',
#  '돈값',
#  '카페',
#  '부수',
#  '수입',
#  '작년',
#  '아메리카노',
#  '수준',
#  '손님',
#  '인사',
#  '커녕',
#  '인사',
#  '해도',
#  '대충',
#  '사장',
#  '디저트',
#  '커피',
#  '무난',
#  '복합',
#  '공간',
#  '쇼핑',
#  '힙하',
#  '여유',
#  '기도',
#  '커피',
#  '아메리카노',
#  '무료',
#  '리필',
#  '홍대',
#  '작업',
#  '카페',
#  '종류',
#  '구경',
#  '커피',
#  '북카페',
#  '편집',
#  '느낌',
#  '비치',
#  '구매',
#  '커피',
#  '커피',
#  '샌드위치',
#  '가격',
#  '직원',
#  '불친절',
#  '테이블',
#  '간격',
#  '정도',
#  '편안',
#  '각종',
#  '굿즈',
#  '북카페',
#  '혼자',
#  '한잔',
#  '아이쇼핑',
#  '일석이조',
#  '커피',
#  '가격',
#  '대가',
#  '테이블',
#  '간격',
#  '북카페',
#  '편집',
#  '느낌',
#  '진열',
#  '물품',
#  '커피',
#  '공간',
#  '디자인',
#  '요소',
#  '매장',
#  '차지',
#  '공부',
#  '작업',
#  '커피',
#  '때문',
#  '입도',
#  '음료',
#  '테이크아웃',
#  '하프',
#  '음료',
#  '라떼',
#  '밍밍',
#  '팝업',
#  '독립',
#  '적도',
#  '진열',
#  '헤드셋',
#  '준비',
#  '판매',
#  '제품',
#  '학생',
#  '프로젝트',
#  '회의',
#  '자주',
#  '방문',
#  '진행',
#  '기억',
#  '야외',
#  '테라스',
#  '가을',
#  '방문',
#  '일본',
#  '느낌',
#  '혼자',
#  '공부',
#  '가기',
#  '카페',
#  '독립',
#  '서점',
#  '혼자',
#  '방문',
#  '오히려',
#  '에너지',
#  '오래오래',
#  '가게',
#  '리뷰',
#  '처음',
#  '북카페',
#  '라지',
#  '커피',
#  '팔면',
#  '죄악',
#  '커피',
#  '노맛',
#  '안사면',
#  '판매',
#  '목적',
#  '카페',
#  '이름',
#  '편집',
#  '직원',
#  '응대',
#  '또한',
#  '관리',
#  '일체',
#  '추천',
#  '편집',
#  '공부',
#  '카페',
#  '공부',
#  '사람',
#  '그니',
#  '라떼',
#  '달달',
#  '아이스티',
#  '상큼',
#  '살짝',
#  '화장실',
#  '커피',
#  '충격',
#  '커피',
#  '열시',
#  '오픈',
#  '준비',
#  '사람',
#  '운영',
#  '시간',
#  '커피',
#  '커피',
#  '레몬에이드',
#  '얼음',
#  '레몬',
#  '탄산',
#  '전혀',
#  '자신감',
#  '천원',
#  '북카페',
#  '테이블',
#  '간격',
#  '의자',
#  '무선',
#  '충전기',
#  '공부',
#  '좌석',
#  '사람',
#  '시간',
#  '영업',
#  '바스크',
#  '치즈케이크',
#  '단체',
#  '아아',
#  '여럿',
#  '이서',
#  '탁자',
#  '혼자',
#  '점도',
#  '주기',
#  '사장',
#  '금일',
#  '방문',
#  '친구',
#  '세명',
#  '테라스',
#  '테이블',
#  '자리',
#  '사장',
#  '지인',
#  '보이시',
#  '저희',
#  '기분',
#  '요인',
#  '테이블',
#  '자리',
#  '의자',
#  '테이블',
#  '높이',
#  '플라스틱',
#  '의자',
#  '장사',
#  '손님',
#  '막대',
#  '지인',
#  '테이블',
#  '손님',
#  '카페',
#  '자리',
#  '시간',
#  '보고',
#  '테이블',
#  '눈치',
#  '카페',
#  '생각',
#  '가세',
#  '테이블',
#  '커플',
#  '곳도',
#  '테라스',
#  '테이블',
#  '친구',
#  '이서',
#  '테이블',
#  '테이블',
#  '의자',
#  '테라스',
#  '자리',
#  '지인',
#  '서비스',
#  '지인',
#  '테라스',
#  '상식',
#  '생각',
#  '테이블',
#  '테이블',
#  '테이블',
#  '의자',
#  '카페',
#  '절대',
#  '장사',
#  '지인',
#  '카페',
#  '노트북',
#  '카페',
#  '커피',
#  '인스타',
#  '업로드',
#  '카페',
#  '뱅쇼',
#  '알딸딸',
#  '날씨',
#  '평일',
#  '시경',
#  '방문',
#  '가격',
#  '테이블',
#  '사이',
#  '간격',
#  '조금',
#  '자주',
#  '이제',
#  '사실',
#  '년새',
#  '손님',
#  '다소',
#  '점도',
#  '항상',
#  '애정',
#  '공간',
#  '우퍼',
#  '때문',
#  '책상',
#  '진동',
#  '정도',
#  '북카페',
#  '분류',
#  '마케팅',
#  '전시',
#  '느낌',
#  '사람',
#  '공간',
#  '생각',
#  '전혀',
#  '안듬',
#  '북카페',
#  '아주',
#  '점재',
#  '방문',
#  '의사',
#  '유아',
#  '이스',
#  '라떼',
#  '곡물',
#  '특유',
#  '남수정',
#  '라떼',
#  '직원',
#  '가격',
#  '대비',
#  '생각',
#  '점재',
#  '방문',
#  '사무',
#  '작업',
#  '환경',
#  '자유',
#  '개인',
#  '업무',
#  '공간',
#  '전시',
#  '판매',
#  '구경',
#  '쏠쏠',
#  '음료',
#  '무난',
#  '방문',
#  '횟수',
#  '인스타',
#  '감성',
#  '프라이탁',
#  '음악',
#  '크기',
#  '음료',
#  '말차',
#  '라떼',
#  '추천',
#  '화장실',
#  '외부',
#  '깨끗책',
#  '화장실',
#  '작업',
#  '콘센트',
#  '작업',
#  '거나',
#  '공부',
#  '사람',
#  '치안',
#  '시설',
#  '야외',
#  '테이블',
#  '시간',
#  '근처',
#  '라면',
#  '매일',
#  '여유',
#  '아이스',
#  '라떼',
#  '우유',
#  '커피',
#  '쓴맛',
#  '아메리카노',
#  '라떼',
#  '중간',
#  '정도',
#  '라떼',
#  '무슨',
#  '공간',
#  '구성',
#  '근처',
#  '자주',
#  '직원',
#  '약간',
#  '와글와글',
#  '개인',
#  '업무',
#  '마음',
#  '드네',
#  '북카페',
#  '노래',
#  '소리',
#  '의자',
#  '음료',
#  '홍대역',
#  '인근',
#  '서점',
#  '아트',
#  '카페',
#  '혜원',
#  '출판사',
#  '운영',
#  '사진',
#  '문학',
#  '커피',
#  '종류',
#  '테마',
#  '주로',
#  '엽서',
#  '센스',
#  '에코',
#  '상품',
#  '구경',
#  '종류',
#  '케이크',
#  '종류',
#  '특색',
#  '사진',
#  '인절미',
#  '케이크',
#  '제리',
#  '구멍',
#  '치즈',
#  '모양',
#  '케이크',
#  '커피',
#  '리필',
#  '가운데',
#  '카운터',
#  '중심',
#  '전반',
#  '부와',
#  '좌측',
#  '서점',
#  '아트',
#  '후반',
#  '부와',
#  '우측',
#  '카페',
#  '공간',
#  '구성',
#  '규모',
#  '방문',
#  '각자',
#  '시간',
#  '음료',
#  '주문',
#  '갑자기',
#  '매장',
#  '이용',
#  '샌드위치',
#  '주문',
#  '고함',
#  '강매',
#  '레전드',
#  '이용',
#  '섭식장애',
#  '사람',
#  '매장',
#  '이용',
#  '하나요',
#  '공부',
#  '사람',
#  '테이블',
#  '콘센트',
#  '별로',
#  '커피',
#  '공부',
#  '심구',
#  '거리',
#  '구경',
#  '용품',
#  '계단',
#  '정도',
#  '휠체어',
#  '이용',
#  '조금',
#  '어려움',
#  '화장실',
#  '노트북',
#  '인상',
#  '고독',
#  '현대인',
#  '르끰누',
#  '재활용',
#  '상품',
#  '장난감',
#  '여자',
#  '알바',
#  '불친절',
#  '무슨',
#  '북카페',
#  '음악',
#  '프라이탁',
#  '구경',
#  '가방',
#  '컨셉',
#  '느낌',
#  '카페',
#  '오픈',
#  '느낌',
#  '카페',
#  '약간',
#  '인테리어',
#  '화장실',
#  '북카페',
#  '카페',
#  '자리',
#  '굿즈들',
#  '구경',
#  '수도',
#  '커피',
#  '마시기',
#  '거리',
#  '주스',
#  '장소',
#  '커피',
#  '서적',
#  '문구',
#  '종종',
#  '문화',
#  '행사',
#  '공간',
#  '볼거리',
#  '지름신',
#  '점원',
#  '가면',
#  '독립',
#  '서점',
#  '카페',
#  '예술',
#  '정도',
#  '방문',
#  '뭔가',
#  '매력',
#  '학생',
#  '고시원',
#  '금욜',
#  '저녁',
#  '시간',
#  '가성',
#  '비도',
#  '별로',
#  '존맛',
#  '용서',
#  '최악',
#  '최악',
#  '셋팅',
#  '반찬',
#  '단체',
#  '짜증',
#  '내면',
#  '말투',
#  '자리',
#  '고함',
#  '메뉴',
#  '전혀',
#  '메뉴',
#  '한마디',
#  '매운탕',
#  '역시',
#  '달라',
#  '다시',
#  '방어',
#  '물량',
#  '무조건',
#  '광어',
#  '가격',
#  '체적',
#  '난국',
#  '직원',
#  '불친절',
#  '눈치',
#  '식당',
#  '시간',
#  '대기',
#  '바로',
#  '입장',
#  '방어',
#  '로만',
#  '주문',
#  '무조건',
#  '방어',
#  '처음',
#  '무맛',
#  '올해',
#  '방어',
#  '사이드',
#  '주신',
#  '전이',
#  '초밥',
#  '셀프',
#  '안내',
#  '야채',
#  '추가',
#  '반찬',
#  '셀프',
#  '매장',
#  '안이',
#  '가세',
#  '최악',
#  '전화',
#  '아예',
#  '배달',
#  '포장',
#  '변경',
#  '어찌',
#  '방어',
#  '어회',
#  '우회',
#  '새우',
#  '전반',
#  '가격',
#  '대가',
#  '오히려',
#  '동네',
#  '술집',
#  '웨이팅',
#  '테이블',
#  '간격',
#  '크게',
#  '수도',
#  '직원',
#  '회도',
#  '별로',
#  '별로',
#  '공간',
#  '테이블',
#  '사람과',
#  '수준',
#  '대화',
#  '불가',
#  '참으로',
#  '불친절',
#  '심지어',
#  '양도',
#  '별로',
#  '콘치',
#  '하니',
#  '본인',
#  '가게',
#  '콘치즈',
#  '후기',
#  '하니',
#  '콘치',
#  '사진',
#  '맛집',
#  '이유',
#  '계산',
#  '맛집',
#  '다짐',
#  '사장',
#  '직원',
#  '서비스',
#  '개똥',
#  '인정',
#  '위치',
#  '특성',
#  '밑반찬',
#  '맛남',
#  '역시',
#  '홍대입구역',
#  '횟집',
#  '최고',
#  '도다리',
#  '지리',
#  '다만',
#  '직원',
#  '살짝',
#  '저녁',
#  '자리',
#  '바로',
#  '창문',
#  '활짝',
#  '부탁',
#  '환기',
#  '광어',
#  '연어',
#  '광어',
#  '우럭',
#  '잘못',
#  '우럭',
#  '절대',
#  '줌옆',
#  '좌석',
#  '연어',
#  '횟집',
#  '방어',
#  '방어',
#  '회도',
#  '매운탕',
#  '그닥',
#  '서빙',
#  '대답',
#  '점도',
#  '계산',
#  '매운탕',
#  '세트',
#  '매운탕',
#  '추가',
#  '술병',
#  '계산',
#  '얘기',
#  '테이블',
#  '영수증',
#  '확인',
#  '가끔',
#  '오늘',
#  '실망',
#  '연어초밥',
#  '초밥',
#  '포장',
#  '연어',
#  '초밥',
#  '관건',
#  '고민',
#  '참고',
#  '쓰시',
#  '가게',
#  '광어',
#  '새우',
#  '튀김',
#  '겨울',
#  '방어',
#  '맛집',
#  '방어',
#  '사이즈',
#  '양도',
#  '배리',
#  '굳이',
#  '바다',
#  '사랑',
#  '방어',
#  '종업원',
#  '친절',
#  '눈치',
#  '정도',
#  '불친절',
#  '매운탕',
#  '별로',
#  '줄평',
#  '위치',
#  '장사',
#  '솜씨',
#  '음식',
#  '평타',
#  '별로',
#  '가격',
#  '홍대',
#  '물가',
#  '생각',
#  '퀄리티',
#  '고려',
#  '서비스',
#  '실수',
#  '기분',
#  '수도',
#  '당신',
#  '콘치즈',
#  '당신',
#  '직원',
#  '사이드',
#  '메뉴인',
#  '미역국',
#  '밥알',
#  '재탕',
#  '차마',
#  '상상',
#  '재탕',
#  '설거지',
#  '제대로',
#  '비위',
#  '상햇',
#  '쿠팡잇츠',
#  '배달',
#  '주문',
#  '배달',
#  '기사',
#  '음식',
#  '주문',
#  '취소',
#  '연락',
#  '음식점',
#  '수용',
#  '범위',
#  '주문',
#  '평소',
#  '자주',
#  '오늘',
#  '아주머니',
#  '테이블',
#  '넵킨',
#  '대충',
#  '음식물',
#  '얼룩',
#  '그대로',
#  '세팅',
#  '맥주잔',
#  '제대로',
#  '자국',
#  '음식물',
#  '최악',
#  '테이블',
#  '그게',
#  '가장',
#  '기본',
#  '오진',
#  '화장실',
#  '가성',
#  '친절',
#  '겨를',
#  '방어',
#  '자체',
#  '가성',
#  '방어',
#  '위치',
#  '고려',
#  '가성',
#  '생각',
#  '서비스',
#  '정신',
#  '하나',
#  '친절',
#  '불친절',
#  '지도',
#  '다만',
#  '웨이팅',
#  '마이너스',
#  '이건',
#  '친절',
#  '일도',
#  '가지',
#  '시간',
#  '서빙',
#  '매니',
#  '최악',
#  '먼저',
#  '사람',
#  '먼저',
#  '시간',
#  '웨이',
#  '자리',
#  '소리',
#  '한마디',
#  '체크',
#  '방구',
#  '장사',
#  '불친절',
#  '방어',
#  '특대',
#  '두툼해',
#  '됴타웨이팅',
#  '시간',
#  '방어',
#  '연어',
#  '중인',
#  '회덮밥',
#  '도착',
#  '시간',
#  '웨이',
#  '남자',
#  '여자',
#  '이서',
#  '매운탕',
#  '콘치',
#  '계란찜',
#  '백김치',
#  '부추',
#  '전이',
#  '밑반찬',
#  '회덮밥',
#  '웨이팅',
#  '다시',
#  '밑반찬',
#  '다시',
#  '의향',
#  '홍대',
#  '근처',
#  '횟집',
#  '하나',
#  '가격',
#  '독보',
#  '양도',
#  '음가',
#  '성비',
#  '별로',
#  '친절',
#  '매우',
#  '데이트',
#  '주차',
#  '별로',
#  '방문',
#  '의사',
#  '여태',
#  '파스타',
#  '제일',
#  '스테이크',
#  '강추',
#  '피자',
#  '패스츄리',
#  '소스',
#  '하나',
#  '하나',
#  '가격',
#  '책상',
#  '식기',
#  '화장실',
#  '리뷰',
#  '별로',
#  '인테리어',
#  '완전',
#  '친구',
#  '강아지',
#  '방문',
#  '뇨끼',
#  '파스타',
#  '뇨끼',
#  '직원',
#  '장사',
#  '음식',
#  '거의',
#  '접대',
#  '별로',
#  '맛집',
#  '방문',
#  '의사',
#  '최고',
#  '인테리어',
#  '음료',
#  '달라',
#  '구경',
#  '음료',
#  '옛날',
#  '해리',
#  '포터',
#  '다음',
#  '장소',
#  '원츄',
#  '원츄',
#  '이색',
#  '카페',
#  '아이',
#  '메뉴',
#  '깡패',
#  '특색',
#  '해덕',
#  '최고',
#  '장소',
#  '쮝쮝',
#  '카페',
#  '마법',
#  '한번',
#  '생각',
#  '친구',
#  '연인',
#  '끼리',
#  '해리포터',
#  '무조건',
#  '해리포터',
#  '해리포터',
#  '덕후',
#  '헤헤',
#  '아부',
#  '라카',
#  '브라',
#  '쪼아용',
#  '라떼',
#  '별로',
#  '영화',
#  '카페',
#  ...]

# %%
## 가중치 계산
# Create a dictionary of synonym groups
synonym_groups = {
    "western": ["양식","피자","파스타","버거","샐러드","스테이크","화덕","시카고피자","레스토랑","피클"],
    "japan": ["일식","라멘","우동","튀김","초밥","츠케멘","소바","차슈","카츠","회"],
    "service": ["서비스","친절","퀄리티","위생","설명","상태","관리","청결","정성","합리"],
    "location": ["스타일","컨셉","인스타","특색","감성","뷰","테라스","테마","야외","예술"],
    "meat": ["고기","곱창","돼지","닭갈비","등심","갈비","대창","삼겹살","육즙","양고기"],
    "alchol": ["술","국물","안주","맥주","술집","막걸리","소주","한잔","생맥주", "칵테일"],
    "cafe": ["카페","딸기","케이크","음료","빵","디저트","라떼","빙수","케익","생크림"],
    "time": ["시간","근처","거리","동네","예약","대기","웨이팅","주변","멀리","가까"]
}

# Function to calculate the frequency of group words in each review's word list
def calculate_group_weights(words, group_words):
    return sum(word in group_words for word in words)

# Apply the function for each group
for group_name, group_words in synonym_groups.items():
    review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))

# Aggregate these group weights by merchant
grouped_weights = review_df_clean.groupby('merchant')[list(synonym_groups.keys())].sum()

# Normalize the weights by the number of reviews for each restaurant
normalized_weights = grouped_weights.div(review_df_clean.groupby('merchant').size(), axis=0)

# Display the processed weights for each restaurant
normalized_weights.reset_index().head()
# Out:
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
# C:\Users\Jws\AppData\Local\Temp\ipykernel_32960\4274761084.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_clean[group_name] = review_df_clean['filtered_words'].apply(lambda words: calculate_group_weights(words, group_words))
#       merchant   western     japan   service  location      meat    alchol  \
# 0         1984  0.000000  0.000000  0.063492  0.222222  0.000000  0.015873
# 1  21세기 우리바다수산  0.000000  0.090909  0.181818  0.000000  0.000000  0.022727
# 2       38도씨식당  0.307692  0.000000  0.076923  0.000000  0.000000  0.000000
# 3     943킹스크로스  0.000000  0.006211  0.031056  0.111801  0.003106  0.074534
# 4        가로수포차  0.333333  0.000000  0.250000  0.083333  0.083333  0.416667
#
#        cafe      time
# 0  0.571429  0.158730
# 1  0.000000  0.272727
# 2  0.000000  0.000000
# 3  0.549689  0.055901
# 4  0.000000  0.000000

# %%
# Reset index to ensure 'merchant' is a column
normalized_weights_reset = normalized_weights.reset_index()

# %%
normalized_weights_reset['별천지설농탕']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jws\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '별천지설농탕'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 normalized_weights_reset['별천지설농탕']
#
# File c:\Users\Jws\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Jws\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '별천지설농탕'

# %%
# normalized_weights_reset.to_csv('../data2/weights.csv', index=False)

# %%
from scipy.stats import pearsonr
import numpy as np

# %%
### 유사도 비교


# Function to calculate Pearson correlation matrix for all pairs of merchants
def pearson_correlation_matrix(df):
    # Number of merchants
    n = df.shape[0]
    # Initialize the correlation matrix
    correlation_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            if i != j:
                data_i = df.iloc[i, 1:].values
                data_j = df.iloc[j, 1:].values
                correlation, _ = pearsonr(data_i, data_j)
                correlation_matrix[i, j] = correlation
            else:
                correlation_matrix[i, j] = 1  # Self correlation is always 1
    return correlation_matrix

# Calculate the Pearson correlation matrix
correlation_matrix = pearson_correlation_matrix(normalized_weights_reset)
correlation_matrix
# Out:
# array([[ 1.        , -0.1258035 , -0.29907038, ..., -0.31724098,
#         -0.3732846 , -0.20629136],
#        [-0.1258035 ,  1.        , -0.16890769, ..., -0.16045149,
#          0.23341702,  0.50467209],
#        [-0.29907038, -0.16890769,  1.        , ..., -0.2372895 ,
#         -0.24557394, -0.07057202],
#        ...,
#        [-0.31724098, -0.16045149, -0.2372895 , ...,  1.        ,
#          0.03738847, -0.29740896],
#        [-0.3732846 ,  0.23341702, -0.24557394, ...,  0.03738847,
#          1.        , -0.04373735],
#        [-0.20629136,  0.50467209, -0.07057202, ..., -0.29740896,
#         -0.04373735,  1.        ]])

# %%
import numpy as np

# %%
np.save('../data2/cor.npy', correlation_matrix)

# %%
## 유사도 높은 10개 식당 출력
def find_similar_restaurants(restaurant_name, weights_path, cor_path, top_n=10):
    # 데이터 로드
    weights_df = pd.read_csv(weights_path)
    cor_matrix = np.load(cor_path)
    
    # 음식점 이름 목록 가져오기
    restaurant_names = weights_df['merchant'].values
    
    # 주어진 음식점의 인덱스 찾기
    if restaurant_name in restaurant_names:
        idx = np.where(restaurant_names == restaurant_name)[0][0]
        
        # 유사도 점수와 인덱스 가져오기
        similarity_scores = cor_matrix[idx]
        
        # 유사도에 따라 인덱스 정렬 및 상위 N개 선택
        sorted_indices = np.argsort(similarity_scores)[::-1]
        top_indices = sorted_indices[1:top_n+1]  # 자기 자신 제외
        
        # 결과 출력
        print(f"Top {top_n} restaurants similar to {restaurant_name}:")
        for i in top_indices:
            print(f"{restaurant_names[i]} - Similarity: {similarity_scores[i]}")
    else:
        print(f"Restaurant name '{restaurant_name}' not found in the list.")

# 사용 예
# find_similar_restaurants('example_restaurant', 'path/to/weights.csv', 'path/to/cor.npy')

# %%
find_similar_restaurants('삼거리포차','../data2/weights.csv','../data2/cor.npy')
# Out:
# Top 10 restaurants similar to 삼거리포차:
# 꼼보포차 홍대2호점 - Similarity: 0.9861264954268181
# 룸넘버3 브런치 카페&와인 - Similarity: 0.9773555548504418
# 미로식당 - Similarity: 0.9759046823277522
# 산울림1992 - Similarity: 0.9656821497458467
# 키즈나 - Similarity: 0.9519366412056718
# 벽돌포차 - Similarity: 0.9439794899424117
# 코키펍 홍대점 - Similarity: 0.9169493006161777
# 썰스데이파티 - Similarity: 0.9169493006161777
# 어른이대공원 - Similarity: 0.8988714651559209
# 별천지설농탕 - Similarity: 0.8960632943213851

# %%
## -------------------------------------------------------

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\jws\anaconda3\lib\site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\jws\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
# !pip install cython
# Out:
# Collecting cython
#   Downloading Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Downloading Cython-3.0.10-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.8 MB 495.5 kB/s eta 0:00:06
#    ---- ----------------------------------- 0.3/2.8 MB 2.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.8 MB 2.2 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.8 MB 2.5 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 2.4/2.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: cython
# Successfully installed cython-3.0.10

# %%
import numpy as np
import cython
import scipy

# %%
# !pip install gensim

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from gensim.models.fasttext import FastText

# %%
from gensim.models import KeyedVectors

# 모델 로드
model = KeyedVectors.load_word2vec_format('./cc.ko.300.bin', binary=True)

# %%
from gensim.models import KeyedVectors
from gensim import models

# 모델 로드
ko_model = models.fasttext.load_facebook_model('./cc.ko.300.bin')

# 'filtered_words'에서 상위 단어 선택
top_words = ['라멘', '양식', '서비스', '커플', '고기', '술', '카페', '웨이팅', '데이트', '가족']  # 예시 단어 리스트

# 각 단어에 대해 유사 단어 찾기
for word in top_words:
    if word in ko_model.wv.key_to_index:  # 모델에 단어가 있는지 확인
        similar_words = ko_model.wv.most_similar(word, topn=13)  # 가장 유사한 10개 단어 찾기
        print(f"Word: {word}, Similar Words: {similar_words}")
    else:
        print(f"{word} is not in the vocabulary")
# Out:
# Word: 라멘, Similar Words: [('소바', 0.6055879592895508), ('라멘의', 0.6014007925987244), ('퓨얼드', 0.5990808010101318), ('라멘은', 0.5769829750061035), ('이치란', 0.576982319355011), ('라멘으로', 0.5695579051971436), ('초밥', 0.5679571628570557), ('잇푸도', 0.5663458108901978), ('덮밥', 0.5654603242874146), ('오뎅', 0.5640437602996826)]
# Word: 양식, Similar Words: [('糧食', 0.7907487750053406), ('良識', 0.7743086814880371), ('洋食', 0.6927233934402466), ('樣式', 0.6794001460075378), ('양식과', 0.5734102725982666), ('수산증', 0.5720512866973877), ('일용할', 0.5660973787307739), ('양식의', 0.552295982837677), ('양식은', 0.5503145456314087), ('보자르', 0.5492727756500244)]
# Word: 서비스, Similar Words: [('서비스의', 0.6431233286857605), ('호텔식당조직의', 0.6139702200889587), ('서비스를', 0.6111576557159424), ('이용과정', 0.5958628058433533), ('서비스와', 0.5880147218704224), ('-서비스', 0.5860386490821838), ('광고서비스', 0.58290696144104), ('U-도서관', 0.5818356275558472), ('콘시어지', 0.5796222686767578), ('제공업체의', 0.5785194635391235)]
# Word: 커플, Similar Words: [('커플과', 0.570796549320221), ('먹깨비', 0.5535597205162048), ('커플이나', 0.5425965785980225), ('커플들', 0.5403568744659424), ('커플이', 0.5383749604225159), ('신혼', 0.5371889472007751), ('커플을', 0.5303009748458862), ('男女', 0.5289727449417114), ('커플의', 0.5270025134086609), ('커플들이', 0.523864209651947)]
# Word: 고기, Similar Words: [('古記', 0.6972495913505554), ('목살', 0.597810685634613), ('육류', 0.5962321162223816), ('고기를', 0.583968997001648), ('수육', 0.5760470032691956), ('흰살', 0.5660216808319092), ('숙회', 0.5641065239906311), ('생선', 0.558871865272522), ('편육', 0.5580330491065979), ('곱창', 0.5544238090515137)]
# Word: 술, Similar Words: [('술을', 0.7096263766288757), ('術', 0.6628096103668213), ('戌', 0.6610605120658875), ('파시냐노', 0.6376713514328003), ('나비글리오', 0.6320750117301941), ('술도', 0.6313875913619995), ('술의', 0.6250050663948059), ('술은', 0.6233973503112793), ('숟', 0.6193842887878418), ('술이', 0.6186871528625488)]
# Word: 카페, Similar Words: [('까페', 0.7127673625946045), ('페드로키', 0.6023558378219604), ('카페나', 0.5754309892654419), ('교회홈', 0.5745173096656799), ('카페를', 0.572992742061615), ('카페는', 0.5614081621170044), ('드롭탑', 0.5575875043869019), ('카페에', 0.5567399263381958), ('카페다', 0.5529505014419556), ('마간다', 0.5501941442489624)]
# Word: 웨이팅, Similar Words: [('웨이팅이', 0.4955567419528961), ('6시반에', 0.4449743628501892), ('대기줄이', 0.4429379999637604), ('웨이팅은', 0.44271084666252136), ('조금일찍', 0.43935129046440125), ('일찍와서', 0.43410032987594604), ('타임에는', 0.4322274327278137), ('다되서', 0.43121495842933655), ('저녁이라', 0.43073710799217224), ('주말이라', 0.43008679151535034)]
# Word: 데이트, Similar Words: [('데이트를', 0.5660568475723267), ('두시의', 0.5621026754379272), ('꼬마씨', 0.5324050188064575), ('데이트와', 0.5284243822097778), ('쥬얼리S', 0.5032374858856201), ('데이트가', 0.5014175772666931), ('485회', 0.496982604265213), ('데이트의', 0.4927515983581543), ('데이트코스', 0.4878951907157898), ('박경림입니다', 0.48595428466796875)]
# Word: 가족, Similar Words: [('멜로다큐', 0.6314994096755981), ('친지', 0.6244649887084961), ('家族', 0.6061099767684937), ('오락관', 0.5969728231430054), ('푸콘', 0.5624155402183533), ('출시ㆍ우리', 0.556937038898468), ('슈돌', 0.5460627675056458), ('가족과', 0.5415053963661194), ('우쿠레레', 0.5342689156532288), ('신족', 0.5261022448539734)]
