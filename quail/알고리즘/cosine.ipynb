# %%
import pandas as pd
review_df_clean = pd.read_csv('../data2/review_df_clean.csv')

# %%
review_df_clean
# Out:
#        merchant   user_name  user_rank num_response  user_star         time  \
# 0          1984  2018.05.10         22           58        2.5  2024.04.21.
# 1          1984      맛난곳만리뷰          7            7        5.0  2024.02.10.
# 2          1984          진아         25           58        4.6  2024.02.05.
# 3          1984         박찬찬         27           71        3.9  2023.12.16.
# 4          1984       프로페셔널         16           37        2.7  2023.12.04.
# ...         ...         ...        ...          ...        ...          ...
# 18669  훠궈나라 홍대점         ㅇㅅㅇ         31          122        4.0  2019.12.28.
# 18670  훠궈나라 홍대점          상준          3            2        5.0  2019.12.14.
# 18671  훠궈나라 홍대점           .          9           15        4.3  2019.11.18.
# 18672  훠궈나라 홍대점         김후연          2            1        1.0  2019.11.03.
# 18673  훠궈나라 홍대점          아임         10           16        4.1  2019.10.01.
#
# ...
