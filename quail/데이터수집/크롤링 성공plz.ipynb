# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
import os
import matplotlib.pyplot as plt
import base64

# %%
## 카카오 맵 
driver = webdriver.Chrome()
driver.get('https://map.kakao.com/')
time.sleep(2)

## input 창에 검색어 입력
searchbox = driver.find_element(By.ID, 'search.keyword.query')
searchbox.send_keys('홍대 맛집'+ Keys.ENTER)
time.sleep(3)

## 상세보기 주소 가져오기 
list_url = []

## 아래 1,2,3,4,5 리스트 번호 다 뜨도록
# 장소 더보기 클릭
driver.find_element(By.ID, 'info.search.place.more').click()
time.sleep(2)
# 1번리스트로 돌아오기
driver.find_element(By.ID, 'info.search.page.no1').click()
time.sleep(2)

for count in range(3):
    
    for inx in range(2, 6):
        
        # 현재 리스트의 상세보기 주소 스크래핑
        moreview_element = driver.find_elements(By.CSS_SELECTOR, 'a[data-id="moreview"]')
        for i in range(len(moreview_element)):
            list_url.append(moreview_element[i].get_attribute('href'))
        
        # 다음 리스트 클릭
        driver.find_element(By.ID, f'info.search.page.no{inx}').click()
        time.sleep(2)
        # 5번 리스트 저장
        if inx == 5:
            moreview_element = driver.find_elements(By.CSS_SELECTOR, 'a[data-id="moreview"]')
            for i in range(len(moreview_element)):
                list_url.append(moreview_element[i].get_attribute('href'))
        time.sleep(2)
    # 다음 리스트 페이지 넘어가기
    driver.find_element(By.ID ,'info.search.page.next').click()
    time.sleep(2)



## 웹페이지 종료
driver.close()

# %%
len(list_url)
# Out:
# 225

# %%
list_url

# %%
## 정보 넣을 빈 딕셔너리
data = {
    'merchant' : [],
    'category' : [],
    'star' : [],
    'address' : [],
    'oper_time' : [],
    'starCount' : [],
    'reviewCount' : []
}
data2 = {
    'user_name' : [],
    'user_rank' : [],
    'num_response' : [],
    'user_star' : [], 
    'time' : [],
    'rating' : [],
    'content' : []
}

# %%
print(len(data['merchant']))
print(len(data['category']))
print(len(data['star']))
print(len(data['address']))
print(len(data['oper_time']))
print(len(data['starCount']))
print(len(data['reviewCount']))
# Out:
# 225
# 225
# 225
# 225
# 225
# 225
# 225

# %%
data['reviewCount']
# Out:
# ['642',
#  '191',
#  '426',
#  '624',
#  '439',
#  '804',
#  '178',
#  '30',
#  '118',
#  '120',
#  '272',
#  '48',
#  '239',
#  '387',
#  '260',
#  '360',
#  '278',
#  '116',
#  '91',
#  '136',
#  '681',
#  '192',
#  '382',
#  '1157',
#  '403',
#  '7',
#  '1638',
#  '197',
#  '821',
#  '567',
#  '74',
#  '454',
#  '123',
#  '301',
#  '313',
#  '922',
#  '2',
#  '50',
#  '217',
#  '171',
#  '307',
#  '156',
#  '52',
#  '1469',
#  '479',
#  '181',
#  '223',
#  '1438',
#  '453',
#  '45',
#  '310',
#  '203',
#  '211',
#  '12',
#  '96',
#  '121',
#  '150',
#  '70',
#  '31',
#  '35',
#  '2544',
#  '208',
#  '314',
#  '904',
#  '894',
#  '104',
#  '238',
#  '352',
#  '64',
#  '295',
#  '409',
#  '1727',
#  '116',
#  '129',
#  '90',
#  '119',
#  '15',
#  '263',
#  '173',
#  '125',
#  '133',
#  '363',
#  '34',
#  '136',
#  '75',
#  '131',
#  '54',
#  '278',
#  '591',
#  '165',
#  '99',
#  '81',
#  '153',
#  '73',
#  '265',
#  '240',
#  '45',
#  '45',
#  '311',
#  '537',
#  '221',
#  '66',
#  '226',
#  '210',
#  '85',
#  '58',
#  '36',
#  '290',
#  '56',
#  '129',
#  '269',
#  '39',
#  '402',
#  '42',
#  '331',
#  '711',
#  '92',
#  '306',
#  '3',
#  '74',
#  '166',
#  '63',
#  '554',
#  '30',
#  '35',
#  '17',
#  '165',
#  '6',
#  '15',
#  '2',
#  '65',
#  '207',
#  '66',
#  '98',
#  '36',
#  '361',
#  '96',
#  '302',
#  '125',
#  '412',
#  '176',
#  '125',
#  '460',
#  '462',
#  '151',
#  '49',
#  '501',
#  '26',
#  '44',
#  '16',
#  '291',
#  '1610',
#  '104',
#  '44',
#  '60',
#  '148',
#  '32',
#  '151',
#  '11',
#  '96',
#  '452',
#  '2141',
#  '104',
#  '167',
#  '260',
#  '34',
#  '57',
#  '10',
#  '320',
#  '59',
#  '188',
#  '202',
#  '75',
#  '179',
#  '71',
#  '360',
#  '110',
#  '182',
#  '6',
#  '303',
#  '152',
#  '22',
#  '58',
#  '27',
#  '291',
#  '84',
#  '63',
#  '256',
#  '330',
#  '146',
#  '50',
#  '76',
#  '343',
#  '154',
#  '95',
#  '58',
#  '177',
#  '159',
#  '59',
#  '26',
#  '38',
#  '224',
#  '27',
#  '54',
#  '56',
#  '95',
#  '155',
#  '140',
#  '79',
#  '421',
#  '2048',
#  '67',
#  '202',
#  '145',
#  '123',
#  '50',
#  '50',
#  '590',
#  '99',
#  '93',
#  '51',
#  '3',
#  '90',
#  '30',
#  '70']

# %%
data['reviewCount']
# Out:
# '642'

# %%
del data['reviewCount'][37]

# %%
len(list_url)
# Out:
# 189

# %%
df = pd.DataFrame('merchant':data['merchant'], )
# Out:
# {'merchant': ['피오니 홍대점',
#   '943킹스크로스',
#   '카미야',
#   '우와 홍대본점',
#   '칸다소바 홍대점',
#   '감성타코 홍대점',
#   '맛이차이나',
#   '강강술래 홍대점',
#   '홍대 조선시대',
#   '비스트로주라',
#   '또보겠지떡볶이집 깐따삐아점',
#   '땡스네이쳐',
#   '프리모바치오바치 홍대본점',
#   '하카타분코',
#   '츠케루',
#   '가미우동',
#   '테이스티버거',
#   '진진',
#   '정돈',
#   '여우골 홍대점',
#   '하이디라오 홍대지점',
#   '마녀주방 홍대점',
#   '콜린',
#   '어반플랜트 합정',
#   '오레노라멘 합정본점',
#   '공감 홍대2호점',
#   '산더미불고기',
#   '개화기요정',
#   '비스트로사랑방',
#   '더담',
#   '짬뽕지존 홍대점',
#   '아오이토리',
#   '냉장고',
#   '이츠모라멘',
#   '황곱 홍대점',
#   '장인닭갈비 홍대점',
#   '삼거리포차',
#   '미어캣프랜즈',
#   '지로우라멘',
#   '홍마떡 홍대본점',
#   '소코아 홍대점',
#   '스아게K',
#   '김덕후의곱창조 홍대본점',
#   '델리인디아',
#   '피자네버슬립스 합정상수점',
#   '이치류 홍대본점',
#   '버터밀크',
#   '혼가츠',
#   '스탠스커피',
#   '하하&김종국의 401정육식당 홍대본점',
#   '산울림1992',
#   '이빠네마그릴 홍대점',
#   '멘야산다이메 홍대점',
#   '광동포차',
#   '홍대인파스타',
#   '웃사브',
#   '후라토식당 상수직영점',
#   '아웃닭 홍대점',
#   '백년토종삼계탕 본점',
#   '효봉포차',
#   '스케줄 합정',
#   '마시타야',
#   '홍대조폭떡볶이 홍대2호점',
#   '산리오러버스클럽',
#   '바다회사랑 2호점',
#   '제비다방',
#   '또보겠지떡볶이집 스마일보이점',
#   '카페공명 홍대점',
#   '온달집 홍대직영점',
#   '카레시',
#   '고기꾼김춘배 홍대본점',
#   '홍대씨부엉',
#   '철길왕갈비살',
#   '서강8경',
#   '서울이스케이프룸 홍대2호점',
#   '로쏘1924',
#   '꼼보포차 홍대2호점',
#   '앤트러사이트 합정점',
#   '온블랙94',
#   '철인7호치킨 홍대점',
#   '집사의하루 홍대점',
#   '어메이징농카이',
#   '재미난조각가 홍대점',
#   '훠궈나라 홍대점',
#   '더피자보이즈 합정본점',
#   '그동네떡볶이 홍대점',
#   '돈주는남자 마포점',
#   '달콤한거짓말',
#   '가든포에트',
#   '제임스시카고피자 홍대본점',
#   '보승회관 홍대직영점',
#   '합정광안리',
#   '21세기 우리바다수산',
#   '심양 홍대점',
#   '빠넬로',
#   '코노미 홍대점',
#   '조선화로구이',
#   '카페 지금여기',
#   '경주식당',
#   '우동카덴 합정점',
#   '라멘트럭 상수본점',
#   '은행골 홍대점',
#   '토모토카레 홍대점',
#   '겨울이머무는집',
#   '앵춘',
#   '도마 홍대본점',
#   '톤앤매너',
#   '싸인이스케이프 홍대점',
#   '일편등심',
#   '플레이트946',
#   '38도씨식당',
#   '왔쏘 홍대점',
#   '또보겠지떡볶이집 호호피크닉점',
#   '홍익닭한마리 홍대본점',
#   '홍스쭈꾸미 홍대본점',
#   '라헬의부엌 홍대점',
#   '부탄츄 홍대점',
#   '괴르츠',
#   '돼지상회 홍대직영점',
#   '미로식당',
#   '달콤왕가탕후루',
#   '벽돌포차',
#   '옥동식 서교점',
#   '막걸리싸롱 홍대본점',
#   '멜로우',
#   '리얼이스케이프챌린지',
#   '오리지널시카고피자 홍대본점',
#   '자세',
#   '썰스데이파티',
#   '몬스터피자 본점',
#   '예티',
#   '엑스이스케이프 홍대놀이터점',
#   '더귀여워',
#   '별천지설농탕',
#   '만만코코로 홍대점',
#   '스파카나폴리',
#   '좋아해닭발1',
#   '몰토베네',
#   '민트하임',
#   '이미커피',
#   '윤씨밀방',
#   '구스토타코',
#   '신주양꼬치 홍대점',
#   '카와카츠 본점',
#   '홍대삭 상수본점',
#   '제순식당 홍대점',
#   '야키토리 나루토',
#   '별자리마라탕 홍대점',
#   '클럽에반스',
#   '가비애',
#   '식스티즈',
#   '고고갈비 홍대상수점',
#   '구공탄곱창 본점',
#   '김앤김대게 서교점',
#   '룸넘버3 브런치 카페&와인',
#   '둥지닭볶음탕',
#   '손오공마라탕',
#   '카츠미 홍대본점',
#   '치치 서교점',
#   '서교참치',
#   '카페공명 연남점',
#   '꽃피는고기 홍대본점',
#   '루프탑어반비치',
#   '시루케이크',
#   '수상한베이글',
#   '바다포차 시실리',
#   '브레이크아웃이스케이프 홍대점',
#   '코키펍 홍대점',
#   '비트포비아 홍대던전점',
#   '여우골 홍대서교점',
#   '스페이스원',
#   '코테츠',
#   '가로수포차',
#   '허밍벨라',
#   '탐탐오향족발',
#   '티엔미미 홍대점',
#   '홍대반지카페 본점',
#   '금옥당 서교점',
#   '작가',
#   '중화복춘',
#   '비하인드',
#   '육연해by육회먹은연어 홍대점',
#   '참새방앗간',
#   '히츠지야 한국본점',
#   '스시오 홍대점',
#   '무라',
#   '고베규카츠 상수점',
#   '1984',
#   '신미경홍대닭갈비',
#   '홍대차칸곱창',
#   '어리',
#   '페더',
#   '모멘트커피',
#   '더피자보이즈 서교',
#   '부산집 홍대본점',
#   '소년식당 홍대본점',
#   '퍼셉션 (Perception)',
#   '키쉬미뇽',
#   '카페장쌤',
#   '스타벅스 홍대삼거리점',
#   '삿뽀로 홍대점',
#   '락희돈',
#   '아마',
#   '커피랩',
#   '어른이대공원',
#   '마루샤브스카이 홍대직영점',
#   '위키드찜닭',
#   '대포막창',
#   '옹다래찜닭 홍대점',
#   '큐브이스케이프 홍대점',
#   '수지앤파스타',
#   '퐁포네뜨 홍대점',
#   '토라비',
#   '옛맛서울불고기 (2024년 5월 예정)',
#   '무대륙',
#   '닭꼬얌',
#   '배터리88',
#   '또보겠지떡볶이집 붕붕허니비점',
#   '고수포차',
#   '와우끝집',
#   '키즈나',
#   '앤디스커피',
#   '델문도',
#   '스노브',
#   '오니'],
#  'category': ['카페',
#   '테마카페',
#   '돈까스,우동',
#   '일식',
#   '일본식라면',
#   '멕시칸,브라질',
#   '중국요리',
#   '한식',
#   '한식',
#   '양식',
#   '떡볶이',
#   '카페',
#   '이탈리안',
#   '일본식라면',
#   '일본식라면',
#   '돈까스,우동',
#   '햄버거',
#   '중식',
#   '돈까스,우동',
#   '초밥,롤',
#   '중국요리',
#   '양식',
#   '테마카페',
#   '카페',
#   '일본식라면',
#   '일본식주점',
#   '불고기,두루치기',
#   '일본식주점',
#   '이탈리안',
#   '한정식',
#   '중국요리',
#   '제과,베이커리',
#   '육류,고기',
#   '일본식라면',
#   '곱창,막창',
#   '닭요리',
#   '실내포장마차',
#   '테마카페',
#   '일본식라면',
#   '떡볶이',
#   '일식',
#   '일식',
#   '곱창,막창',
#   '인도음식',
#   '피자',
#   '육류,고기',
#   '카페',
#   '돈까스,우동',
#   '카페',
#   '육류,고기',
#   '호프,요리주점',
#   '멕시칸,브라질',
#   '일본식라면',
#   '실내포장마차',
#   '이탈리안',
#   '인도음식',
#   '돈까스,우동',
#   '치킨',
#   '삼계탕',
#   '실내포장마차',
#   '양식',
#   '일본식라면',
#   '떡볶이',
#   '카페',
#   '회',
#   '다방',
#   '떡볶이',
#   '커피전문점',
#   '실내포장마차',
#   '일식',
#   '육류,고기',
#   '떡볶이',
#   '갈비',
#   '양식',
#   '테마카페',
#   '피자',
#   '실내포장마차',
#   '커피전문점',
#   '스테이크,립',
#   '치킨',
#   '고양이카페',
#   '태국음식',
#   '사주카페',
#   '중국요리',
#   '피자',
#   '떡볶이',
#   '육류,고기',
#   '디저트카페',
#   '양식',
#   '피자',
#   '순대',
#   '한식',
#   '회',
#   '양꼬치',
#   '양식',
#   '일본식주점',
#   '육류,고기',
#   '카페',
#   '육류,고기',
#   '돈까스,우동',
#   '일본식라면',
#   '초밥,롤',
#   '일식',
#   '애견카페',
#   '술집',
#   '육류,고기',
#   '카페',
#   '테마카페',
#   '육류,고기',
#   '이탈리안',
#   '호프,요리주점',
#   '고기뷔페',
#   '떡볶이',
#   '닭요리',
#   '해물,생선',
#   '디저트카페',
#   '일본식라면',
#   '양식',
#   '삼겹살',
#   '호프,요리주점',
#   '간식',
#   '실내포장마차',
#   '곰탕',
#   '호프,요리주점',
#   '테마카페',
#   '테마카페',
#   '피자',
#   '칵테일바',
#   '호프,요리주점',
#   '피자',
#   '인도음식',
#   '테마카페',
#   '애견카페',
#   '설렁탕',
#   '호프,요리주점',
#   '이탈리안',
#   '닭요리',
#   '이탈리안',
#   '디저트카페',
#   '커피전문점',
#   '양식',
#   '멕시칸,브라질',
#   '양꼬치',
#   '돈까스,우동',
#   '분식',
#   '한식',
#   '일본식주점',
#   '중국요리',
#   '칵테일바',
#   '카페',
#   '햄버거',
#   '갈비',
#   '곱창,막창',
#   '게,대게',
#   '카페',
#   '닭요리',
#   '중국요리',
#   '일식',
#   '호프,요리주점',
#   '참치회',
#   '커피전문점',
#   '육류,고기',
#   '와인바',
#   '떡카페',
#   '제과,베이커리',
#   '실내포장마차',
#   '테마카페',
#   '호프,요리주점',
#   '테마카페',
#   '초밥,롤',
#   '햄버거',
#   '일식',
#   '실내포장마차',
#   '카페',
#   '족발,보쌈',
#   '중식',
#   '테마카페',
#   '디저트카페',
#   '일본식주점',
#   '중국요리',
#   '카페',
#   '육류,고기',
#   '호프,요리주점',
#   '일식',
#   '스시오',
#   '일식집',
#   '돈까스,우동',
#   '북카페',
#   '닭요리',
#   '곱창,막창',
#   '칵테일바',
#   '칵테일바',
#   '카페',
#   '피자',
#   '일본식주점',
#   '일식',
#   '커피전문점',
#   '카페',
#   '카페',
#   '스타벅스',
#   '일식집',
#   '일본식주점',
#   '인도음식',
#   '커피전문점',
#   '호프,요리주점',
#   '샤브샤브',
#   '닭요리',
#   '곱창,막창',
#   '닭요리',
#   '테마카페',
#   '이탈리안',
#   '제과,베이커리',
#   '디저트카페',
#   '불고기,두루치기',
#   '카페',
#   '닭요리',
#   '호프,요리주점',
#   '떡볶이',
#   '실내포장마차',
#   '회',
#   '일본식주점',
#   '카페',
#   '카페',
#   '디저트카페',
#   '일본식주점'],
#  'star': ['3.8',
#   '4.1',
#   '4.2',
#   '3.4',
#   '4.3',
#   '3.5',
#   '3.6',
#   '3.8',
#   '4.7',
#   '4.4',
#   '0',
#   '4.2',
#   '3.9',
#   '3.0',
#   '4.5',
#   '4.4',
#   '3.6',
#   '3.5',
#   '4.4',
#   '4.1',
#   '4.2',
#   '4.1',
#   '3.8',
#   '4.2',
#   '4.4',
#   '0',
#   '0',
#   '2.3',
#   '4.0',
#   '3.2',
#   '3.3',
#   '4.0',
#   '4.7',
#   '0',
#   '4.7',
#   '0',
#   '2.8',
#   '2.5',
#   '4.0',
#   '0',
#   '4.4',
#   '3.9',
#   '0',
#   '4.5',
#   '4.1',
#   '4.3',
#   '4.0',
#   '3.0',
#   '4.2',
#   '2.2',
#   '3.7',
#   '4.3',
#   '3.8',
#   '3.1',
#   '3.7',
#   '3.6',
#   '4.0',
#   '3.4',
#   '3.7',
#   '4.4',
#   '3.5',
#   '0',
#   '2.7',
#   '3.9',
#   '3.2',
#   '4.4',
#   '3.6',
#   '4.1',
#   '4.7',
#   '0',
#   '0',
#   '4.0',
#   '3.4',
#   '3.4',
#   '3.4',
#   '4.0',
#   '2.9',
#   '3.6',
#   '4.0',
#   '5.0',
#   '4.4',
#   '3.8',
#   '3.0',
#   '3.9',
#   '4.1',
#   '0',
#   '3.4',
#   '4.4',
#   '0',
#   '4.5',
#   '2.8',
#   '0',
#   '2.6',
#   '3.8',
#   '3.8',
#   '3.7',
#   '3.8',
#   '4.0',
#   '3.8',
#   '3.1',
#   '3.5',
#   '3.3',
#   '4.3',
#   '3.2',
#   '4.2',
#   '4.4',
#   '0',
#   '4.7',
#   '4.1',
#   '4.7',
#   '4.1',
#   '4.5',
#   '3.9',
#   '3.7',
#   '3.7',
#   '0',
#   '2.6',
#   '3.2',
#   '0',
#   '3.9',
#   '3.3',
#   '3.4',
#   '3.9',
#   '2.1',
#   '4.1',
#   '2.7',
#   '3.8',
#   '3.3',
#   '2.8',
#   '3.9',
#   '4.1',
#   '0',
#   '0',
#   '3.5',
#   '1.6',
#   '4.1',
#   '0',
#   '4.5',
#   '3.7',
#   '4.3',
#   '3.8',
#   '3.8',
#   '3.2',
#   '4.2',
#   '4.1',
#   '4.7',
#   '4.7',
#   '4.1',
#   '4.5',
#   '4.1',
#   '4.5',
#   '4.1',
#   '4.0',
#   '3.6',
#   '5.0',
#   '4.6',
#   '3.5',
#   '3.7',
#   '2.8',
#   '3.6',
#   '4.0',
#   '4.7',
#   '0',
#   '4.5',
#   '3.8',
#   '4.2',
#   '4.4',
#   '2.9',
#   '3.4',
#   '4.8',
#   '4.6',
#   '0',
#   '3.8',
#   '3.4',
#   '4.0',
#   '3.0',
#   '3.9',
#   '3.9',
#   '0',
#   '4.1',
#   '4.4',
#   '3.4',
#   '2.7',
#   '0',
#   '2.1',
#   '3.8',
#   '3.4',
#   '3.5',
#   '4.8',
#   '3.9',
#   '4.6',
#   '4.9',
#   '3.4',
#   '0',
#   '4.4',
#   '0',
#   '4.3',
#   '3.3',
#   '4.1',
#   '4.4',
#   '0',
#   '4.0',
#   '4.5',
#   '4.4',
#   '2.5',
#   '4.6',
#   '3.3',
#   '4.6',
#   '3.8',
#   '2.7',
#   '4.1',
#   '4.3',
#   '4.2',
#   '3.4',
#   '3.8',
#   '3.7',
#   '3.1',
#   '3.9',
#   '4.6',
#   '3.9',
#   '4.2',
#   '3.3',
#   '2.9',
#   '3.5',
#   '0'],
#  'address': ['서울마포구 독막로7길51 1층(우)04043',
#   '서울마포구 양화로16길24 지하1층,1~4층(우)04039',
#   '서울마포구 와우산로21길28-6 지하1층(우)04040',
#   '서울마포구 와우산로21길21-16 2층202호(우)04041',
#   '서울마포구 와우산로51-6 1층(우)04049',
#   '서울마포구 와우산로21길20-11 2층(우)04040',
#   '서울마포구 독막로68 2층(우)04074',
#   '서울마포구 잔다리로6길25 1,2층(우)04039',
#   '서울마포구 홍익로3길44 지하1층(우)04039',
#   '서울마포구 와우산로23길18-7 1층(우)04054',
#   '서울마포구 와우산로21길28-12 (우)04040',
#   '서울마포구 홍익로10 푸르지오상가지하1층121호(우)04055',
#   '서울마포구 와우산로23길44 2,3층(우)04055',
#   '서울마포구 독막로19길43 1층(우)04068',
#   '서울마포구 와우산로23길9 칼리오페1층102호(우)04055',
#   '서울마포구 홍익로2길23 1층2호(우)04055',
#   '서울마포구 독막로67-11 행운빌딩1층(우)04049',
#   '서울마포구 월드컵북로1길60 1층(우)04031',
#   '서울마포구 어울마당로46 1층(우)04049',
#   '서울마포구 와우산로19길9 (우)04041',
#   '서울마포구 양화로176 와이즈파크5층(우)04051',
#   '서울마포구 와우산로21길36-10 1,2층(우)04040',
#   '서울마포구 어울마당로45 1,2층(우)04048',
#   '서울마포구 독막로4길3 1~3층(우)04072',
#   '서울마포구 독막로6길14 (우)04072',
#   '서울마포구 와우산로17길10 2층(우)04049',
#   '서울마포구 어울마당로47 1층(우)04048',
#   '서울마포구 독막로7길22 (우)04048',
#   '서울마포구 와우산로15길40 2층(우)04049',
#   '서울마포구 와우산로29길44 2층201호(우)04052',
#   '서울마포구 어울마당로44-1 보리수빌딩1층(우)04049',
#   '서울마포구 와우산로29길8 KC빌딩1층(우)04052',
#   '서울마포구 와우산로23 규민빌딩1층102호(우)04074',
#   '서울마포구 와우산로23길18-7 2층202호(우)04054',
#   '서울마포구 어울마당로149 1층(우)04051',
#   '서울마포구 어울마당로111-1 1층(우)04050',
#   '서울마포구 와우산로70 (우)04067',
#   '서울마포구 와우산로21길20 2층(우)04040',
#   '서울마포구 와우산로29가길79 (우)04054',
#   '서울마포구 어울마당로112-6 1층(우)04055',
#   '서울마포구 와우산로15길49 1층(우)04049',
#   '서울마포구 와우산로29라길7 (우)04053',
#   '서울마포구 와우산로51-9 1,2층(우)04049',
#   '서울마포구 독막로9길8 2층(우)04048',
#   '서울마포구 양화로6길73 4층(우)04047',
#   '서울마포구 잔다리로3안길44 (우)04043',
#   '서울마포구 와우산로130 1층(우)04059',
#   '서울마포구 와우산로21길36-6 102호(우)04040',
#   '서울마포구 와우산로11길9 1층101호(우)04049',
#   '서울마포구 잔다리로23 1층(우)04043',
#   '서울마포구 서강로9길60 (우)04061',
#   '서울마포구 홍익로7 소망빌딩지하1층(우)04040',
#   '서울마포구 홍익로5안길24 (우)04039',
#   '서울마포구 잔다리로5-1 (우)04049',
#   '서울마포구 홍익로5안길32 홍대가자2빌딩103호(우)04039',
#   '서울마포구 와우산로11길10 (우)04049',
#   '서울마포구 독막로15길3-14 1층(우)04049',
#   '서울마포구 와우산로17길19 (우)04049',
#   '서울마포구 양화로118 (우)04038',
#   '서울마포구 와우산로18길12 (우)04067',
#   '서울마포구 양화로6길33 홍타운1층(우)04044',
#   '서울마포구 와우산로29라길26 (우)04053',
#   '서울마포구 홍익로6길38 1층(우)04050',
#   '서울마포구 와우산로19길18 가동1,2층(우)04041',
#   '서울마포구 동교로143 1,2층(우)04002',
#   '서울마포구 와우산로24 (우)04075',
#   '서울마포구 와우산로29길14-8 2층(우)04052',
#   '서울마포구 와우산로17길11-8 1,2,3층(우)04049',
#   '서울마포구 잔다리로9 1층(우)04049',
#   '서울마포구 독막로9길31 스페이스1층(우)04048',
#   '서울마포구 홍익로3길36 3,4층(우)04039',
#   '서울마포구 와우산로21길28-6 1층(우)04040',
#   '서울마포구 와우산로32길24 (우)04061',
#   '서울마포구 토정로128 8층(우)04081',
#   '서울마포구 와우산로17길11 코스모스빌딩3층(우)04049',
#   '서울마포구 홍익로29 1층(우)04038',
#   '서울마포구 와우산로17길19 (우)04049',
#   '서울마포구 토정로5길10 (우)04073',
#   '서울마포구 와우산로39-14 (우)04049',
#   '서울마포구 양화로6길99-3 (우)04048',
#   '서울마포구 와우산로21길19-8 태경빌딩2층(우)04041',
#   '서울마포구 동교로156-11 1층(우)04031',
#   '서울마포구 와우산로21길24 2층(우)04040',
#   '서울마포구 어울마당로133 (우)04050',
#   '서울마포구 독막로9길6 2층(우)04048',
#   '서울마포구 와우산로27길14 104호(우)04053',
#   '서울마포구 잔다리로6길34-9 (우)04042',
#   '서울마포구 독막로61-4 (우)04049',
#   '서울마포구 와우산로14길12 1층(우)04067',
#   '서울마포구 어울마당로122-1 1층(우)04055',
#   '서울마포구 어울마당로131 (우)04050',
#   '서울마포구 독막로3길38 1층(우)04047',
#   '서울마포구 동교로173 (우)03992',
#   '서울마포구 독막로9길43 (우)04048',
#   '서울마포구 어울마당로5길29 1층(우)04047',
#   '서울마포구 잔다리로6길28 (우)04042',
#   '서울마포구 월드컵북로5 (우)04031',
#   '서울마포구 양화로16길30-5 3층(우)04039',
#   '서울마포구 와우산로13길49-7 (우)04049',
#   '서울마포구 양화로7안길2-1 1,2층(우)04037',
#   '서울마포구 독막로14길31 1층(우)04074',
#   '서울마포구 와우산로15길34 (우)04049',
#   '서울마포구 와우산로29길27 (우)04053',
#   '서울마포구 와우산로17길19-5 1층(우)04049',
#   '서울마포구 독막로81 1층(우)04049',
#   '서울마포구 양화로16길33 1층(우)04039',
#   '서울마포구 와우산로29가길13 1층(우)04053',
#   '서울마포구 와우산로65 6층(우)04049',
#   '서울마포구 홍익로6길52 SIL빌딩3층(우)04050',
#   '서울마포구 독막로19길20-6 1층(우)04067',
#   '서울마포구 와우산로17길19-17 2층(우)04049',
#   '서울마포구 독막로7길20 2층(우)04048',
#   '서울마포구 독막로3길34 2층201호(우)04047',
#   '서울마포구 와우산로29라길20 2층(우)04053',
#   '서울마포구 어울마당로146 1층(우)04053',
#   '서울마포구 와우산로29길47 1,2층(우)04053',
#   '서울마포구 와우산로35길75 1층(우)04052',
#   '서울마포구 토정로136-13 우성빌딩7층(우)04081',
#   '서울마포구 홍익로5안길28 (우)04039',
#   '서울마포구 와우산로30길80 (우)04059',
#   '서울마포구 홍익로3길29 1층(우)04039',
#   '서울마포구 와우산로17길5 밤사빌딩1,2층(우)04049',
#   '서울마포구 양화로7길44-10 1층(우)04035',
#   '서울마포구 와우산로21길12-6 1층(우)04040',
#   '서울마포구 잔다리로30-11 1층(우)04042',
#   '서울마포구 와우산로27길21 4층(우)04054',
#   '서울마포구 독막로7길51 3,4층(우)04043',
#   '서울마포구 와우산로19길6-11 (우)04041',
#   '서울마포구 와우산로21길19-12 1층(우)04041',
#   '서울마포구 와우산로73 (우)04041',
#   '서울마포구 와우산로18길20 (우)04067',
#   '서울마포구 와우산로21길20-5 홍대프라자3층(우)04040',
#   '서울마포구 어울마당로44-1 라꼼마빌딩2층(우)04049',
#   '서울마포구 월드컵북로6 (우)03995',
#   '서울마포구 양화로16길34 2,3층(우)04039',
#   '서울마포구 양화로6길28 2층(우)04046',
#   '서울마포구 와우산로107 1층(우)04054',
#   '서울마포구 성지3길67 1층(우)04072',
#   '서울마포구 잔다리로6길28 (우)04042',
#   '서울마포구 동교로25길7 1층(우)03992',
#   '서울마포구 와우산로15길15 지하1층(우)04049',
#   '서울마포구 와우산로41 (우)04049',
#   '서울마포구 와우산로66 (우)04067',
#   '서울마포구 동교로126 광남벨라스아파트1층102호(우)04030',
#   '서울마포구 독막로71 1층(우)04049',
#   '서울마포구 와우산로15길30 지1층(우)04049',
#   '서울마포구 독막로9길26 야키토리나루토(우)04048',
#   '서울마포구 와우산로23길50 지하1층(우)04055',
#   '서울마포구 와우산로63 2층(우)04049',
#   '서울마포구 와우산로147-1 (우)04053',
#   '서울마포구 와우산로23길9 칼리오페1층105호(우)04055',
#   '서울마포구 독막로77 1층(우)04049',
#   '서울마포구 양화로6길77 1층(우)04047',
#   '서울마포구 양화로100 3층(우)04038',
#   '서울마포구 독막로73-1 2층(우)04049',
#   '서울마포구 와우산로29마길16 1층(우)04053',
#   '서울마포구 양화로18길15 (우)04051',
#   '서울마포구 어울마당로51 2층(우)04048',
#   '서울마포구 와우산로18길16 1층(우)04067',
#   '서울마포구 와우산로23길35-3 2층(우)04055',
#   '서울마포구 연희로11 한국특허정보원빌딩1층(우)03985',
#   '서울마포구 와우산로13길49-3 1층(우)04049',
#   '서울마포구 독막로9길38 DE빌딩6층(우)04048',
#   '서울마포구 어울마당로1길18 1층(우)04073',
#   '서울마포구 와우산로15길22 (우)04049',
#   '서울마포구 독막로9길9 1층(우)04048',
#   '서울마포구 와우산로102 3층(우)04059',
#   '서울마포구 와우산로21길19-8 1층(우)04041',
#   '서울마포구 독막로3길30 지하2층(우)04047',
#   '서울마포구 월드컵북로1길20 1층(우)04031',
#   '서울마포구 와우산로21길20-10 1층(우)04040',
#   '서울마포구 와우산로3길16 석진스토리1층102호(우)04074',
#   '서울마포구 잔다리로6길34-13 1,2층(우)04042',
#   '서울마포구 독막로7길57 (우)04043',
#   '서울마포구 와우산로29길48-6 (우)04052',
#   '서울마포구 양화로144 MERCURE앰배서더HOTEL홍대4층(우)04050',
#   '서울마포구 잔다리로6길40-6 3층(우)04042',
#   '서울마포구 어울마당로39 1층(우)04048',
#   '서울마포구 어울마당로71 (우)04042',
#   '서울마포구 동교로220-7 1층(우)03994',
#   '서울마포구 어울마당로5길18 1층(우)04048',
#   '서울마포구 양화로6길102 1층(우)04048',
#   '서울마포구 어울마당로129-1 (우)04050',
#   '서울마포구 독막로3길21 101호(우)04044',
#   '서울마포구 어울마당로100-6 1층(우)04040',
#   '서울마포구 와우산로15길49 1층(우)04049',
#   '서울마포구 양화로6길103 2층(우)04048',
#   '서울마포구 동교로194 혜원빌딩1층(우)03995',
#   '서울마포구 와우산로21길31-10 1층(우)04041',
#   '서울마포구 와우산로23길35-8 1층(우)04055',
#   '서울마포구 와우산로29길69 지하1층(우)04053',
#   '서울마포구 독막로15길13 지하1층(우)04049',
#   '서울마포구 월드컵북로4길29 1층(우)03992',
#   '서울마포구 와우산로29마길24-1 지하1층(우)04053',
#   '서울마포구 와우산로38길4 (우)04057',
#   '서울마포구 와우산로29라길16 (우)04053',
#   '서울마포구 어울마당로1길16 1층(우)04073',
#   '서울마포구 양화로6길35 (우)04044',
#   '서울마포구 와우산로29마길5 1층(우)04053',
#   '서울마포구 와우산로64 (우)04067',
#   '서울마포구 월드컵북로14 (우)03992',
#   '서울마포구 월드컵북로2길86 1층(우)03994',
#   '서울마포구 양화로16길10 2층(우)04038',
#   '서울마포구 와우산로29길14 (우)04052',
#   '서울마포구합정동 410-31 ',
#   '서울마포구 와우산로94 홍문관16층(우)04066',
#   '서울마포구 와우산로19길26 2층(우)04041',
#   '서울마포구 양화로6길57-5 (우)04047',
#   '서울마포구 양화로122 (우)04038',
#   '서울마포구 양화로16길15 무광빌딩4층(우)04039',
#   '서울마포구 독막로15길3-18 (우)04049',
#   '서울마포구 와우산로25길11 (우)04054',
#   '서울마포구 와우산로29바길24 2층(우)04053',
#   '서울마포구 창전로45 서강한화오벨리스크스아파트103동1층101호(우)04086',
#   '서울마포구 토정로5길12 (우)04073',
#   '서울마포구 와우산로18길29 지하1층(우)04067',
#   '서울마포구 와우산로19길6 (우)04041',
#   '서울마포구 양화로19길22-25 2층(우)03994',
#   '서울마포구 독막로76-1 한주빌딩1층102호(우)04074',
#   '서울마포구 와우산로156 2층(우)04061',
#   '서울마포구 와우산로29바길6 지층(우)04053',
#   '서울마포구 와우산로35길75 2,3층(우)04052',
#   '서울마포구 잔다리로19-6 2층(우)04048',
#   '서울마포구 와우산로59 (우)04049',
#   '서울마포구 어울마당로75 2,3층(우)04042'],
#  'oper_time': ['매일 12:00 ~ 21:00\n\n매일 라스트오더 ~ 20:30',
#   '월~목 11:30 ~ 21:30\n\n금~일 10:00 ~ 21:30',
#   '매일 11:00 ~ 21:30\n\n매일 라스트오더 ~ 21:00',
#   '매일 12:00 ~ 22:00월~금 휴게시간 14:30 ~ 17:00',
#   '매일 10:30 ~ 21:30\n\n월~토 휴게시간 16:00 ~ 17:00\n\n일 휴게시간 15:30 ~ 17:00',
#   '월~금 11:30 ~ 22:00\n\n토,일 12:00 ~ 22:00\n\n월~금 휴게시간 16:00 ~ 17:00',
#   '매일 11:30 ~ 22:00월~금 휴게시간 16:00 ~ 17:00',
#   '매일 11:00 ~ 22:00',
#   '월,화,수,목,일 17:30 ~ 03:00\n\n금,토 17:30 ~ 04:00',
#   '매일 11:30 ~ 21:00월~금 휴게시간 15:10 ~ 17:00',
#   '화~일 11:30 ~ 20:00\n\n화~금 휴게시간 15:00 ~ 16:00',
#   '매일 12:00 ~ 21:00',
#   '매일 11:00 ~ 23:00\n\n매일 라스트오더 ~ 22:00',
#   '매일 11:30 ~ 03:00',
#   '매일 11:30 ~ 21:30',
#   '화~일 11:30 ~ 20:30\n\n화~일 라스트오더 ~ 20:00\n\n화~일 휴게시간 15:00 ~ 17:00',
#   '화~일 11:30 ~ 22:00\n\n화~일 휴게시간 15:00 ~ 16:30',
#   '매일 11:30 ~ 21:30매일 휴게시간 15:00 ~ 17:00',
#   '매일 11:30 ~ 20:30매일 휴게시간 14:30 ~ 17:00',
#   '매일 11:00 ~ 22:00',
#   '매일 10:00 ~ 03:00',
#   '매일 12:00 ~ 21:30\n(매장 상황에 따라 상이하게 변동이 있을 수 있는 점 양해 부탁드립니다.)\n\n매일 라스트오더 ~ 20:30',
#   '매일 10:30 ~ 23:00',
#   '매일 10:00 ~ 22:00',
#   '매일 11:00 ~ 21:00',
#   '매일 16:00 ~ 02:00',
#   '매일 00:00 ~ 24:00',
#   '월~금 17:00 ~ 02:00\n\n토,일 17:00 ~ 03:00',
#   '매일 12:00 ~ 22:00\n\n매일 휴게시간 15:00 ~ 17:00',
#   '매일 12:00 ~ 20:40\n\n매일 라스트오더 ~ 20:00\n\n월~토 휴게시간 14:50 ~ 17:00',
#   '매일 00:00 ~ 24:00',
#   '매일 09:00 ~ 21:00',
#   '화~일 15:00 ~ 22:00',
#   '매일 11:30 ~ 21:00',
#   '월,화,수,목,일 17:00 ~ 23:00\n\n금,토 15:00 ~ 24:00',
#   '매일 11:30 ~ 24:00',
#   '0',
#   '매일 13:30 ~ 20:00',
#   '매일 11:00 ~ 21:30매일 휴게시간 15:00 ~ 17:00',
#   '화~토 11:30 ~ 22:30\n\n일 11:30 ~ 22:00\n\n화~일 휴게시간 15:00 ~ 16:30',
#   '매일 11:30 ~ 22:00매일 휴게시간 15:00 ~ 17:00',
#   '화~금 11:30 ~ 22:00\n\n토,일 12:00 ~ 21:00\n\n화~금 휴게시간 15:00 ~ 17:00',
#   '매일 15:00 ~ 03:00\n\n매일 라스트오더 ~ 02:00\n(주방 마감)',
#   '매일 11:00 ~ 22:10',
#   '매일 12:00 ~ 24:00',
#   '월~토 17:00 ~ 23:00\n\n일 17:00 ~ 22:00\n\n월~토 라스트오더 ~ 22:00\n\n일 라스트오더 ~ 21:00',
#   '월,화,목,금,토,일 10:00 ~ 15:00',
#   '매일 11:00 ~ 22:00',
#   '월~금 11:00 ~ 22:00\n\n토,일 12:00 ~ 22:00',
#   '월,화,수,목,일 16:00 ~ 02:00\n\n금,토 16:00 ~ 04:00',
#   '화~목 17:00 ~ 24:00\n\n금,토 17:00 ~ 01:00\n\n일 16:00 ~ 24:00',
#   '매일 11:30 ~ 22:00매일 휴게시간 14:30 ~ 17:00',
#   '매일 11:50 ~ 21:00',
#   '매일 18:00 ~ 10:00',
#   '매일 11:30 ~ 22:00',
#   '화~일 11:50 ~ 22:00',
#   '매일 11:30 ~ 22:00\n\n매일 휴게시간 15:00 ~ 17:00',
#   '매일 16:00 ~ 02:00\n\n매일 라스트오더 ~ 01:00',
#   '매일 09:30 ~ 22:30',
#   '0',
#   '매일 11:00 ~ 23:00',
#   '매일 11:00 ~ 17:00',
#   '매일 11:00 ~ 06:00',
#   '매일 12:00 ~ 21:00(에약제)',
#   '월~토 14:30 ~ 01:00\n\n일 14:30 ~ 23:00',
#   '매일 11:00 ~ 02:00',
#   '월~토 11:30 ~ 21:30',
#   '매일 11:00 ~ 23:00',
#   '월,화,수,목,일 17:00 ~ 05:00\n\n금,토 16:30 ~ 09:00',
#   '화~일 12:00 ~ 21:00',
#   '매일 12:00 ~ 23:00',
#   '매일 11:00 ~ 24:00',
#   '매일 12:00 ~ 23:00\n\n매일 라스트오더 ~ 22:30',
#   '매일 12:00 ~ 24:00매일 휴게시간 15:00 ~ 17:30',
#   '매일 11:00 ~ 24:00',
#   '매일 11:00 ~ 23:00',
#   '월~금 17:00 ~ 05:00\n\n토,일 17:00 ~ 06:00',
#   '매일 09:00 ~ 22:00',
#   '화~토 17:00 ~ 02:00\n\n일 15:00 ~ 23:40',
#   '매일 16:00 ~ 02:00',
#   '0',
#   '매일 11:00 ~ 20:30매일 휴게시간 15:20 ~ 17:00',
#   '0',
#   '매일 11:00 ~ 02:00',
#   '월,화,수,목,일 12:00 ~ 21:30\n\n금,토 12:00 ~ 22:00\n\n월,화,수,목,일 라스트오더 ~ 20:30\n\n금,토 라스트오더 ~ 21:00\n\n매일 휴게시간 15:00 ~ 16:00',
#   '월,화,목,금,토,일 11:30 ~ 21:40\n\n월,화,목,금,토,일 라스트오더 ~ 21:00\n\n월,화,목,금 휴게시간 15:30 ~ 16:00',
#   '월~금 13:00 ~ 23:00\n\n토,일 12:00 ~ 23:00\n\n월~금 휴게시간 15:00 ~ 17:00\n\n토,일 휴게시간 15:00 ~ 16:00',
#   '화~목 11:00 ~ 21:50\n\n금~일 11:00 ~ 22:20',
#   '수~금 11:30 ~ 22:00\n\n토,일 11:00 ~ 22:00\n\n수~금 휴게시간 15:30 ~ 17:30\n\n토,일 휴게시간 16:00 ~ 17:30',
#   '월~금 12:00 ~ 22:00\n\n토,일 12:00 ~ 23:00',
#   '매일 00:00 ~ 24:00',
#   '매일 17:00 ~ 02:00',
#   '매일 15:00 ~ 06:00',
#   '월~목 17:00 ~ 24:00\n\n금 17:00 ~ 02:30\n\n토 17:00 ~ 03:30\n\n일 17:00 ~ 23:55\n\n월~목 라스트오더 ~ 23:30\n\n금 라스트오더 ~ 02:00\n\n토 라스트오더 ~ 03:00\n\n일 라스트오더 ~ 23:25',
#   '수~금 17:30 ~ 23:00\n\n토,일 12:00 ~ 22:00\n\n토,일 휴게시간 15:30 ~ 17:00',
#   '월~금 16:00 ~ 22:00\n\n토,일 13:00 ~ 22:00',
#   '월~토 11:00 ~ 24:00',
#   '매일 11:00 ~ 20:00(휴무 및 영업시간 변경 인스타공지)',
#   '매일 11:30 ~ 23:00매일 휴게시간 15:30 ~ 17:30',
#   '월~금 11:30 ~ 21:00\n\n토 11:30 ~ 20:30\n\n월~금 휴게시간 14:40 ~ 17:30',
#   '매일 11:00 ~ 21:30',
#   '매일 12:00 ~ 23:00',
#   '매일 11:30 ~ 21:00',
#   '월,수,목,금,토,일 13:00 ~ 21:00\n\n월,수,목,금,토,일 휴게시간 19:30 ~ 19:50\n\n월,수,목,금,토,일 휴게시간 17:20 ~ 17:40\n\n월,수,목,금,토,일 휴게시간 14:50 ~ 15:10',
#   '매일 17:00 ~ 05:00',
#   '화~목 17:00 ~ 01:00\n\n금,토 16:00 ~ 03:00\n\n일 16:00 ~ 01:00',
#   '매일 12:00 ~ 20:00',
#   '매일 12:00 ~ 24:00',
#   '매일 12:00 ~ 23:00',
#   '월~토 11:30 ~ 22:00\n\n월~토 휴게시간 15:00 ~ 17:30',
#   '매일 11:30 ~ 21:30매일 휴게시간 15:30 ~ 17:00',
#   '매일 12:00 ~ 02:00',
#   '화~일 11:30 ~ 21:00\n\n화~일 라스트오더 ~ 20:00',
#   '월,수,목,금,토 11:30 ~ 21:00\n\n일 11:30 ~ 20:30\n\n월,수,목,금,토 휴게시간 15:30 ~ 17:00\n\n일 휴게시간 15:00 ~ 17:00',
#   '매일 11:30 ~ 24:00',
#   '매일 11:00 ~ 20:50',
#   '매일 11:30 ~ 21:30',
#   '매일 11:00 ~ 01:00매일 휴게시간 16:00 ~ 17:00',
#   '매일 11:30 ~ 24:00',
#   '월~토 18:00 ~ 24:00',
#   '매일 11:00 ~ 24:00',
#   '월,화,수,목,일 17:00 ~ 05:00\n\n금,토 17:00 ~ 06:00',
#   '매일 11:00 ~ 22:30\n(재료소진시 조기마감)\n\n월~금 휴게시간 15:00 ~ 17:00\n(토,일 브레이크타임 없음)',
#   '매일 16:00 ~ 03:00',
#   '월,화,수,목,일 12:00 ~ 21:00\n\n금,토 12:00 ~ 22:00',
#   '매일 11:00 ~ 23:00',
#   '매일 11:00 ~ 23:00',
#   '월,화,수,목,일 17:00 ~ 02:00\n\n금,토 17:00 ~ 04:00',
#   '월,화,수,목,일 19:00 ~ 04:00\n\n금,토 19:00 ~ 05:00',
#   '매일 17:00 ~ 05:00',
#   '매일 10:00 ~ 02:00',
#   '매일 11:00 ~ 22:00',
#   '매일 12:30 ~ 21:00',
#   '매일 07:00 ~ 22:00\n\n매일 휴게시간 15:00 ~ 17:00',
#   '매일 00:00 ~ 24:00',
#   '수~일 11:30 ~ 21:30\n\n수~일 휴게시간 15:00 ~ 17:00',
#   '월,수,목,금,토,일 17:00 ~ 01:30',
#   '매일 11:30 ~ 21:30\n\n매일 휴게시간 15:30 ~ 17:30',
#   '매일 11:30 ~ 21:30',
#   '수~일 12:00 ~ 21:00',
#   '수~일 11:30 ~ 21:00\n\n수~일 휴게시간 15:00 ~ 16:00',
#   '화~토 11:30 ~ 22:00\n\n일 11:30 ~ 20:30',
#   '월~금 17:00 ~ 05:00\n\n토,일 17:00 ~ 06:00',
#   '월~토 11:30 ~ 20:00\n\n월~토 휴게시간 15:00 ~ 17:00',
#   '매일 11:30 ~ 23:00',
#   '월,화,수,목,금,일 11:00 ~ 22:00\n\n월,화,수,목,금,일 라스트오더 ~ 21:00',
#   '월~금 16:00 ~ 23:00\n\n토,일 15:00 ~ 23:00',
#   '매일 11:30 ~ 22:30',
#   '매일 19:30 ~ 23:00',
#   '매일 00:00 ~ 24:00',
#   '매일 10:30 ~ 21:00',
#   '월,화,금,토,일 11:30 ~ 01:00\n\n수,목 11:30 ~ 23:00',
#   '매일 17:00 ~ 02:00\n\n매일 라스트오더 ~ 00:30',
#   '매일 11:30 ~ 22:00',
#   '화~토 11:00 ~ 24:00\n\n일 11:00 ~ 23:00',
#   '매일 11:30 ~ 22:00\n\n월~금 휴게시간 15:00 ~ 16:00\n\n토,일 휴게시간 16:00 ~ 17:00',
#   '월,수,목,금,토,일 11:00 ~ 22:00\n\n월,수,목,금,토,일 라스트오더 ~ 21:30',
#   '매일 11:00 ~ 22:00',
#   '매일 17:00 ~ 05:00',
#   '매일 15:30 ~ 24:00',
#   '매일 10:00 ~ 22:00',
#   '매일 14:00 ~ 24:00',
#   '월~금 17:00 ~ 01:30\n\n토,일 17:00 ~ 03:00',
#   '월~토 11:00 ~ 21:00',
#   '매일 09:30 ~ 22:00',
#   '매일 17:00 ~ 05:00',
#   '월~금 12:50 ~ 23:00\n\n토,일 10:30 ~ 23:00',
#   '월~목 16:00 ~ 24:00\n\n금,토 16:00 ~ 03:00\n\n일 13:00 ~ 24:00',
#   '매일 12:00 ~ 24:00',
#   '매일 11:30 ~ 22:00매일 휴게시간 15:00 ~ 16:30',
#   '매일 11:30 ~ 21:30\n\n매일 휴게시간 15:00 ~ 16:00',
#   '월~목 17:00 ~ 24:00\n\n금 17:00 ~ 01:00\n\n토 13:00 ~ 01:00\n\n일 13:00 ~ 24:00',
#   '매일 17:00 ~ 02:30',
#   '월~토 11:00 ~ 23:00\n\n일 11:00 ~ 22:00\n\n월~토 라스트오더 ~ 22:30\n\n일 라스트오더 ~ 21:30',
#   '월,수,목,금,토,일 14:30 ~ 24:00',
#   '매일 11:00 ~ 21:00\n\n매일 휴게시간 15:00 ~ 17:00',
#   '매일 11:00 ~ 21:00',
#   '매일 12:00 ~ 22:00',
#   '매일 00:00 ~ 24:00',
#   '매일 11:30 ~ 22:00\n\n매일 라스트오더 ~ 21:00\n\n매일 휴게시간 15:30 ~ 17:00',
#   '매일 13:00 ~ 22:00',
#   '월,화,수,목,일 16:00 ~ 04:00\n\n금,토 16:00 ~ 05:00',
#   '월~금 16:00 ~ 03:00\n\n토,일 16:00 ~ 04:00',
#   '매일 13:00 ~ 24:00',
#   '매일 11:00 ~ 22:00',
#   '월~토 11:10 ~ 20:40\n\n일 11:00 ~ 20:40\n\n월~토 휴게시간 15:40 ~ 17:00',
#   '매일 11:30 ~ 21:00',
#   '매일 10:00 ~ 23:00\n\n매일 라스트오더 ~ 22:30',
#   '매일 11:00 ~ 23:00',
#   '매일 13:30 ~ 01:00',
#   '매일 17:00 ~ 02:00',
#   '매일 19:00 ~ 03:00',
#   '매일 10:00 ~ 22:00',
#   '월~금 15:00 ~ 23:00\n\n토 13:00 ~ 23:00\n\n일 13:00 ~ 22:00',
#   '월,화,수,목,일 16:00 ~ 02:00\n\n금,토 16:00 ~ 04:00',
#   '월~금 11:30 ~ 17:30\n\n토,일 11:30 ~ 21:00\n\n토,일 휴게시간 16:00 ~ 17:00',
#   '월~금 09:00 ~ 22:00\n\n토,일 10:00 ~ 22:00',
#   '매일 10:00 ~ 24:00',
#   '매일 12:00 ~ 20:00',
#   '월,화,수,일 08:30 ~ 21:00\n\n목~토 08:30 ~ 22:00',
#   '매일 11:30 ~ 22:00\n\n월~금 휴게시간 15:00 ~ 17:00',
#   '월~토 16:00 ~ 23:40\n(재료소진시까지)',
#   '매일 11:00 ~ 22:30',
#   '월~토 08:00 ~ 23:00\n\n일 09:00 ~ 23:00',
#   '매일 15:00 ~ 04:00',
#   '매일 11:30 ~ 21:30\n\n매일 휴게시간 15:00 ~ 17:30',
#   '수~금 17:00 ~ 22:30\n\n토,일 13:00 ~ 22:30',
#   '화~금 17:00 ~ 01:00\n\n토,일 16:00 ~ 01:00',
#   '매일 11:00 ~ 23:30',
#   '월~목 12:00 ~ 23:20\n\n금 12:00 ~ 01:10\n\n토 11:00 ~ 01:10\n\n일 11:00 ~ 23:20',
#   '화~일 11:30 ~ 22:00',
#   '매일 10:30 ~ 21:00',
#   '매일 12:00 ~ 21:30',
#   '화~일 11:00 ~ 21:00\n\n화~일 휴게시간 13:30 ~ 16:30',
#   '매일 12:00 ~ 24:00',
#   '매일 11:00 ~ 23:00',
#   '매일 17:00 ~ 05:00',
#   '화~일 11:30 ~ 21:00\n\n화~일 라스트오더 ~ 20:00\n\n화~금 휴게시간 15:00 ~ 16:30',
#   '월~목 17:00 ~ 01:00\n\n금 17:00 ~ 02:00\n\n토 16:00 ~ 02:00\n\n일 16:00 ~ 24:00',
#   '월~토 17:00 ~ 22:00',
#   '화~일 17:00 ~ 02:00',
#   '월~금 10:00 ~ 23:00\n\n토,일 11:00 ~ 23:00',
#   '월~금 13:00 ~ 21:00\n\n토,일 12:00 ~ 21:00',
#   '매일 11:00 ~ 23:00',
#   '월,화,수,목,일 16:00 ~ 05:00\n\n금,토 16:00 ~ 06:50\n\n월,화,수,목,일 라스트오더 ~ 04:00\n\n금,토 라스트오더 ~ 05:50'],
#  'starCount': ['274',
#   '360',
#   '191',
#   '168',
#   '280',
#   '134',
#   '151',
#   '23',
#   '498',
#   '194',
#   '0',
#   '80',
#   '141',
#   '280',
#   '925',
#   '322',
#   '134',
#   '59',
#   '199',
#   '134',
#   '177',
#   '80',
#   '100',
#   '324',
#   '705',
#   '0',
#   '0',
#   '42',
#   '61',
#   '31',
#   '36',
#   '238',
#   '131',
#   '0',
#   '1635',
#   '0',
#   '28',
#   '59',
#   '308',
#   '0',
#   '125',
#   '178',
#   '0',
#   '111',
#   '305',
#   '92',
#   '219',
#   '103',
#   '75',
#   '36',
#   '102',
#   '41',
#   '124',
#   '10',
#   '48',
#   '84',
#   '59',
#   '39',
#   '46',
#   '20',
#   '94',
#   '0',
#   '88',
#   '64',
#   '156',
#   '97',
#   '63',
#   '68',
#   '240',
#   '0',
#   '0',
#   '37',
#   '54',
#   '33',
#   '11',
#   '132',
#   '25',
#   '179',
#   '25',
#   '1324',
#   '131',
#   '138',
#   '30',
#   '90',
#   '134',
#   '0',
#   '25',
#   '91',
#   '0',
#   '329',
#   '53',
#   '0',
#   '50',
#   '41',
#   '84',
#   '48',
#   '31',
#   '20',
#   '68',
#   '317',
#   '156',
#   '54',
#   '83',
#   '68',
#   '46',
#   '53',
#   '0',
#   '9',
#   '37',
#   '33',
#   '15',
#   '26',
#   '62',
#   '36',
#   '100',
#   '0',
#   '207',
#   '58',
#   '0',
#   '28',
#   '61',
#   '18',
#   '340',
#   '11',
#   '17',
#   '9',
#   '76',
#   '40',
#   '16',
#   '29',
#   '65',
#   '0',
#   '0',
#   '44',
#   '20',
#   '203',
#   '0',
#   '162',
#   '48',
#   '125',
#   '171',
#   '128',
#   '36',
#   '350',
#   '95',
#   '47',
#   '196',
#   '89',
#   '38',
#   '56',
#   '91',
#   '88',
#   '50',
#   '14',
#   '11',
#   '38',
#   '119',
#   '35',
#   '19',
#   '20',
#   '208',
#   '34',
#   '0',
#   '87',
#   '44',
#   '15',
#   '25',
#   '14',
#   '22',
#   '213',
#   '101',
#   '0',
#   '14',
#   '45',
#   '43',
#   '37',
#   '23',
#   '40',
#   '0',
#   '207',
#   '53',
#   '22',
#   '31',
#   '0',
#   '163',
#   '78',
#   '23',
#   '87',
#   '336',
#   '18',
#   '52',
#   '76',
#   '54',
#   '0',
#   '49',
#   '0',
#   '78',
#   '68',
#   '149',
#   '36',
#   '0',
#   '79',
#   '51',
#   '87',
#   '29',
#   '5',
#   '16',
#   '42',
#   '26',
#   '32',
#   '51',
#   '59',
#   '69',
#   '98',
#   '100',
#   '59',
#   '38',
#   '141',
#   '28',
#   '37',
#   '29',
#   '30',
#   '64',
#   '47',
#   '0'],
#  'reviewCount': ['642',
#   '191',
#   '426',
#   '624',
#   '439',
#   '804',
#   '178',
#   '30',
#   '118',
#   '120',
#   '272',
#   '48',
#   '239',
#   '387',
#   '260',
#   '360',
#   '278',
#   '116',
#   '91',
#   '136',
#   '681',
#   '192',
#   '382',
#   '1157',
#   '403',
#   '7',
#   '1638',
#   '197',
#   '821',
#   '567',
#   '74',
#   '454',
#   '123',
#   '301',
#   '313',
#   '922',
#   '2',
#   '2',
#   '50',
#   '217',
#   '171',
#   '307',
#   '156',
#   '52',
#   '1469',
#   '479',
#   '181',
#   '223',
#   '1438',
#   '453',
#   '45',
#   '310',
#   '203',
#   '211',
#   '12',
#   '96',
#   '121',
#   '150',
#   '70',
#   '31',
#   '35',
#   '2544',
#   '208',
#   '314',
#   '904',
#   '894',
#   '104',
#   '238',
#   '352',
#   '64',
#   '295',
#   '409',
#   '1727',
#   '116',
#   '129',
#   '90',
#   '119',
#   '15',
#   '263',
#   '173',
#   '125',
#   '133',
#   '363',
#   '34',
#   '136',
#   '75',
#   '131',
#   '54',
#   '278',
#   '591',
#   '165',
#   '99',
#   '81',
#   '153',
#   '73',
#   '265',
#   '240',
#   '45',
#   '45',
#   '311',
#   '537',
#   '221',
#   '66',
#   '226',
#   '210',
#   '85',
#   '58',
#   '36',
#   '290',
#   '56',
#   '129',
#   '269',
#   '39',
#   '402',
#   '42',
#   '331',
#   '711',
#   '92',
#   '306',
#   '3',
#   '74',
#   '166',
#   '63',
#   '554',
#   '30',
#   '35',
#   '17',
#   '165',
#   '6',
#   '15',
#   '2',
#   '65',
#   '207',
#   '66',
#   '98',
#   '36',
#   '361',
#   '96',
#   '302',
#   '125',
#   '412',
#   '176',
#   '125',
#   '460',
#   '462',
#   '151',
#   '49',
#   '501',
#   '26',
#   '44',
#   '16',
#   '291',
#   '1610',
#   '104',
#   '44',
#   '60',
#   '148',
#   '32',
#   '151',
#   '11',
#   '96',
#   '452',
#   '2141',
#   '104',
#   '167',
#   '260',
#   '34',
#   '57',
#   '10',
#   '320',
#   '59',
#   '188',
#   '202',
#   '75',
#   '179',
#   '71',
#   '360',
#   '110',
#   '182',
#   '6',
#   '303',
#   '152',
#   '22',
#   '58',
#   '27',
#   '291',
#   '84',
#   '63',
#   '256',
#   '330',
#   '146',
#   '50',
#   '76',
#   '343',
#   '154',
#   '95',
#   '58',
#   '177',
#   '159',
#   '59',
#   '26',
#   '38',
#   '224',
#   '27',
#   '54',
#   '56',
#   '95',
#   '155',
#   '140',
#   '79',
#   '421',
#   '2048',
#   '67',
#   '202',
#   '145',
#   '123',
#   '50',
#   '50',
#   '590',
#   '99',
#   '93',
#   '51',
#   '3',
#   '90',
#   '30',
#   '70']}

# %%
list_url = ['https://place.map.kakao.com/19382069']

# %%
data = {
    'merchant' : [],
    'category' : [],
    'star' : [],
    'address' : [],
    'oper_time' : [],
    'starCount' : [],
    'reviewCount' : []
}

# %%
data2 = {
    'user_name' : [],
    'user_rank' : [],
    'num_response' : [],
    'user_star' : [], 
    'time' : [],
    'rating' : [],
    'content' : []
    }

# %%
### 기본 정보 크롤링 (상세보기 get으로 열어서 가져오기)

driver = webdriver.Chrome()
for i in range(len(list_url)):

    data2 = {
    'user_name' : [],
    'user_rank' : [],
    'num_response' : [],
    'user_star' : [], 
    'time' : [],
    'rating' : [],
    'content' : []
    }


    ## 상세보기 웹페이지 열기
    driver.get(list_url[i])
    driver.implicitly_wait(3)

    # 영업시간 더 보기 클릭
    try:
        oper_more = driver.find_elements(By.CSS_SELECTOR, 'a[data-logevent = "main_info,more_timeinfo"]')
        oper_more[0].click()
        time.sleep(2)  

    # 영업시간 더보기가 없는 경우
    except:
        pass

    # 후기 더보기 클릭
    try:
        link_more = driver.find_element(By.CLASS_NAME, 'txt_more')
        while link_more.text == "후기 더보기":
            link_more = driver.find_element(By.CLASS_NAME, 'txt_more')
            # 마지막 후기 더보기까지 눌렀으면 멈추기
            if link_more.text != "후기 접기":
                link_more.click()
                time.sleep(0.3)
    # 후기 더보기 없는 경우        
    except:
        pass
    time.sleep(0.1)
  
    ## 상세page bs4 파싱 분석
    soup = bs(driver.page_source, 'html.parser')

    

    try:    
        print(driver.find_elements(By.CSS_SELECTOR, 'h2[class = "tit_location"]')[1].text,"파싱완료")    
    except:
        print('예외')
        
    


    ## 매장명
    mer = soup.find('h2', {'class':'tit_location'}).get_text()
    data['merchant'].append(mer)
    ## 분류
    data['category'].append(soup.find('span',{'class':'txt_location'}).get_text().split(':')[1].strip())
    ## 주소
    data['address'].append(soup.find('span', {'class': 'txt_address'}).get_text().replace(" ", "").replace("\n", " "))

    ## 별점, 리뷰 수 
    # 별점 있는 경우
    if len(soup.find_all('span',{'class':'color_b'})) > 1:
        data['star'].append(soup.find_all('span', {'class':'color_b'})[0].get_text().strip('점'))
        data['starCount'].append(soup.find('a', {'class': 'link_evaluation'})['data-cnt'])
        data['reviewCount'].append(soup.find_all('span', {'class':'color_b'})[1].get_text().strip('개'))
    # 별점 없는 경우
    else:
        data['star'].append('0')
        data['starCount'].append('0')
        data['reviewCount'].append(soup.find('span', {'class':'color_b'}).get_text().strip('개'))

    ## 영업시간
    try:
        # 더보기 있는 경우
        if oper_more:    
            data['oper_time'].append(soup.find_all('ul', {'class':'list_operation'})[1].get_text().strip())
        # 더보기 없는 경우
        else:
            data['oper_time'].append(soup.find('ul', {'class':'list_operation'}).get_text().strip().replace("\n", ""))
    except:
        data['oper_time'].append('0')


    # 리뷰 목록 잡기
    reveiw_listed = soup.find_all('li', {'data-ismy':'false'})

    #### df2 만들기 (리뷰df)
    for j in range(len(reveiw_listed)):
        ## 유저 이름
        data2['user_name'].append(soup.find_all('span',{'class':'txt_username'})[j].get_text())
        ## 유저 레벨
        data2['user_rank'].append(soup.find_all('span', {'class' : 'txt_badge'})[j].get_text().strip('레벨'))
        ## 유저 후기수
        data2['num_response'].append(
            soup.find_all('div',{'class':'unit_info'})[j].find_all('span',{'class':'txt_desc'})[0].get_text()
        )
        ## 유저 별점 평균
        data2['user_star'].append(
            soup.find_all('div',{'class':'unit_info'})[j].find_all('span',{'class':'txt_desc'})[1].get_text()
        )
        ### 리뷰 작성 시간
        data2['time'].append(
            soup.find_all('div',{'class':'unit_info'})[j].find('span',{'class':'time_write'}).get_text()
        )
        ## 리뷰 내용
        data2['content'].append(
            soup.find_all('p', {'class':'txt_comment'})[j].get_text().strip('더보기')
        )

        ## 유저가 평가한 별점 
        # 너비를 추출하여 별점 계산 (너비는 별점의 백분율을 나타냄)
        style_attribute = soup.find_all('div', {'class':'star_info'})[j].find('span',{'class':'ico_star inner_star'})['style']
        width_percent = float(style_attribute.split(':')[1].strip('%;'))
        rating_out_of_five = width_percent / 20  # 별점은 100%를 5로 나눈 값
        data2['rating'].append(rating_out_of_five)

    ## 데이터 프레임으로 만들기
    df2 = pd.DataFrame(data2)
    df2.to_csv(f'./data2/{mer}.csv',index = False)

    

    print(f"{i+1}번째 데이터 입력 완료, {mer}.csv 저장 완료")

driver.close()

df = pd.DataFrame(data)
df.to_csv("./data1/data.csv", index=False)
# Out:
# 홍대조폭떡볶이 홍대2호점 파싱완료
# 1번째 데이터 입력 완료, 홍대조폭떡볶이 홍대2호점.csv 저장 완료

# %%
df = pd.DataFrame(data)
df.to_csv("./data1/data.csv", index=False)

# %%
len(df['merchant'].unique())
# Out:
# 49

# %%
list_url=['https://place.map.kakao.com/20809319','https://place.map.kakao.com/27197478','https://place.map.kakao.com/905125344','https://place.map.kakao.com/20885402','https://place.map.kakao.com/27459445',
          'https://place.map.kakao.com/10304651','https://place.map.kakao.com/763211643','https://place.map.kakao.com/524094409','https://place.map.kakao.com/1925626633','https://place.map.kakao.com/926080103',
          'https://place.map.kakao.com/7876611','https://place.map.kakao.com/27515050','https://place.map.kakao.com/27321311','https://place.map.kakao.com/1570928971','https://place.map.kakao.com/726593676',
          'https://place.map.kakao.com/1546782043','https://place.map.kakao.com/7919830','https://place.map.kakao.com/8368414','https://place.map.kakao.com/1351400084','https://place.map.kakao.com/27468317',
          'https://place.map.kakao.com/11263998','https://place.map.kakao.com/196078294','https://place.map.kakao.com/16050660','https://place.map.kakao.com/26873353','https://place.map.kakao.com/1737597646',
          'https://place.map.kakao.com/747903409','https://place.map.kakao.com/1706900559','https://place.map.kakao.com/245300878','https://place.map.kakao.com/1009353804','https://place.map.kakao.com/22924852',
          'https://place.map.kakao.com/13113825','https://place.map.kakao.com/15985522','https://place.map.kakao.com/12532489','https://place.map.kakao.com/27194461','https://place.map.kakao.com/490667330',
          'https://place.map.kakao.com/1558238643','https://place.map.kakao.com/1228594008','https://place.map.kakao.com/13091834','https://place.map.kakao.com/1570017396','https://place.map.kakao.com/1351221007',
          'https://place.map.kakao.com/193594597','https://place.map.kakao.com/8101657','https://place.map.kakao.com/19183637','https://place.map.kakao.com/10900296','https://place.map.kakao.com/11230411',
          'https://place.map.kakao.com/19909925','https://place.map.kakao.com/1421762112','https://place.map.kakao.com/23211197','https://place.map.kakao.com/26217952']

# %%
len(list_url)
# Out:
# 49

# %%
df
# Out:
#                  merchant  category star  \
# 0                     가비애        카페  4.1
# 1             고기꾼김춘배 홍대본점     육류,고기    0
# 2                    고수포차    실내포장마차  4.6
# 3                   구스토타코   멕시칸,브라질  3.8
# 4                     닭꼬얌       닭요리  3.7
# 5                     델문도        카페  2.9
# 6         또보겠지떡볶이집 붕붕허니비점       떡볶이  3.9
# 7         또보겠지떡볶이집 스마일보이점       떡볶이  3.6
# 8                    마시타야     일본식라면    0
# 9                    몰토베네      이탈리안  4.5
# 10                    무대륙        카페  3.8
# 11                   민트하임     디저트카페  3.7
# 12              바다회사랑 2호점         회  3.2
# 13                  배터리88   호프,요리주점  3.1
# 14             별자리마라탕 홍대점      중국요리  4.1
# 15               산리오러버스클럽        카페  3.9
# 16                  삼거리포차    실내포장마차  2.8
# 17                   서강8경        양식  3.4
# 18         서울이스케이프룸 홍대2호점      테마카페  3.4
# 19                 수지앤파스타      이탈리안  4.1
# 20                    스노브     디저트카페  3.5
# 21                 스케줄 합정        양식  3.5
# 22                 스파카나폴리      이탈리안  4.1
# 23              신주양꼬치 홍대점       양꼬치  3.2
# 24                  앤디스커피        카페  3.3
# 25               야키토리 나루토     일본식주점  4.7
# 26  옛맛서울불고기 (2024년 5월 예정)  불고기,두루치기  3.4
# 27                     오니     일본식주점    0
# 28              온달집 홍대직영점    실내포장마차  4.7
# 29                   와우끝집         회  3.9
# 30                   윤씨밀방        양식  3.8
# 31                   이미커피     커피전문점  4.3
# 32             재미난조각가 홍대점      사주카페  3.0
# 33                   제비다방        다방  4.4
# 34               제순식당 홍대점        한식  4.7
# 35                 좋아해닭발1       닭요리    0
# 36              집사의하루 홍대점     고양이카페  4.4
# 37                 철길왕갈비살        갈비  3.4
# 38                    카레시        일식    0
# 39                카와카츠 본점    돈까스,우동  4.2
# 40               카페공명 홍대점     커피전문점  4.1
# 41                  클럽에반스      칵테일바  4.5
# 42                    키즈나     일본식주점  4.2
# 43                    토라비     디저트카페  4.2
# 44               퐁포네뜨 홍대점   제과,베이커리  4.3
# 45               홍대삭 상수본점        분식  4.1
# 46                  홍대씨부엉       떡볶이  4.0
# 47                 홍대차칸곱창     곱창,막창  3.9
# 48                   효봉포차    실내포장마차  4.4
#
#                                         address  \
# 0                      서울마포구 와우산로147-1 (우)04053
# 1                    서울마포구 홍익로3길36 3,4층(우)04039
# 2              서울마포구 독막로76-1 한주빌딩1층102호(우)04074
# 3                         서울마포구 와우산로41 (우)04049
# 4                  서울마포구 와우산로18길29 지하1층(우)04067
# 5                     서울마포구 잔다리로19-6 2층(우)04048
# 6                  서울마포구 양화로19길22-25 2층(우)03994
# 7                  서울마포구 와우산로29길14-8 2층(우)04052
# 8                     서울마포구 와우산로29라길26 (우)04053
# 9                       서울마포구 성지3길67 1층(우)04072
# 10                       서울마포구 토정로5길12 (우)04073
# 11                      서울마포구 잔다리로6길28 (우)04042
# 12                    서울마포구 동교로143 1,2층(우)04002
# 13                      서울마포구 와우산로19길6 (우)04041
# 14                 서울마포구 와우산로23길50 지하1층(우)04055
# 15               서울마포구 와우산로19길18 가동1,2층(우)04041
# 16                        서울마포구 와우산로70 (우)04067
# 17                      서울마포구 토정로128 8층(우)04081
# 18             서울마포구 와우산로17길11 코스모스빌딩3층(우)04049
# 19                    서울마포구 독막로15길3-18 (우)04049
# 20                        서울마포구 와우산로59 (우)04049
# 21                  서울마포구 양화로6길33 홍타운1층(우)04044
# 22                     서울마포구 양화로6길28 2층(우)04046
# 23                        서울마포구 와우산로66 (우)04067
# 24                 서울마포구 와우산로35길75 2,3층(우)04052
# 25                서울마포구 독막로9길26 야키토리나루토(우)04048
# 26  서울마포구 창전로45 서강한화오벨리스크스아파트103동1층101호(우)04086
# 27                   서울마포구 어울마당로75 2,3층(우)04042
# 28                       서울마포구 잔다리로9 1층(우)04049
# 29                     서울마포구 와우산로156 2층(우)04061
# 30                 서울마포구 와우산로15길15 지하1층(우)04049
# 31                     서울마포구 동교로25길7 1층(우)03992
# 32                   서울마포구 와우산로21길24 2층(우)04040
# 33                        서울마포구 와우산로24 (우)04075
# 34                  서울마포구 와우산로15길30 지1층(우)04049
# 35                     서울마포구 와우산로107 1층(우)04054
# 36             서울마포구 와우산로21길19-8 태경빌딩2층(우)04041
# 37                     서울마포구 와우산로32길24 (우)04061
# 38                 서울마포구 독막로9길31 스페이스1층(우)04048
# 39          서울마포구 동교로126 광남벨라스아파트1층102호(우)04030
# 40             서울마포구 와우산로17길11-8 1,2,3층(우)04049
# 41                      서울마포구 와우산로63 2층(우)04049
# 42                   서울마포구 와우산로29바길6 지층(우)04053
# 43                  서울마포구 와우산로29바길24 2층(우)04053
# 44                     서울마포구 와우산로25길11 (우)04054
# 45                       서울마포구 독막로71 1층(우)04049
# 46                 서울마포구 와우산로21길28-6 1층(우)04040
# 47                 서울마포구 와우산로23길35-8 1층(우)04055
# 48                     서울마포구 와우산로18길12 (우)04067
#
#                                             oper_time starCount reviewCount
# 0                                    매일 00:00 ~ 24:00        56          16
# 1                                    매일 12:00 ~ 23:00         0         409
# 2   월~목 17:00 ~ 01:00\n\n금 17:00 ~ 02:00\n\n토 16:0...        28          99
# 3                화~토 11:30 ~ 22:00\n\n일 11:30 ~ 20:30       128         125
# 4                                    매일 11:00 ~ 23:00        59          50
# 5              월~금 13:00 ~ 21:00\n\n토,일 12:00 ~ 21:00        64          90
# 6   화~일 11:30 ~ 21:00\n\n화~일 라스트오더 ~ 20:00\n\n화~금 ...       141         590
# 7                                   월~토 11:30 ~ 21:30        63         238
# 8                                    매일 11:00 ~ 17:00         0         208
# 9           매일 11:30 ~ 21:30\n\n매일 휴게시간 15:30 ~ 17:30       162         302
# 10                                   매일 12:00 ~ 24:00       100         123
# 11                                   매일 11:30 ~ 21:30        48         125
# 12               월~토 14:30 ~ 01:00\n\n일 14:30 ~ 23:00       156         894
# 13                                   매일 17:00 ~ 05:00        38          50
# 14                                   매일 11:30 ~ 22:30        89          26
# 15                              매일 12:00 ~ 21:00(에약제)        64         904
# 16                                                  0        28           2
# 17              매일 12:00 ~ 24:00매일 휴게시간 15:00 ~ 17:30        33         129
# 18                                   매일 11:00 ~ 24:00        11          90
# 19                                  화~일 11:30 ~ 22:00        51        2048
# 20                                   매일 11:00 ~ 23:00        47          30
# 21                                   매일 11:00 ~ 23:00        94        2544
# 22        수~일 11:30 ~ 21:30\n\n수~일 휴게시간 15:00 ~ 17:00       203         361
# 23             월~금 17:00 ~ 05:00\n\n토,일 17:00 ~ 06:00        36         460
# 24             월~금 10:00 ~ 23:00\n\n토,일 11:00 ~ 23:00        30           3
# 25             월~금 16:00 ~ 23:00\n\n토,일 15:00 ~ 23:00       196         501
# 26        화~일 11:00 ~ 21:00\n\n화~일 휴게시간 13:30 ~ 16:30        98         145
# 27  월,화,수,목,일 16:00 ~ 05:00\n\n금,토 16:00 ~ 06:50\n...         0          70
# 28       월,화,수,목,일 17:00 ~ 05:00\n\n금,토 16:30 ~ 09:00       240          64
# 29                                  월~토 17:00 ~ 22:00        37          93
# 30        수~일 11:30 ~ 21:00\n\n수~일 휴게시간 15:00 ~ 16:00       171         176
# 31                                  수~일 12:00 ~ 21:00       125         412
# 32                                                  0        30          34
# 33                                   매일 11:00 ~ 02:00        97         104
# 34  월,화,수,목,금,일 11:00 ~ 22:00\n\n월,화,수,목,금,일 라스트오더...        47          49
# 35                          월,수,목,금,토,일 17:00 ~ 01:30         0          96
# 36                                                  0       131         133
# 37               매일 12:00 ~ 23:00\n\n매일 라스트오더 ~ 22:30        54         116
# 38                                  화~일 12:00 ~ 21:00         0         295
# 39        월~토 11:30 ~ 20:00\n\n월~토 휴게시간 15:00 ~ 17:00       350         462
# 40                                   매일 11:00 ~ 23:00        68         352
# 41                                   매일 19:30 ~ 23:00        38          44
# 42                                  화~일 17:00 ~ 02:00        29          51
# 43                                   매일 12:00 ~ 21:30        69         201
# 44                                   매일 10:30 ~ 21:00        59          67
# 45                                   매일 11:30 ~ 23:00        95         151
# 46                                   매일 11:00 ~ 24:00        37        1727
# 47                                   매일 13:30 ~ 01:00        18         146
# 48                                                  0        20          35

# %%
a = pd.read_csv('./data1/data.csv')

# %%
# Out:
# 225
