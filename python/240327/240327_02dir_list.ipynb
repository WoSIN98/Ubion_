# %% [markdown]
# #### 특정 경로에 있는 파일의 목록을 로드
# 1. 일반적인 방법 -> 상대경로, 절대경로를 이용해서 파일을 하나씩 로드
# 2. 특정 경로에 있는 파일의 목록(list)을 기준으로 데이터를 로드
#     - os 라이브러리 이용하는 방법
#     - glob 라이브러리 이용하는 방법
# 3. 파일의 목록을 기준으로 데이터를 for문을 이용해서 로드

# %%
import os
import glob
import pandas as pd

# %%
## csv 폴더 안에 있는 2017 폴더에 있는 데이터들을 로드 

# os 라이브러리를 이용하여 파일의 목록을 불러온다. 
# 목록(list) + 파일의 목록을 보는 명령어(dir)
os.listdir('../../csv/2017/')
# Out:
# ['201701_expense_list.csv',
#  '201702_expense_list.csv',
#  '201703_expense_list.csv',
#  '201704_expense_list.csv',
#  '201705_expense_list.csv',
#  '201706_expense_list.csv',
#  '201707_expense_list.csv',
#  '201708_expense_list.csv',
#  '201709_expense_list.csv',
#  '201710_expense_list.csv',
#  '201711_expense_list.csv',
#  '201712_expense_list.csv']

# %%
## 파일 목록을 로드할 경로를 변수에 저장
file_path = '../../csv/2017/'                # 맨 뒤에 /없으면 아래 코드 실행 시 에러 뜬다. 
file_list = os.listdir(file_path)
file_list
# Out:
# ['201701_expense_list.csv',
#  '201702_expense_list.csv',
#  '201703_expense_list.csv',
#  '201704_expense_list.csv',
#  '201705_expense_list.csv',
#  '201706_expense_list.csv',
#  '201707_expense_list.csv',
#  '201708_expense_list.csv',
#  '201709_expense_list.csv',
#  '201710_expense_list.csv',
#  '201711_expense_list.csv',
#  '201712_expense_list.csv']

# %%
pd.read_csv(file_path + file_list[0])

# %%
result = pd.DataFrame()                 # 비어있는 데이터프레임
for file in file_list:
    df = pd.read_csv(file_path+file)    # + 띄어쓰면 오류난다.
    # result와 df를 유니언 결합하여 result에 담아준다.
    result = pd.concat([result, df] , axis = 0, ignore_index = True)
print(result)
# Out:
#             nid                            title  \
# 0      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4      11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...         ...                              ...
# 70127  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70128  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70129  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70130  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 70131  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
#
#                                               url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 2      http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# ...

# %%
file_path2 = '../../csv/2019/'
file_list2 = os.listdir(file_path2)
file_list2
# Out:
# ['201901_expense_list.json',
#  '201902_expense_list.json',
#  '201903_expense_list.json',
#  '201904_expense_list.json',
#  '201905_expense_list.json',
#  '201906_expense_list.json',
#  '201907_expense_list.json',
#  '201908_expense_list.json',
#  '201909_expense_list.json',
#  '201910_expense_list.json',
#  '201911_expense_list.json',
#  '201912_expense_list.json']

# %%
result_2019 = pd.DataFrame()            
for file2 in file_list2:
    df2 = pd.read_json(file_path2+file2)   
    result_2019 = pd.concat([result_2019, df2] , axis = 0, ignore_index = True)
result_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156258 entries, 0 to 156257
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nid                156258 non-null  int64
#  1   title              156258 non-null  object
#  2   url                156258 non-null  object
#  3   dept_nm_lvl_1      156258 non-null  object
#  4   dept_nm_lvl_2      156258 non-null  object
#  5   dept_nm_lvl_3      156258 non-null  object
#  6   dept_nm_lvl_4      156258 non-null  object
#  7   dept_nm_lvl_5      156258 non-null  object
#  8   exec_yr            156258 non-null  int64
#  9   exec_month         156258 non-null  int64
#  10  expense_budget     4394 non-null    float64
#  11  expense_execution  3304 non-null    float64
#  12  category           155900 non-null  object
#  13  dept_nm_full       156258 non-null  object
#  14  exec_dt            156258 non-null  object
# ...

# %%
file_path3 = '../../csv/2020/'
file_list3 = os.listdir(file_path3)
result3 = pd.DataFrame()            
for file3 in file_list3:
    df3 = pd.read_excel(file_path3+file3)   
    result3 = pd.concat([result3, df3] , axis = 0, ignore_index = True)
print(result3)
# Out:
#             nid                                            title  \
# 0      21789676            2020년 1월 사업소 서울식물원 시설운영과 업무추진비 - 부서운영
# 1      21762080  2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 2      21762080  2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 3      21762080  2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 4      21762080  2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# ...         ...                                              ...
# 70857  22228979          2020년 12월 사업소 서울시립대학교 자유융합대학 업무추진비 - 전체
# 70858  22228979          2020년 12월 사업소 서울시립대학교 자유융합대학 업무추진비 - 전체
# 70859  22228979          2020년 12월 사업소 서울시립대학교 자유융합대학 업무추진비 - 전체
# 70860  22241147   2020년 12월 사업소 물재생센터 난지물재생센터 시설보수과 업무추진비 - 부서운영
# 70861  22241147   2020년 12월 사업소 물재생센터 난지물재생센터 시설보수과 업무추진비 - 부서운영
#
#                                               url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0      http://opengov.seoul.go.kr/public/21789676           사업소         서울식물원
# ...

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 1.3/3.9 MB 16.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.3/3.9 MB 26.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 27.7 MB/s eta 0:00:00
# ...

# %%
file_path4 = '../../csv/2021/'
file_list4 = os.listdir(file_path4)
result4 = pd.DataFrame()            
for file4 in file_list4:
    if file4.endswith('csv') :
        df4 = pd.read_csv(file_path4+file4)
        result4 = pd.concat([result4, df4] , axis = 0, ignore_index = True)
    elif file4.endswith('json') :
        df4 = pd.read_json(file_path4+file4)
        result4 = pd.concat([result4, df4] , axis = 0, ignore_index = True)
    elif file4.endswith('xlsx') : 
        df4 = pd.read_excel(file_path4+file4)
        result4 = pd.concat([result4, df4] , axis = 0, ignore_index = True)
    elif file4.endswith('xml') : 
        df4 = pd.read_xml(file_path4+file4)
        result4 = pd.concat([result4, df4] , axis = 0, ignore_index = True)
print(result4)
# Out:
#              nid                                              title  \
# 0       22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1       22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2       22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3       22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4       22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...          ...                                                ...
# 335271  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 335272  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 335273  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 335274  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 335275  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
#
#                                                 url dept_nm_lvl_1  \
# 0        http://opengov.seoul.go.kr/public/22249566           사업소
# ...

# %%
#---------------------------

# %%
## 2021폴더를 확인
file_path = '../../csv/2021/'
file_list = os.listdir(file_path)
file_list
# Out:
# ['202101_expense_list.csv',
#  '202101_expense_list.json',
#  '202101_expense_list.xlsx',
#  '202101_expense_list.xml',
#  '202102_expense_list.csv',
#  '202102_expense_list.json',
#  '202102_expense_list.xlsx',
#  '202102_expense_list.xml',
#  '202103_expense_list.csv',
#  '202103_expense_list.json',
#  '202103_expense_list.xlsx',
#  '202103_expense_list.xml',
#  '202104_expense_list.csv',
#  '202104_expense_list.json',
#  '202104_expense_list.xlsx',
#  '202104_expense_list.xml',
#  '202105_expense_list.csv',
#  '202105_expense_list.json',
#  '202105_expense_list.xlsx',
#  '202105_expense_list.xml',
#  '202106_expense_list.csv',
#  '202106_expense_list.json',
#  '202106_expense_list.xlsx',
#  '202106_expense_list.xml',
#  '202107_expense_list.csv',
#  '202107_expense_list.json',
#  '202107_expense_list.xlsx',
#  '202107_expense_list.xml',
#  '202108_expense_list.csv',
#  '202108_expense_list.json',
#  '202108_expense_list.xlsx',
#  '202108_expense_list.xml',
# ...

# %%
file_list[0].split('.')[-1] == 'csv'
# Out:
# True

# %%
file_list[0].endswith('csv')
# Out:
# True

# %%
os.path.splitext(file_list[0])                    # 파일명과 확장자를 나눠주는 함수          # 결과 튜플
# Out:
# ('201701_expense_list', '.csv')

# %%
file_name, file_end = os.path.splitext(file_list[0])
file_end
# Out:
# '.csv'

# %%
result_2021 = pd.DataFrame()

# 확장자를 선택해서 해당하는 확장자만 result_2021에 결합
for file in file_list:
    # excel 파일인 경우에만 result_2021에 결합
    if file.split(".")[-1] in ['xlsx','xls']:
        df = pd.read_excel(file_path+file)
        result_2021 = pd.concat([result_2021, df], axis = 0, ignore_index= True)

# %%
result_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83819 entries, 0 to 83818
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                83819 non-null  int64
#  1   title              83819 non-null  object
#  2   url                83819 non-null  object
#  3   dept_nm_lvl_1      83819 non-null  object
#  4   dept_nm_lvl_2      83819 non-null  object
#  5   dept_nm_lvl_3      67930 non-null  object
#  6   dept_nm_lvl_4      24831 non-null  object
#  7   dept_nm_lvl_5      1473 non-null   object
#  8   exec_yr            83819 non-null  int64
#  9   exec_month         83819 non-null  int64
#  10  expense_budget     60524 non-null  float64
#  11  expense_execution  60524 non-null  float64
#  12  category           980 non-null    object
#  13  dept_nm_full       83819 non-null  object
#  14  exec_dt            83819 non-null  object
#  15  exec_loc           83185 non-null  object
# ...

# %%
###
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "a = pd.read_json('../../csv/2019/201901_expense_list.json')\nprint(a)",
#   'import os\nimport glob\nimport pandas as pd',
#   "## 파일 목록을 로드할 경로를 변수에 저장\nfile_path = '../../csv/2017/'                # 맨 뒤에 /없으면 아래 코드 실행 시 에러 뜬다. \nfile_list = os.listdir(file_path)\nfile_list",
#   'pd.read_csv(file_path + file_list[0])',
#   'result = pd.DataFrame()                 # 비어있는 데이터프레임\nfor file in file_list:\n    df = pd.read_csv(file_path+file)    # + 띄어쓰면 오류난다.\n    # result와 df를 유니언 결합하여 result에 담아준다.\n    result = pd.concat([result, df] , axis = 0, ignore_index = True)\nprint(result)',
#   "file_path2 = '../../csv/2019/'\nfile_list2 = os.listdir(file_path)\nfile_list2",
# ...

# %%
globals()["a1"] = 10
print(a1)
# Out:
# 10

# %%
## 2021 폴더에 있는 파일들을 각각 다른 변수에 저장 
file_path = "../../csv/2021/"
file_list = os.listdir(file_path)

for file in file_list:
    # 사용할 변수의 이름 
    name, end = os.path.splitext(file)
    # end에 있는 . 을 제거
    # print(end[1:])
    # print(end.lstrip('.'))
    # print(end.replace('.',''))
    end = end[1:]
    if end == 'csv':
        df = pd.read_csv(file_path+file)
    elif end == 'json':
        df = pd.read_json(file_path+file)
    elif end == 'xml':
        df = pd.read_xml(file_path+file)
    elif end in ['xlsx', 'xls']:
        df = pd.read_excel(file_path+file)
    else: 
        continue
    globals()[f"{name}_{end}"] = df.copy()

# %%
globals()['202101_expense_list_csv']            # globals()로 변수 만들면 숫자나 특수기호로도 변수명 만들 수 있으나, 호출시에 globals()['']로 불러와야한다.

# %%
#### 지정된 경로에 파일들을 하나의 데이터프레임으로 결합하여 되돌려주는 함수 생성
# 매개변수 -> 경로, 확장자명 
def data_load(_path, _end = 'csv'):
    # _path : 파일의 경로
    # _end : 파일의 확장자명

    # 유저가 입력한 경로를 이용하여 파일의 리스트를 변수에 저장 
    file_list = os.listdir(_path)
    # 비어있는 데이터프레임 생성
    result = pd.DataFrame()
    _path = _path + '/'
    # _path에 '\'의 값을 '/' 대체
    # _path = _path.replace('\','/')
    for file in file_list:
        # file -> 파일명 
        # 파일명의 확장자가 유저가 입력한 확장자와 같다면 
        if file.endswith(_end):
            if _end == 'csv':
                df = pd.read_csv(_path+file)
            elif _end == 'json':
                df = pd.read_json(_path+file)
            elif _end == 'xml':
                df = pd.read_xml(_path+file)
            elif _end in ['xlsx', 'xls']:
                df = pd.read_excel(_path+file)
            else:
                return "지원하는 확장자가 아닙니다."                 # return은 함수종료의 의미도 있으므로 위의 4가지 경우가 아니면 함수 종료
            #df를 result에 유니언 결합
            result = pd.concat([result, df], axis = 0, ignore_index = True)
    return result

# %%
data_load(r'C:')   # 절대경로

# %%
data_load('../../csv/2021/','json')   # 상대경로
# Out:
#             nid                                              title  \
# 0      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 1      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 2      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 3      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# 4      22249566              2021년 1월 사업소 물재생센터 중랑물재생센터 업무추진비 - 전체
# ...         ...                                                ...
# 83814  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83815  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83816  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83817  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 83818  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
#
#                                                url dept_nm_lvl_1  \
# 0       http://opengov.seoul.go.kr/public/22249566           사업소
# ...
