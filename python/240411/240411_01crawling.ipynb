# %%
import requests

# %%
url = 'https://www.naver.com'
response = requests.get(url)

# %%
from pprint import pprint

# %%
pprint(response.text)
# Out:
# ('   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta '
#  'charset="utf-8"> <meta name="Referrer" content="origin"> <meta '
#  'http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" '
#  'content="width=1190"> <title>NAVER</title> <meta '
#  'name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" '
#  'content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 '
#  '정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta '
#  'property="og:url" content="https://www.naver.com/"> <meta '
#  'property="og:image" '
#  'content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> '
#  '<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> '
#  '<meta name="twitter:card" content="summary"> <meta name="twitter:title" '
#  'content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta '
#  'name="twitter:image" '
# ...

# %%
html_data = response.text

# %%
type(html_data)
# Out:
# str

# %%
## html_data에서 '네이버' 문자열의 위치를 검색
print(html_data.find('네이버'))
print(html_data.index('네이버'))
# Out:
# 378
# 378

# %%
print(html_data.find('구글'))
print(html_data.index('구글'))

# %%
html_data[378:381]
# Out:
# '네이버'

# %% [markdown]
# ### bs4 라이브러리
# - bs4 라이브러리 안에 있는 BeautifulSoup Class를 사용
# - html로 이루어진 문자형 데이터를 parsing 작업을 하여 데이터를 쉽게 추출하기 위한 Class
#     - parsing : 데이터의 타입을 변경(Class 안에 데이터를 대입)
# - html의 TAG를 기준으로 데이터(contents)를 쉽게 추출
# - 웹의 구조를 어느정도 파악을 하고 사용을 하게 되면 쉽게 접근이 가능
# - Parser를 활용하여 파이썬에서 접근이 쉽게 객체(변수 + 함수)의 형태로 제공

# %%
## 라이브러리 설치
#!pip install bs4

# %%
## 라이브러리 로드
from bs4 import BeautifulSoup as bs

# %%
## html로 이루어진 문자열을 bs Class에 대입 -> pasing
soup = bs(html_data, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# - 태그의 이름을 기준으로 검색(필터)
#     - soup.태그명 : 해당 태그명의 첫번째 태그를 출력
#     - soup.태그명.string : 첫번째 태그의 문자열(contents)을 출력
#         - ex) `<p>test</p>` --> test
#     - soup.태그명['속성명'] : 첫번째 태그의 해당 속성의 값을 출력
#         - ex) `<a href = 'https://www.google.com'>구글</a>` --> 'https://www.google.com'

# %%
soup.a
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.a.string
# Out:
# '상단영역 바로가기'

# %%
soup.a['href']
# Out:
# '#topAsideButton'

# %% [markdown]
# - find( )
#     - HTML 데이터에서 특정 태그의 첫번째 정보를 출력
#     - find(속성명 = 속성값) : 해당 속성명과 속성의 값이 같은 태그들 중 첫번재 태그의 정보를 출력  (Class라는 속성을 많이 쓴다.)
#     - 결과 데이터가 TAG의 형태로 출력 (문자열로 생각하면 문자 데이터)
# - find_all( )
#     - HTML 데이터에서 특정 태그의 모든 정보를 출력
#     - limit 매개변수 : 출력해주는 데이터의 개수를 지정
#     - 결과 데이터가 TAG들의 집합인 ResultSet 형태로 출력(문자열로 생각하면 리스트 데이터)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
type(soup.find('a'))           # Tag는 bs를 상속해왔기에 bs의 함수를 쓸 수 있다.
# Out:
# bs4.element.Tag

# %%
type(soup.find_all('a'))        # ResultSet은 bs를 상속하지 않았기에 bs함수 쓸 수 없다.
# Out:
# bs4.element.ResultSet

# %%
print(soup.find('a'))
print(soup.a)
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
pprint(soup.find_all('a'))           # 리스트 형태라고 생각해도 괜찮다.
# Out:
# [<a href="#topAsideButton"><span>상단영역 바로가기</span></a>,
#  <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a>,
#  <a href="#newsstand"><span>새소식 블록 바로가기</span></a>,
#  <a href="#shopping"><span>쇼핑 블록 바로가기</span></a>,
#  <a href="#feed"><span>관심사 블록 바로가기</span></a>,
#  <a href="#account"><span>MY 영역 바로가기</span></a>,
#  <a href="#widgetboard"><span>위젯 보드 바로가기</span></a>,
#  <a href="#viewSetting"><span>보기 설정 바로가기</span></a>,
#  <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a>,
#  <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>,
#  <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>,
#  <a class="close _keywordOnOff" href="#">자동저장 끄기</a>,
#  <a data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>,
#  <a class="close _close" href="#">닫기</a>,
# ...

# %%
## Tag 형태로 되어있는 데이터에서 contents를 추출
a_data = soup.find('a')
print(a_data)
print(a_data.string)
print(a_data.get_text())
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>
# 상단영역 바로가기
# 상단영역 바로가기

# %%
## ResultSet 형태로 되어있는 데이터에서 contents 출력
a_list = soup.find_all('a')
print(a_list)
print(a_list.string)
print(a_list.get_text)

# %%
print(a_list[1].string)
print(a_list[1].get_text)
# Out:
# 서비스 메뉴 바로가기
# <bound method PageElement.get_text of <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a>>

# %%
result = list()
for i in range(0,len(a_list)):
    result.append(a_list[i].get_text())

print(result)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
result2 = []
i = 0
while i < len(a_list):
    result2.append(a_list[i].get_text())
    i = i + 1
print(result2)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
def app(_list):
   _list.get_text()

# %%
list(map(app, a_list))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
import pandas as pd
a_series = pd.Series(a_list)
a_series = a_series.map(lambda x : x.get_text())
result4 = list(a_series.values)
print(result4)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
## 수업 ------------------

# %%
# for + range
_list = []

for i in range(len(a_list)):
    _list.append(a_list[i].get_text())               # .string으로 불러오면 제대로 불러오지 못할 때가 있다.
                                                     # .get_text()는 text 다 가져온다. get_text() 쓰는 것이 좋다.

# %%
# for + list데이터
_list3 = list()

for tag in a_list:
    _list3.append(tag.get_text())

print(_list3)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
# while 조건식
_list4 = []
i = 0

while i < len(a_list):
    _list4.append(a_list[i].get_text())
    i += 1
print(_list4)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
# while 무한반복
i = 0
_list5 = []

while True:
    try:
        _list5.append(a_list[i].get_text())
        i += 1
    except:
        break
print(_list5)
# Out:
# ['상단영역 바로가기', '서비스 메뉴 바로가기', '새소식 블록 바로가기', '쇼핑 블록 바로가기', '관심사 블록 바로가기', 'MY 영역 바로가기', '위젯 보드 바로가기', '보기 설정 바로가기', '전체삭제', '도움말', '도움말', '자동저장 끄기', '도움말', '닫기', '이 정보가 표시된 이유', '레이어 닫기', '자세히보기', '관심사를 반영한 컨텍스트 자동완성도움말', '컨텍스트 자동완성', '자세히 보기', '자세히 보기', '네이버로그인', '컨텍스트 자동완성 레이어 닫기', '자동완성 끄기', '도움말', '신고', '닫기']

# %%
# map() + 일반함수
def change(x):
    return x.get_text()

list(map(change,a_list))
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기',
#  '전체삭제',
#  '도움말',
#  '도움말',
#  '자동저장 끄기',
#  '도움말',
#  '닫기',
#  '이 정보가 표시된 이유',
#  '레이어 닫기',
#  '자세히보기',
#  '관심사를 반영한 컨텍스트 자동완성도움말',
#  '컨텍스트 자동완성',
#  '자세히 보기',
#  '자세히 보기',
#  '네이버로그인',
#  '컨텍스트 자동완성 레이어 닫기',
#  '자동완성 끄기',
#  '도움말',
#  '신고',
#  '닫기']

# %%
# map + lambda
list(map(lambda x : x.get_text(), a_list))
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기',
#  '전체삭제',
#  '도움말',
#  '도움말',
#  '자동저장 끄기',
#  '도움말',
#  '닫기',
#  '이 정보가 표시된 이유',
#  '레이어 닫기',
#  '자세히보기',
#  '관심사를 반영한 컨텍스트 자동완성도움말',
#  '컨텍스트 자동완성',
#  '자세히 보기',
#  '자세히 보기',
#  '네이버로그인',
#  '컨텍스트 자동완성 레이어 닫기',
#  '자동완성 끄기',
#  '도움말',
#  '신고',
#  '닫기']

# %%
## naver html 문서에서 div태그 중에 id가 newsstand인 태그를 추출   # id가 newsstand인 것은 하나밖에 없으므로 find쓴다.
soup.find('div', attrs={'id' : 'newsstand'})          # output 안나온다.

# %%
soup.find('div', attrs={'id' : 'container'})          # output 나온다.
# naver가 동적페이지이기 때문에.
# Out:
# <div id="container" role="main"> <div id="root"></div> </div>

# %%
## 새로운 주소로 요청을 보낸다.
url2 = 'https://finance.naver.com/'
response2 = requests.get(url2)

# %%
html_data2 = response2.text
html_data2
# Out:
# '\n\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t<title>네이버페이 증권</title>\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n\t\t<meta property="og:title" content="네이버페이 증권"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버페이 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel
# ...

# %%
## BeautifulSoup를 이용하여 데이터를 parsing
soup2 = bs(html_data2, 'html.parser')
soup2
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
# <meta content="네이버페이 증권" property="og:title">
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240411105708/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# div 태그 중 class가 section_sise_top인 태그의 개수를 확인 
len(soup2.find_all('div', attrs = {'class' : 'section_sise_top'}))
# Out:
# 1

# %%
div_data = soup2.find('div', attrs = {'class' : 'section_sise_top'})

# %%
div_data
# Out:
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <ul class="tab_area sise_top1">
# <li class="tab1"><a class="is_active" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span>거래상위</span></a></li>
# <li class="tab2"><a href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span>상승</span></a></li>
# <li class="tab3"><a href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span>하락</span></a></li>
# <li class="tab4"><a href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span>시가총액 상위</span></a></li>
# </ul>
# <div class="group_type is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# ...

# %%
# div_data에서 table 태그의 개수를 확인
len(div_data.find_all('table'))
# Out:
# 4

# %%
### table 태그의 데이터들을 변수에 저장
tables = div_data.find_all('table')

# %%
# tables의 첫번째 태그를 이용하여 데이터를 추출하여 데이터 프레임으로 생성
_table = tables[0]

# %%
type(_table)
# Out:
# bs4.element.Tag

# %%
_table
# Out:
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>2,030</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 5</td>
# <td>
# <em class="down">
# 				-0.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=038460" onclick="clickcr(this, 'spe.slist', '038460', '2', event);">바이오스마트</a></th>
# <td>6,030</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 720</td>
# <td>
# <em class="up">
# 				+13.56%
# 				</em>
# </td>
# </tr>
# <tr class="same">
# ...

# %%
## _table에서 thead를 추출
head_data = _table.find('thead')

# %%
head_data
# Out:
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>

# %%
th_data = head_data.find_all('th')
th_data
# Out:
# [<th scope="col">종목명</th>,
#  <th scope="col">현재가</th>,
#  <th scope="col">전일대비</th>,
#  <th scope="col">등락률</th>]

# %%
_col = []
for tag in th_data:
    _col.append(tag.get_text())
print(_col)                                   # df의 col명
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
tbody_data = _table.find('tbody')
tbody_data
# Out:
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>2,030</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 5</td>
# <td>
# <em class="down">
# 				-0.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=038460" onclick="clickcr(this, 'spe.slist', '038460', '2', event);">바이오스마트</a></th>
# <td>6,030</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 720</td>
# <td>
# <em class="up">
# 				+13.56%
# 				</em>
# </td>
# </tr>
# <tr class="same">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '3', event);">KODEX 인버스</a></th>
# <td>4,140</td>
# <td><em class="bu_p bu_pn"><span class="blind">보합</span></em></td>
# <td>
# <em class="steady">
# 				0.00%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# ...

# %%
## tbody_data에서 tr태그들을 모두 찾는다.
tr_data = tbody_data.find_all('tr')
tr_data
# Out:
# [<tr class="down">
#  <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
#  <td>2,030</td>
#  <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 5</td>
#  <td>
#  <em class="down">
#  				-0.25%
#  				</em>
#  </td>
#  </tr>,
#  <tr class="up">
#  <th scope="row"><a href="/item/main.naver?code=038460" onclick="clickcr(this, 'spe.slist', '038460', '2', event);">바이오스마트</a></th>
#  <td>6,030</td>
#  <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 720</td>
#  <td>
#  <em class="up">
#  				+13.56%
#  				</em>
#  </td>
#  </tr>,
#  <tr class="same">
#  <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '3', event);">KODEX 인버스</a></th>
#  <td>4,140</td>
#  <td><em class="bu_p bu_pn"><span class="blind">보합</span></em></td>
#  <td>
#  <em class="steady">
#  				0.00%
#  				</em>
#  </td>
#  </tr>,
#  <tr class="down">
# ...

# %%
## tr_data에서 첫번째 원소를 추출하여 contents들을 리스트로 생성
_val = [tr_data[0].find('th').get_text()]

for tag2 in tr_data[0].find_all('td'):
    _val.append(tag2.get_text().strip())               # tab, 줄바꿈 없애주기

print(_val)
# Out:
# ['KODEX 200선물인버스2X', '2,030', '하락 5', '-0.25%']

# %%
# 위 코드를 반복 실행하여 새로운 빈 리스트에 추가
_values = []
for i in range(len(tr_data)):
    _val = [tr_data[i].find('th').get_text()]

    for tag2 in tr_data[i].find_all('td'):
        _val.append(tag2.get_text().strip())
    
    _values.append(_val)

_values
# Out:
# [['KODEX 200선물인버스2X', '2,030', '하락 5', '-0.25%'],
#  ['바이오스마트', '6,030', '상승 720', '+13.56%'],
#  ['KODEX 인버스', '4,140', '보합', '0.00%'],
#  ['HB테크놀러지', '3,655', '하락 35', '-0.95%'],
#  ['삼성전자', '84,600', '상승 500', '+0.59%'],
#  ['엘컴텍', '1,598', '상승 9', '+0.57%'],
#  ['KODEX 레버리지', '19,745', '보합', '0.00%'],
#  ['에이프로젠', '1,804', '하락 19', '-1.04%'],
#  ['TIGER 200선물인버스2X', '2,160', '보합', '0.00%'],
#  ['삼성 인버스 2X WTI원유 선물 ETN', '83', '보합', '0.00%'],
#  ['이스타코', '854', '하락 38', '-4.26%'],
#  ['이수페타시스', '43,600', '상승 1,150', '+2.71%'],
#  ['SDN', '1,539', '하락 20', '-1.28%'],
#  ['켐트로닉스', '28,900', '상승 400', '+1.40%'],
#  ['디와이디', '872', '상승 74', '+9.27%']]

# %%
fin_df = pd.DataFrame(_values, columns = _col )
fin_df
# Out:
#                        종목명     현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X   2,030      하락 5   -0.25%
# 1                   바이오스마트   6,030    상승 720  +13.56%
# 2                KODEX 인버스   4,140        보합    0.00%
# 3                  HB테크놀러지   3,655     하락 35   -0.95%
# 4                     삼성전자  84,600    상승 500   +0.59%
# 5                      엘컴텍   1,598      상승 9   +0.57%
# 6               KODEX 레버리지  19,745        보합    0.00%
# 7                    에이프로젠   1,804     하락 19   -1.04%
# 8         TIGER 200선물인버스2X   2,160        보합    0.00%
# 9   삼성 인버스 2X WTI원유 선물 ETN      83        보합    0.00%
# 10                    이스타코     854     하락 38   -4.26%
# 11                  이수페타시스  43,600  상승 1,150   +2.71%
# 12                     SDN   1,539     하락 20   -1.28%
# 13                   켐트로닉스  28,900    상승 400   +1.40%
# 14                    디와이디     872     상승 74   +9.27%

# %%
## df를 csv로 저장
fin_df.to_csv('./fin_df.csv', index = False)

# %%
a = pd.read_csv('./fin_df.csv')

# %%
a
# Out:
#                        종목명     현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X   2,030      하락 5   -0.25%
# 1                   바이오스마트   6,030    상승 720  +13.56%
# 2                KODEX 인버스   4,140        보합    0.00%
# 3                  HB테크놀러지   3,655     하락 35   -0.95%
# 4                     삼성전자  84,600    상승 500   +0.59%
# 5                      엘컴텍   1,598      상승 9   +0.57%
# 6               KODEX 레버리지  19,745        보합    0.00%
# 7                    에이프로젠   1,804     하락 19   -1.04%
# 8         TIGER 200선물인버스2X   2,160        보합    0.00%
# 9   삼성 인버스 2X WTI원유 선물 ETN      83        보합    0.00%
# 10                    이스타코     854     하락 38   -4.26%
# 11                  이수페타시스  43,600  상승 1,150   +2.71%
# 12                     SDN   1,539     하락 20   -1.28%
# 13                   켐트로닉스  28,900    상승 400   +1.40%
# 14                    디와이디     872     상승 74   +9.27%

# %%
### tables 데이터에 있는 table 태그들을 모두 데이터 프레임으로 변환
cnt = 1
for _table in tables:
    # _table에서 thead 태그를 추출
    thead_data = _table.find('thead')
    _col = []
    for tag in thead_data.find_all('th'):
        _col.append(tag.get_text())
    tbody_data = _table.find('tbody')
    tr_data = tbody_data.find_all('tr')
    _values = []
    for tag in tr_data:
        _val = [tag.find('th').get_text()]
        for tag2 in tag.find_all('td'):
            _val.append(tag2.get_text().strip())
        _values.append(_val)
    # 데이터프레임을 생성하여 글로벌 변수에 대입
    globals()[f'df{cnt}'] = pd.DataFrame(_values, columns=_col)
    cnt += 1

# %%
df4
# Out:
#          종목명      현재가      전일대비     등락률
# 0       삼성전자   84,600    상승 500  +0.59%
# 1     SK하이닉스  189,900  상승 1,500  +0.80%
# 2   LG에너지솔루션  379,500    하락 500  -0.13%
# 3      삼성전자우   69,700    상승 500  +0.72%
# 4   삼성바이오로직스  795,000        보합   0.00%
# 5        현대차  240,500    하락 500  -0.21%
# 6         기아  110,000  하락 1,700  -1.52%
# 7       셀트리온  178,900    하락 600  -0.33%
# 8   POSCO홀딩스  402,000  상승 2,000  +0.50%
# 9      NAVER  185,800  상승 2,200  +1.20%
# 10     삼성SDI  410,500  상승 3,000  +0.74%
# 11      LG화학  390,500  상승 3,500  +0.90%
# 12      KB금융   66,800  하락 1,500  -2.20%
# 13      삼성물산  144,100  하락 2,900  -1.97%
# 14    에코프로비엠  239,500    상승 500  +0.21%

# %%
### 위의 과정을 pandas에서 함수로 쉽게 만들어 놓았다. 단, 테이블 태그에 한정해서 가능.
div_str = str(div_data)    # soup를 문자형으로 바꿔줘야 한다.
pd.read_html(div_str)
# Out:
# C:\Users\Jws\AppData\Local\Temp\ipykernel_1132\4118286687.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(div_str)
# [                       종목명    현재가      전일대비      등락률
#  0         KODEX 200선물인버스2X   2030      하락 5   -0.25%
#  1                   바이오스마트   6030    상승 720  +13.56%
#  2                KODEX 인버스   4140        보합    0.00%
#  3                  HB테크놀러지   3655     하락 35   -0.95%
#  4                     삼성전자  84600    상승 500   +0.59%
#  5                      엘컴텍   1598      상승 9   +0.57%
#  6               KODEX 레버리지  19745        보합    0.00%
#  7                    에이프로젠   1804     하락 19   -1.04%
#  8         TIGER 200선물인버스2X   2160        보합    0.00%
#  9   삼성 인버스 2X WTI원유 선물 ETN     83        보합    0.00%
#  10                    이스타코    854     하락 38   -4.26%
#  11                  이수페타시스  43600  상승 1,150   +2.71%
# ...

# %%
pd.read_html(div_str)[0]           # 테이블 tag에 한정해서 가능
# Out:
# C:\Users\Jws\AppData\Local\Temp\ipykernel_1132\3595166965.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(div_str)[0]           # 테이블 tag에 한정해서 가능
#                        종목명    현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X   2030      하락 5   -0.25%
# 1                   바이오스마트   6030    상승 720  +13.56%
# 2                KODEX 인버스   4140        보합    0.00%
# 3                  HB테크놀러지   3655     하락 35   -0.95%
# 4                     삼성전자  84600    상승 500   +0.59%
# 5                      엘컴텍   1598      상승 9   +0.57%
# 6               KODEX 레버리지  19745        보합    0.00%
# 7                    에이프로젠   1804     하락 19   -1.04%
# 8         TIGER 200선물인버스2X   2160        보합    0.00%
# 9   삼성 인버스 2X WTI원유 선물 ETN     83        보합    0.00%
# 10                    이스타코    854     하락 38   -4.26%
# ...

# %%
url3 = 'https://search.shopping.naver.com/search/all?query=%EB%A9%80%ED%8B%B0%EB%B9%84%ED%83%80%EB%AF%BC'
response3 = requests.get(url3)

# %% [markdown]
# ### 복습
# 1. response3 데이터를 문자열로 저장
# 2. 문자열로 저장된 데이터를 BeautifulSoup를 이용하여 parsing
# 3. div 중 id가 content인 태그를 추출
# 4. 3번에서 추출한 Tag에서 div 중 class가 today_section인 태그를 추출
# 5. 헤드라인만 추출하여 리스트로 생성

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url3 = 'https://sports.news.naver.com/index'
response3 = requests.get(url3)

# %%
html_data3 = response3.text
html_data3
# Out:
# '\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta http-equiv="X-UA-Compatible" content="requiresActiveX=true">\n\t<meta name="viewport" content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes">\n\t<meta property="og:image"       content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png"/>\n\t<meta property="og:title"\t\tcontent="스포츠홈 : 네이버 스포츠"/>\n\t<meta property="og:description" content="스포츠의 시작과 끝!"/>\n\t<meta name="description" content="스포츠의 모든 것, 네이버 스포츠와 함께 하세요">\n\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\n\t<title>스포츠홈 : 네이버 스포츠</title>\n\t\n    <link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsCss.css\'>\n\n    <link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsHome.css\'>\n
# ...

# %%
soup3 = bs(html_data3, 'html.parser')
soup3
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="스포츠홈 : 네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="스포츠의 모든 것, 네이버 스포츠와 함께 하세요" name="description"/>
# <title>스포츠홈 : 네이버 스포츠</title>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsCss.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsHome.css" rel="stylesheet" type="text/css"/>
# ...

# %%
len(soup3.find_all('div', attrs={'class' : 'today_section'}))
# Out:
# 1

# %%
div_data = soup3.find('div', attrs={'class' : 'today_section'})
div_data
# Out:
# <div class="today_section type_no_da">
# <h3 class="blind">오늘의 스포츠</h3>
# <ul class="today_list">
# <li class="today_item">
# <a class="link_today" data-not-edited="Y" href="/news?oid=311&amp;aid=0001713313" onclick="clickcr(this, 'rnk*r.list', '311_0001713313', '1', event);" title="손흥민 분노 유발자, 토트넘 남을 수도...임대는 싫어, 완전 이적 원한다">
# <div class="image_area">
# <!-- [D] 썸네일 이미지 alt 값 비워주세요. -->
# <img alt="" height="95" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net?src=%22http%3A%2F%2Fimgnews.naver.net%2Fimage%2F311%2F2024%2F04%2F12%2F0001713313_001_20240412072603381.jpg%22&amp;type=nf160_95&amp;service=sports" width="160"/>
# </div>
# <div class="text_area">
# <strong class="title">손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다</strong>
# <!-- [D] 내용 두줄 말줄임 적용해주세요. -->
# <p class="news">
# 							지난해 12월 맨체스터 시티와의 경기 당시 패스 타이밍이 늦어 손흥민을 분노케 했던 토트넘 홋스퍼의 윙어 브리안 힐이 토트넘에 잔류할 가능성이 열렸다. 유럽..."
# 						</p>
# <div class="information">
# <span>엑스포츠뉴스</span>
# <span>프리미어리그</span>
# ...

# %%
div_data.find_all('strong')
# Out:
# [<strong class="title">손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다</strong>,
#  <strong class="title">"표정 관리가 좀" 천하의 류현진도 흔들린 실책…페라자 디스(? )+양의지 폭로까지, 유쾌함 넘친 '99번째 승리' </strong>,
#  <strong class="title">토트넘 '희소식! '…'10골 5도움' 공격수 맹활약→'케인 대체자 영입에 '탄력'</strong>,
#  <strong class="title">'5연승 삼성 미쳤다' 120억 캡틴 8연타석 안타, 돌아온 원클럽맨 5할 맹타도 돋보였지만…KKKKK 무실점 피칭, 기다렸다</strong>,
#  <strong class="title">한국 휩쓴 페디의 마구, MLB에선 안 통하나···4할대로 치솟은 스위퍼 피안타율</strong>,
#  <strong class="title">'충격' 오타니 계좌서 220억이나 빼돌리다니…미즈하라의 간큰 절도, 당사자는 진짜 몰랐다 (종합)</strong>]

# %%
head_data = div_data.find_all('strong')
headline = list()
for i in head_data:
   headline.append(i.get_text())

print(headline)
# Out:
# ['손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다', '"표정 관리가 좀" 천하의 류현진도 흔들린 실책…페라자 디스(? )+양의지 폭로까지, 유쾌함 넘친 \'99번째 승리\' ', "토트넘 '희소식! '…'10골 5도움' 공격수 맹활약→'케인 대체자 영입에 '탄력'", "'5연승 삼성 미쳤다' 120억 캡틴 8연타석 안타, 돌아온 원클럽맨 5할 맹타도 돋보였지만…KKKKK 무실점 피칭, 기다렸다", '한국 휩쓴 페디의 마구, MLB에선 안 통하나···4할대로 치솟은 스위퍼 피안타율', "'충격' 오타니 계좌서 220억이나 빼돌리다니…미즈하라의 간큰 절도, 당사자는 진짜 몰랐다 (종합)"]

# %%
## 수업 ---------------------------

# %%
url3 = 'https://sports.news.naver.com/index'
response3 = requests.get(url3)

# %%
soup = bs(response3.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="스포츠홈 : 네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="스포츠의 모든 것, 네이버 스포츠와 함께 하세요" name="description"/>
# <title>스포츠홈 : 네이버 스포츠</title>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsCss.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/111111/44/118/465600/css/generated/nsportsHome.css" rel="stylesheet" type="text/css"/>
# ...

# %%
div_data = soup.find('div', attrs={'id' : 'content'})           # 아이디 값은 하나 밖에 없으므로 바로 find쓴다.
div_data
# Out:
# <div id="content">
# <div class="main_wrap">
# <div class="today_section type_no_da">
# <h3 class="blind">오늘의 스포츠</h3>
# <ul class="today_list">
# <li class="today_item">
# <a class="link_today" data-not-edited="Y" href="/news?oid=311&amp;aid=0001713313" onclick="clickcr(this, 'rnk*r.list', '311_0001713313', '1', event);" title="손흥민 분노 유발자, 토트넘 남을 수도...임대는 싫어, 완전 이적 원한다">
# <div class="image_area">
# <!-- [D] 썸네일 이미지 alt 값 비워주세요. -->
# <img alt="" height="95" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net?src=%22http%3A%2F%2Fimgnews.naver.net%2Fimage%2F311%2F2024%2F04%2F12%2F0001713313_001_20240412072603381.jpg%22&amp;type=nf160_95&amp;service=sports" width="160"/>
# </div>
# <div class="text_area">
# <strong class="title">손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다</strong>
# <!-- [D] 내용 두줄 말줄임 적용해주세요. -->
# <p class="news">
# 							지난해 12월 맨체스터 시티와의 경기 당시 패스 타이밍이 늦어 손흥민을 분노케 했던 토트넘 홋스퍼의 윙어 브리안 힐이 토트넘에 잔류할 가능성이 열렸다. 유럽..."
# 						</p>
# <div class="information">
# ...

# %%
len(div_data.find_all('div',attrs= {'class' : 'today_section'}))
# Out:
# 1

# %%
div_data2 = div_data.find('div',attrs= {'class' : 'today_section'})
div_data2
# Out:
# <div class="today_section type_no_da">
# <h3 class="blind">오늘의 스포츠</h3>
# <ul class="today_list">
# <li class="today_item">
# <a class="link_today" data-not-edited="Y" href="/news?oid=311&amp;aid=0001713313" onclick="clickcr(this, 'rnk*r.list', '311_0001713313', '1', event);" title="손흥민 분노 유발자, 토트넘 남을 수도...임대는 싫어, 완전 이적 원한다">
# <div class="image_area">
# <!-- [D] 썸네일 이미지 alt 값 비워주세요. -->
# <img alt="" height="95" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net?src=%22http%3A%2F%2Fimgnews.naver.net%2Fimage%2F311%2F2024%2F04%2F12%2F0001713313_001_20240412072603381.jpg%22&amp;type=nf160_95&amp;service=sports" width="160"/>
# </div>
# <div class="text_area">
# <strong class="title">손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다</strong>
# <!-- [D] 내용 두줄 말줄임 적용해주세요. -->
# <p class="news">
# 							지난해 12월 맨체스터 시티와의 경기 당시 패스 타이밍이 늦어 손흥민을 분노케 했던 토트넘 홋스퍼의 윙어 브리안 힐이 토트넘에 잔류할 가능성이 열렸다. 유럽..."
# 						</p>
# <div class="information">
# <span>엑스포츠뉴스</span>
# <span>프리미어리그</span>
# ...

# %%
strong_data = div_data2.find_all('strong')

# %%
list(
    map(
        lambda x : x.get_text(),
        strong_data
    )
)
# Out:
# ['손흥민 분노 유발자, 토트넘 남을 수도…임대는 싫어, 완전 이적 원한다',
#  '"표정 관리가 좀" 천하의 류현진도 흔들린 실책…페라자 디스(? )+양의지 폭로까지, 유쾌함 넘친 \'99번째 승리\' ',
#  "토트넘 '희소식! '…'10골 5도움' 공격수 맹활약→'케인 대체자 영입에 '탄력'",
#  "'5연승 삼성 미쳤다' 120억 캡틴 8연타석 안타, 돌아온 원클럽맨 5할 맹타도 돋보였지만…KKKKK 무실점 피칭, 기다렸다",
#  '한국 휩쓴 페디의 마구, MLB에선 안 통하나···4할대로 치솟은 스위퍼 피안타율',
#  "'충격' 오타니 계좌서 220억이나 빼돌리다니…미즈하라의 간큰 절도, 당사자는 진짜 몰랐다 (종합)"]

# %%
## 동적 page는 한 번에 모든 html을 주지 않는다.
# so selenium 쓴다.
