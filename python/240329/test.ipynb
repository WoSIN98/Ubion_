# %%
import requests
from pprint import pprint

# %%
url = 'http://www.google.com'
r = requests.get(url)

# %%
pprint(r.content)
# Out:
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
#  b'"ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type'
#  b'"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.pn'
#  b'g" itemprop="image"><title>Google</title><script nonce="BclUH8jA7Z3jXG3xUmCd'
#  b'cQ">(function(){var _g={kEI:\'LcAXZuDaKPKevr0PgO2B2As\',kEXPI:\'0,1365467,2'
#  b'07,4804,2329817,1015,424527,53691,4998,55519,2872,2891,11754,31274,36419,970'
#  b'8,230,107248,6630,7596,1,11942,30218,2,37997,1758,6699,31123,4567,6256,17113'
#  b',7557,33067,2,2,1,26632,8155,23351,22435,9779,12415,30044,20198,44508,28671,'
#  b'2266,764,15816,1804,27092,8177,11813,1632,13496,29970,5223334,1346,852,147,5'
#  b'992323,2839365,1,2,1,2,1,2,1,15,27982745,16672,43887,3,318,4,1281,3,2121778,'
#  b'2585,16815,2,2,23012532,12799,8409,16664,17450,10577,36870,1923,8588,2370,64'
#  b'07,2866,7595,3384,10052,2901,2212,7981,201,389,7527,2890,2438,1628,2873,5,41'
#  b'46,4,1062,8833,15841,1793,3215,6870,3723,7268,359,17,218,1264,3,611,419,4457'
#  b',123,32,2484,1708,1269,1423,638,3909,4557,205,2205,25,1485,2232,10,892,681,8'
#  b',121,5062,110,1299,1426,55,1059,226,453,4,284,532,7,28,771,3,1366,610,315,18'
#  b',5,183,122,2668,540,2,4,130,87,1716,1078,707,274,430,1280,237,423,927,1,795,'
#  b'1219,853,2,4,228,552,4,37,598,577,362,2,441,1005,347,755,1075,248,2,2,1446,4'
#  b'70,289,212,188,886,2,440,1090,135,699,311,29,290,84,124,301,77,386,3,171,34,'
#  b'302,135,725,497,880,306,1109,1,3,447,5,624,129,520,37,595,64,396,140,337,654'
#  b',36,6,420,62,82,1414,66,754,1002,2,6,2,13,139,230,467,40,1260,163,159,14,76,'
#  b'12,6,12,9,9,9,6,12,6,14,6,12,9,9,6,12,9,6,12,9,9,6,9,12,9,6,12,9,9,9,9,6,12,'
#  b'9,6,12,9,6,12,9,9,9,9,6,9,9,12,9,9,6,9,12,6,12,6,9,9,12,6,9,9,9,12,6,12,6,9,'
#  b'9,12,6,12,9,6,9,12,6,12,6,12,6,9,12,9,6,12,6,9,9,12,9,6,12,6,9,12,6,12,6,12,'
#  b'6,12,6,9,12,9,9,9,6,12,6,9,9,12,9,6,9,9,12,9,9,9,6,9,12,9,6,12,6,9,12,6,12,6'
#  b',9,12,6,9,9,12,6,9,9,12,9,9,6,12,9,6,237,333,567,151,53,544,11,724,7,1,798,2'
#  b'17,625,751,494,453,21638357,4267,3,6857,571,866,285,956,3,635,146,673,2449,3'
#  b"323397',kBL:'pJHf',kOPI:89978449};(function(){var a;(null==(a=window.google)"
#  b'?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function('
#  b"){google.sn='webhp';google.kHL='ko';})();(function(){\nvar h=this||self;f"
#  b'unction l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!=='
#  b'window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var'
#  b' b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b'
#  b'||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("le'
#  b'id")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"==='
#  b'window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}'
#  b'),a="");return a}\nfunction t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&'
#  b'(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g='
#  b'-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]'
#  b');h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toS'
#  b'tring()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1'
#  b']}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google'
#  b'.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google'
#  b'.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a'
#  b'=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){del'
#  b'ete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t(""'
#  b',a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function('
#  b'a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]='
#  b'[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google'
#  b'.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load'
#  b'=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){goo'
#  b'gle.lq.push([a,b])};google.bx=!1;google.lx=function(){};var d=[];google.fce='
#  b'function(a,b,c,e){d.push([a,b,c,e])};google.qce=d;}).call(this);google.f={};'
#  b'(function(){\ndocument.documentElement.addEventListener("submit",function'
#  b'(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c|'
#  b'|"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopP'
#  b'ropagation())},!0);document.documentElement.addEventListener("click",functio'
#  b'n(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentEleme'
#  b'nt)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&'
#  b'&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-siz'
#  b'e:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7'
#  b'px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-s'
#  b'ize:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{'
#  b'height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.g'
#  b'b4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.g'
#  b'bi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n</styl'
#  b'e><style>body,td,a,p,.h{font-family:&#44404;&#47548;,&#46027;&#50880;,arial,'
#  b'sans-serif}.ko{font-size:9pt}body{margin:0;overflow-y:scroll}#gog{padding:3p'
#  b'x 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20'
#  b'px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;w'
#  b'idth:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-'
#  b'serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-le'
#  b'ft:4px}input{font-family:inherit}body{background:#fff;color:#000}a{color:#68'
#  b'1da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{c'
#  b'olor:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:b'
#  b'lock;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#f8f9fa;b'
#  b'order:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.ls'
#  b'bb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{backgroun'
#  b'd:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#000;border:none;curs'
#  b'or:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertica'
#  b'l-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}.Ucigb{wi'
#  b'dth:458px}</style><script nonce="BclUH8jA7Z3jXG3xUmCdcQ">(function(){window.'
#  b'google.erd={jsr:1,bv:1986,de:true};\nvar h=this||self;var k,l=null!=(k=h.'
#  b'mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=funct'
#  b'ion(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);void 0===d&&(d={});d.cad'
#  b'="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d)'
#  b',null;b=d;if(0>v){window.console&&console.error(a,b);if(-2===v)throw a;b=!1}'
#  b'else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if'
#  b'(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="'
#  b'+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b('
#  b'google.sn)+"&jsr="+b(t.jsr)+"&bver="+\nb(t.bv);var f=a.lineNumber;void 0!'
#  b'==f&&(c+="&line="+f);var g=a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3)'
#  b',c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement'
#  b'.outerHTML.split("\\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script f'
#  b'ound.")));google.ple&&1===google.ple&&(e=2);c+="&jsel="+e;for(var u in d)c+='
#  b'"&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&js'
#  b'st="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.'
#  b'log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanc'
#  b'eof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0=='
#  b'=b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"==='
#  b'a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("S'
#  b'cript error")?3:0));r=null;p&&q>=l&&(window.onerror=null)};})();</script></h'
#  b'ead><body bgcolor="#fff"><script nonce="BclUH8jA7Z3jXG3xUmCdcQ">(function(){'
#  b"var src='/images/nav_logo229.png';var iesg=false;document.body.onload = func"
#  b'tion(){window.n && window.n();if (document.images){new Image().src=src;}'
#  b'\nif (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbq'
#  b'f.q.focus();}\n}\n})();</script><div id="mngb"><div id=gbar><nobr><b class'
#  b'=gb1>&#44160;&#49353;</b> <a class=gb1 href="https://www.google.com/imghp?hl'
#  b'=ko&tab=wi">&#51060;&#48120;&#51648;</a> <a class=gb1 href="http://maps.goog'
#  b'le.co.kr/maps?hl=ko&tab=wl">&#51648;&#46020;</a> <a class=gb1 href="https://'
#  b'play.google.com/?hl=ko&tab=w8">Play</a> <a class=gb1 href="https://www.youtu'
#  b'be.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab='
#  b'wn">&#45684;&#49828;</a> <a class=gb1 href="https://mail.google.com/mail/?ta'
#  b'b=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">&#46300'
#  b';&#46972;&#51060;&#48652;</a> <a class=gb1 style="text-decoration:none" href'
#  b'="https://www.google.co.kr/intl/ko/about/products?tab=wh"><u>&#45908;&#48372'
#  b';&#44592;</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span i'
#  b'd=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a '
#  b'href="http://www.google.co.kr/history/optout?hl=ko" class=gb4>&#50937; &#445'
#  b'92;&#47197;</a> | <a  href="/preferences?hl=ko" class=gb4>&#49444;&#51221;</'
#  b'a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?'
#  b'hl=ko&passive=true&continue=http://www.google.com/&ec=GAZAAQ" class=gb4>&#47'
#  b'196;&#44536;&#51064;</a></nobr></div><div class=gbh style=left:0></div><div '
#  b'class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div i'
#  b'd="lga"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/go'
#  b'oglelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" wi'
#  b'dth="272" id="hplogo"><br><br></div><form action="/search" name="f"><table c'
#  b'ellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><'
#  b'td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden'
#  b'"><input value="ko" name="hl" type="hidden"><input name="source" type="hidde'
#  b'n" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden'
#  b'"><div class="ds" style="height:32px;margin:4px 0"><div style="position:rela'
#  b'tive;zoom:1"><input class="lst Ucigb" style="margin:0;padding:5px 8px 0 6px;'
#  b'vertical-align:top;color:#000;padding-right:38px" autocomplete="off" value="'
#  b'" title="Google &#44160;&#49353;" maxlength="2048" name="q" size="57"><img s'
#  b'rc="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;rig'
#  b'ht:5px;top:4px;z-index:300" data-script-url="/textinputassistant/13/ko_tia.j'
#  b's" id="tsuid_1" alt="" height="23" width="27"><script nonce="BclUH8jA7Z3jXG3'
#  b'xUmCdcQ">(function(){var id=\'tsuid_1\';document.getElementById(id).onclic'
#  b"k = function(){var s = document.createElement('script');s.src = this.getAttr"
#  b"ibute('data-script-url');document.body.appendChild(s);};})();</script></div>"
#  b'</div><br style="line-height:0"><span class="ds"><span class="lsbb"><input c'
#  b'lass="lsb" value="Google &#44160;&#49353;" name="btnG" type="submit"></span>'
#  b'</span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_2" v'
#  b'alue="I&#8217;m Feeling Lucky" name="btnI" type="submit"><script nonce="BclU'
#  b'H8jA7Z3jXG3xUmCdcQ">(function(){var id=\'tsuid_2\';document.getElementById'
#  b'(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.f'
#  b"orm.iflsig)this.form.iflsig.disabled = false;}\nelse top.location='/doodl"
#  b'es/\';};})();</script><input value="ANes7DEAAAAAZhfOPfesqRPXdfpTSn84smLf8'
#  b'tI0EUGe" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" '
#  b'align="left" nowrap="" width="25%"><a href="/advanced_search?hl=ko&amp;authu'
#  b'ser=0">&#44256;&#44553;&#44160;&#49353;</a></td></tr></table><input id="gbv"'
#  b' name="gbv" type="hidden" value="1"><script nonce="BclUH8jA7Z3jXG3xUmCdcQ">('
#  b'function(){var a,b="1";if(document&&document.getElementById)if("undefined"!='
#  b'typeof XMLHttpRequest)b="2";else if("undefined"!=typeof ActiveXObject){var c'
#  b',d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.'
#  b'XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if'
#  b'("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document'
#  b'.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){locati'
#  b'on.href=f},0)};}).call(this);</script></form><div id="gac_scont"></div><div '
#  b'style="font-size:83%;min-height:3.5em"><br></div><span id="footer"><div styl'
#  b'e="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQAN'
#  b'b"><a href="/intl/ko/ads/">&#44305;&#44256;</a><a href="http://www.google.co'
#  b'.kr/intl/ko/services/">&#48708;&#51592;&#45768;&#49828; &#49556;&#47336;&#49'
#  b'496;</a><a href="/intl/ko/about.html">Google &#51221;&#48372;</a><a href="ht'
#  b'tp://www.google.com/setprefdomain?prefdom=KR&amp;prev=http://www.google.co.k'
#  b'r/&amp;sig=K_zKOMpEpqw0iAv3Ic6Y4tRdS6f3k%3D">Google.co.kr</a></div></div><p '
#  b'style="font-size:8pt;color:#70757a">&copy; 2024 - <a href="/intl/ko/policies'
#  b'/privacy/">&#44060;&#51064;&#51221;&#48372;&#52376;&#47532;&#48169;&#52840;<'
#  b'/a> - <a href="/intl/ko/policies/terms/">&#50557;&#44288;</a></p></span></ce'
#  b'nter><script nonce="BclUH8jA7Z3jXG3xUmCdcQ">(function(){window.google.cdo={h'
#  b'eight:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeig'
#  b'ht;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentE'
#  b'lement:c.body;a=d.clientWidth;b=d.clientHeight}\nif(a&&b&&(a!=google.cdo.'
#  b'width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&bi'
#  b'w="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=void 0!==window.google&&void 0'
#  b'!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null;null!='
#  b'l&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(0===m||0<m)h+'
#  b'="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})();</script'
#  b'>  <script nonce="BclUH8jA7Z3jXG3xUmCdcQ">(function(){google.xjs={baseco'
#  b"mb:'',basecss:'',basejs:'',ck:'xjs.hp.4BYSiXNMPLY.L.X.O',combam:'AQAAAAEAAAA"
#  b"AAAAAAAAAAAAAAAAIAAAAAAAAjAMAABAACAQAAAAOAAEAAIAEAEBCAHAQHQHAABwBAIAX',cs:'A"
#  b"CT90oECzH1av6yPTCYwkreqaPAOoweDgg',cssam:'AQAAAAEAAAAAAAAAAAAAAAAAAAAAAAAAAA"
#  b"AAAAAAABAACAQAAAAAAAEAAIAEAEBC',csss:'ACT90oEugiB9PlBV3vte4TirE5wAXKQTRQ',ex"
#  b"cm:[],jsam:'AAAAAAAAAAAAAAAAAAAAAAAAAAAIAAAAAAAAjAMAAAAAAAAAAAAOAAAAAAAAAAAA"
#  b"AHAQHQHAABwBAIAX',jss:'ACT90oEN_fliIKW1vYHUcYqIYskz6PG_MA'};})();</script> <"
#  b'link href="/xjs/_/ss/k=xjs.hp.4BYSiXNMPLY.L.X.O/am=AQAAAAEAAAAAAAAAAAAAAAAAA'
#  b'AAAAAAAAAAAAAAAABAACAQAAAAAAAEAAIAEAEBC/d=1/ed=1/rs=ACT90oEugiB9PlBV3vte4Tir'
#  b'E5wAXKQTRQ/m=sb_he,d" rel="stylesheet" nonce="BclUH8jA7Z3jXG3xUmCdcQ">    <s'
#  b'cript nonce="BclUH8jA7Z3jXG3xUmCdcQ">(function(){var u=\'/xjs/_/js/k\\x3dx'
#  b'js.hp.en.BX8sVJ1N5CA.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAIAAAAAAAAjAMAAAA'
#  b'AAAAAAAAOAAAAAAAAAAAAAHAQHQHAABwBAIAX/d\\x3d1/ed\\x3d1/rs\\x3dACT90oEN_fliI'
#  b"KW1vYHUcYqIYskz6PG_MA/m\\x3dsb_he,d';var st=0;var amd=0;\nvar e=this||self"
#  b',f=function(a){return a};var g;var h=function(a){this.g=a};h.prototype.toStr'
#  b'ing=function(){return this.g+""};var k={};\nfunction m(a,b){a.src=b insta'
#  b'nceof h&&b.constructor===h?b.g:"type_error:TrustedResourceUrl";var c,d;(c=(b'
#  b'=null==(d=(c=(a.ownerDocument&&a.ownerDocument.defaultView||window).document'
#  b').querySelector)?void 0:d.call(c,"script[nonce]"))?b.nonce||b.getAttribute("'
#  b'nonce")||"":"")&&a.setAttribute("nonce",c)};var n=function(){var a=document;'
#  b'var b="SCRIPT";"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());'
#  b'return a.createElement(b)};function p(a){a=null===a?"null":void 0===a?"undef'
#  b'ined":a;if(void 0===g){var b=null;var c=e.trustedTypes;if(c&&c.createPolicy)'
#  b'{try{b=c.createPolicy("goog#html",{createHTML:f,createScript:f,createScriptU'
#  b'RL:f})}catch(d){e.console&&e.console.error(d.message)}g=b}else g=b}a=(b=g)?b'
#  b'.createScriptURL(a):a;return new h(a,k)};void 0===google.ps&&(google.ps=[]);'
#  b'function q(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){r(a)'
#  b';google.lx=b};google.bx||google.lx()}function t(a,b){b&&m(a,p(b));var c=a.on'
#  b'load;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(l){ret'
#  b'urn a!==l})};google.ps.push(a);document.body.appendChild(a)}google.as=t;func'
#  b'tion r(a){google.timers&&google.timers.load&&google.tick&&google.tick("load"'
#  b',"xjsls");var b=n();b.onerror=function(){google.ple=1};b.onload=function(){g'
#  b'oogle.ple=0};google.xjsus=void 0;t(b,a);google.aple=-1;google.psa=!0};google'
#  b'.xjsu=u;e._F_jsUrl=u;var v=!1;function w(){v||(q(),v=!0)}setTimeout(function'
#  b'(){var a;if(a=1===st&&google.caft){a:{a=document.getElementsByTagName("img")'
#  b';for(var b=0,c=a.length;b<c;b++){var d=a[b],l=Number(d.getAttribute("data-at'
#  b'f"))&1;d=d.hasAttribute("data-lzy_");if(l&&d){a=!0;break a}}a=!1}a=!a}a?(win'
#  b'dow.setTimeout(w,amd),google.caft(w)):2===st&&google.rairicb?(window.setTime'
#  b'out(w,amd),google.rairicb(w)):q()},0);})();window._ = window._ || {};window.'
#  b'_DumpException = _._DumpException = function(e){throw e;};window._s = window'
#  b'._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {}'
#  b';_qs._DumpException = _._DumpException;(function(){var t=[1,4,0,0,0,10240,0,'
#  b'16835328,134221824,16,1048800,18874368,4603904,74727872,298060800,98566144];'
#  b'window._F_toggles = window._xjs_toggles = t;})();function _F_installCss(c){}'
#  b'\n(function(){google.jl={bfl:0,dw:false,ine:false,ubm:false,uwp:true,vs:f'
#  b"alse};})();(function(){var pmc='{\\x22d\\x22:{},\\x22sb_he\\x22:{\\x22age"
#  b'n\\x22:false,\\x22cgen\\x22:false,\\x22client\\x22:\\x22heirloom-hp\\x22,\\x'
#  b'22dh\\x22:true,\\x22ds\\x22:\\x22\\x22,\\x22fl\\x22:true,\\x22host\\x22:\\'
#  b'x22google.com\\x22,\\x22jsonp\\x22:true,\\x22msgs\\x22:{\\x22cibl\\x22:\\x22'
#  b'\\\\uac80\\\\uc0c9\\\\uc5b4 \\\\uc9c0\\\\uc6b0\\\\uae30\\x22,\\x22dym\\x22:'
#  b'\\x22\\\\uc774\\\\uac83\\\\uc744 \\\\ucc3e\\\\uc73c\\\\uc168\\\\ub098\\\\'
#  b'uc694?\\x22,\\x22lcky\\x22:\\x22I\\\\u2019m Feeling Lucky\\x22,\\x22lml\\'
#  b'x22:\\x22\\\\uc790\\\\uc138\\\\ud788 \\\\uc54c\\\\uc544\\\\ubcf4\\\\uae30\\x'
#  b'22,\\x22psrc\\x22:\\x22\\\\uac80\\\\uc0c9\\\\uc5b4\\\\uac00 \\\\u003Ca hr'
#  b'ef\\x3d\\\\\\x22/history\\\\\\x22\\\\u003E\\\\uc6f9 \\\\uae30\\\\ub85d\\'
#  b'\\u003C/a\\\\u003E\\\\uc5d0\\\\uc11c \\\\uc0ad\\\\uc81c\\\\ub418\\\\uc5'
#  b'c8\\\\uc2b5\\\\ub2c8\\\\ub2e4.\\x22,\\x22psrl\\x22:\\x22\\\\uc0ad\\\\uc81c'
#  b'\\x22,\\x22sbit\\x22:\\x22\\\\uc774\\\\ubbf8\\\\uc9c0\\\\ub85c \\\\uac80\\\\'
#  b'uc0c9\\x22,\\x22srch\\x22:\\x22Google \\\\uac80\\\\uc0c9\\x22},\\x22ovr\\x2'
#  b'2:{},\\x22pq\\x22:\\x22\\x22,\\x22rfs\\x22:[],\\x22sbas\\x22:\\x220 3px 8'
#  b'px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\\x22,\\x22stok\\x22:\\x223QV'
#  b"7y-YY-cbFtO8ztV_JTNNqVbY\\x22}}';google.pmc=JSON.parse(pmc);})();(functio"
#  b'n(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,v'
#  b'alue:a[c++]}:{done:!0}}};\nvar e=this||self;var g,h;a:{for(var k=["CLOSUR'
#  b'E_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],null==l){h=null;break a}h=l}va'
#  b'r p=h&&h[610401301];g=null!=p?p:!1;var q,r=e.navigator;q=r?r.userAgentData||'
#  b'null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.bran'
#  b'd)&&-1!=c.indexOf(a)}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.'
#  b'userAgent)break a;c=""}return-1!=c.indexOf(a)};function v(){return g?!!q&&0<'
#  b'q.brands.length:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast")'
#  b')||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/")'
#  b')||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Androi'
#  b'd"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?'
#  b'0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox"'
#  b')||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u('
#  b'"MSIE");y();x();w();Object.freeze(new function(){});Object.freeze(new functi'
#  b'on(){});var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if('
#  b'A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;retur'
#  b'n void 0===a?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"'
#  b'-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=perform'
#  b'ance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m="undefined"!='
#  b'typeof Symbol&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if('
#  b'"number"==typeof d.length)d={next:b(d)};else throw Error("a`"+String(d));for'
#  b'(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a '
#  b'instanceof HTMLElement)if(a===F){if(c=4<=E.length)c=5>(E[E.length-1]-E[E.len'
#  b'gth-4])/1E3;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":'
#  b'"":f=(f=\na.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute('
#  b'"jsname"))a=a.getAttribute("jsname");else{var C;a=null==(C=a.closest("[jsnam'
#  b'e]"))?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&ved="+f+"&'
#  b'jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMConte'
#  b'ntLoaded",function(){document.body.addEventListener("click",G)});}).call(thi'
#  b's);</script></body></html>')

# %%
url = 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.redbull.com%2Fkr-ko%2Ff1-halo&psig=AOvVaw3Lon96s1WctLOa4RCP16Oq&ust=1712919157178000&source=images&cd=vfe&opi=89978449&ved=0CBIQjRxqFwoTCJiH06D_uYUDFQAAAAAdAAAAABAK'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
from PIL import Image
from io import BytesIO

Image.open(BytesIO(r.content))

# %%
url = 'http://apis.data.go.kr/1741000/RegistrationPopulationByRegion/getRegistrationPopulationByRegion'

service_key = 'dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw=='

_param = {
    'ServiceKey' : service_key,
    "pageNo" : 1,
    "numOfRows" : 50
}

# %%
response = requests.get(url, params= _param)

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n\n<RegistrationPopulationByRegion>\n  <head>\n    <totalCount>266</totalCount>\n    <numOfRows>50</numOfRows>\n    <pageNo>1</pageNo>\n    <type>XML</type>\n    <RESULT>\n      <resultCode>INFO-0</resultCode>\n      <resultMsg>NOMAL SERVICE</resultMsg>\n    </RESULT>\n  </head>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>1</seq>\n    <regi>\xea\xb3\x84</regi>\n    <population_tot>49540367</population_tot>\n    <population_man>24822897</population_man>\n    <population_female>24717470</population_female>\n    <houshol>19005339</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>2</seq>\n    <regi>\xec\x84\x9c\xec\x9a\xb8</regi>\n    <population_tot>10200827</population_tot>\n    <population_man>5061809</population_man>\n    <population_female>5139018</population_female>\n    <houshol>4097562</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>3</seq>\n    <regi>\xeb\xb6\x80\xec\x82\xb0</regi>\n    <population_tot>3564577</population_tot>\n    <population_man>1773154</population_man>\n    <population_female>1791423</population_female>\n    <houshol>1311724</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>4</seq>\n    <regi>\xeb\x8c\x80\xea\xb5\xac</regi>\n    <population_tot>2492724</population_tot>\n    <population_man>1246873</population_man>\n    <population_female>1245851</population_female>\n    <houshol>894969</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>5</seq>\n    <regi>\xec\x9d\xb8\xec\xb2\x9c</regi>\n    <population_tot>2692696</population_tot>\n    <population_man>1356473</population_man>\n    <population_female>1336223</population_female>\n    <houshol>1014755</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>6</seq>\n    <regi>\xea\xb4\x91\xec\xa3\xbc</regi>\n    <population_tot>1422702</population_tot>\n    <population_man>705817</population_man>\n    <population_female>716885</population_female>\n    <houshol>513021</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>7</seq>\n    <regi>\xeb\x8c\x80\xec\xa0\x84</regi>\n    <population_tot>1480895</population_tot>\n    <population_man>741611</population_man>\n    <population_female>739284</population_female>\n    <houshol>531682</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>8</seq>\n    <regi>\xec\x9a\xb8\xec\x82\xb0</regi>\n    <population_tot>1112407</population_tot>\n    <population_man>572815</population_man>\n    <population_female>539592</population_female>\n    <houshol>389735</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>9</seq>\n    <regi>\xea\xb2\xbd\xea\xb8\xb0</regi>\n    <population_tot>11292264</population_tot>\n    <population_man>5690673</population_man>\n    <population_female>5601591</population_female>\n    <houshol>4284475</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>10</seq>\n    <regi>\xea\xb0\x95\xec\x9b\x90</regi>\n    <population_tot>1508575</population_tot>\n    <population_man>759282</population_man>\n    <population_female>749293</population_female>\n    <houshol>606950</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>11</seq>\n    <regi>\xec\xb6\xa9\xeb\xb6\x81</regi>\n    <population_tot>1519587</population_tot>\n    <population_man>765398</population_man>\n    <population_female>754189</population_female>\n    <houshol>587411</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>12</seq>\n    <regi>\xec\xb6\xa9\xeb\x82\xa8</regi>\n    <population_tot>2018537</population_tot>\n    <population_man>1020317</population_man>\n    <population_female>998220</population_female>\n    <houshol>812871</houshol>\n  </row>\n  <row>\n    <wrttimeid>2008</wrttimeid>\n    <seq>13</seq>\n    <regi>\xec\xa0\x84\xeb\xb6\x81</regi>\n    <population_tot>1855772</population_tot>\n    <population_man>924770</population_man>\n    <population_female>931002</popul ...

# %%
import xmltodict

# %%
data = xmltodict.parse(response.content)

# %%
pprint(data)
# Out:
# {'RegistrationPopulationByRegion': {'head': {'RESULT': {'resultCode': 'INFO-0',
#                                                         'resultMsg': 'NOMAL '
#                                                                      'SERVICE'},
#                                              'numOfRows': '50',
#                                              'pageNo': '1',
#                                              'totalCount': '266',
#                                              'type': 'XML'},
#                                     'row': [{'houshol': '19005339',
#                                              'population_female': '24717470',
#                                              'population_man': '24822897',
#                                              'population_tot': '49540367',
#                                              'regi': '계',
#                                              'seq': '1',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '4097562',
#                                              'population_female': '5139018',
#                                              'population_man': '5061809',
#                                              'population_tot': '10200827',
#                                              'regi': '서울',
#                                              'seq': '2',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '1311724',
#                                              'population_female': '1791423',
#                                              'population_man': '1773154',
#                                              'population_tot': '3564577',
#                                              'regi': '부산',
#                                              'seq': '3',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '894969',
#                                              'population_female': '1245851',
#                                              'population_man': '1246873',
#                                              'population_tot': '2492724',
#                                              'regi': '대구',
#                                              'seq': '4',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '1014755',
#                                              'population_female': '1336223',
#                                              'population_man': '1356473',
#                                              'population_tot': '2692696',
#                                              'regi': '인천',
#                                              'seq': '5',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '513021',
#                                              'population_female': '716885',
#                                              'population_man': '705817',
#                                              'population_tot': '1422702',
#                                              'regi': '광주',
#                                              'seq': '6',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '531682',
#                                              'population_female': '739284',
#                                              'population_man': '741611',
#                                              'population_tot': '1480895',
#                                              'regi': '대전',
#                                              'seq': '7',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '389735',
#                                              'population_female': '539592',
#                                              'population_man': '572815',
#                                              'population_tot': '1112407',
#                                              'regi': '울산',
#                                              'seq': '8',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '4284475',
#                                              'population_female': '5601591',
#                                              'population_man': '5690673',
#                                              'population_tot': '11292264',
#                                              'regi': '경기',
#                                              'seq': '9',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '606950',
#                                              'population_female': '749293',
#                                              'population_man': '759282',
#                                              'population_tot': '1508575',
#                                              'regi': '강원',
#                                              'seq': '10',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '587411',
#                                              'population_female': '754189',
#                                              'population_man': '765398',
#                                              'population_tot': '1519587',
#                                              'regi': '충북',
#                                              'seq': '11',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '812871',
#                                              'population_female': '998220',
#                                              'population_man': '1020317',
#                                              'population_tot': '2018537',
#                                              'regi': '충남',
#                                              'seq': '12',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '710550',
#                                              'population_female': '931002',
#                                              'population_man': '924770',
#                                              'population_tot': '1855772',
#                                              'regi': '전북',
#                                              'seq': '13',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '773087',
#                                              'population_female': '960509',
#                                              'population_man': '958491',
#                                              'population_tot': '1919000',
#                                              'regi': '전남',
#                                              'seq': '14',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '1058099',
#                                              'population_female': '1330732',
#                                              'population_man': '1343199',
#                                              'population_tot': '2673931',
#                                              'regi': '경북',
#                                              'seq': '15',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '1203767',
#                                              'population_female': '1603128',
#                                              'population_man': '1622127',
#                                              'population_tot': '3225255',
#                                              'regi': '경남',
#                                              'seq': '16',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '214681',
#                                              'population_female': '280530',
#                                              'population_man': '280088',
#                                              'population_tot': '560618',
#                                              'regi': '제주',
#                                              'seq': '17',
#                                              'wrttimeid': '2008'},
#                                             {'houshol': '19261292',
#                                              'population_female': '24843206',
#                                              'population_man': '24929939',
#                                              'population_tot': '49773145',
#                                              'regi': '계',
#                                              'seq': '1',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '4116660',
#                                              'population_female': '5149033',
#                                              'population_man': '5059269',
#                                              'population_tot': '10208302',
#                                              'regi': '서울',
#                                              'seq': '2',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '1323771',
#                                              'population_female': '1781828',
#                                              'population_man': '1761202',
#                                              'population_tot': '3543030',
#                                              'regi': '부산',
#                                              'seq': '3',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '906470',
#                                              'population_female': '1245903',
#                                              'population_man': '1243878',
#                                              'population_tot': '2489781',
#                                              'regi': '대구',
#                                              'seq': '4',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '1026936',
#                                              'population_female': '1345770',
#                                              'population_man': '1364809',
#                                              'population_tot': '2710579',
#                                              'regi': '인천',
#                                              'seq': '5',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '524093',
#                                              'population_female': '722549',
#                                              'population_man': '711091',
#                                              'population_tot': '1433640',
#                                              'regi': '광주',
#                                              'seq': '6',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '538100',
#                                              'population_female': '741059',
#                                              'population_man': '743121',
#                                              'population_tot': '1484180',
#                                              'regi': '대전',
#                                              'seq': '7',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '394364',
#                                              'population_female': '541259',
#                                              'population_man': '573607',
#                                              'population_tot': '1114866',
#                                              'regi': '울산',
#                                              'seq': '8',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '4359467',
#                                              'population_female': '5687041',
#                                              'population_man': '5773569',
#                                              'population_tot': '11460610',
#                                              'regi': '경기',
#                                              'seq': '9',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '617693',
#                                              'population_female': '751600',
#                                              'population_man': '761270',
#                                              'population_tot': '1512870',
#                                              'regi': '강원',
#                                              'seq': '10',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '599204',
#                                              'population_female': '757510',
#                                              'population_man': '769968',
#                                              'population_tot': '1527478',
#                                              'regi': '충북',
#                                              'seq': '11',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '827846',
#                                              'population_female': '1007857',
#                                              'population_man': '1029725',
#                                              'population_tot': '2037582',
#                                              'regi': '충남',
#                                              'seq': '12',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '720993',
#                                              'population_female': '930028',
#                                              'population_man': '924480',
#                                              'population_tot': '1854508',
#                                              'regi': '전북',
#                                              'seq': '13',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '783156',
#                                              'population_female': '957050',
#                                              'population_man': '955954',
#                                              'population_tot': '1913004',
#                                              'regi': '전남',
#                                              'seq': '14',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '1073367',
#                                              'population_female': '1328899',
#                                              'population_man': '1340977',
#                                              'population_tot': '2669876',
#                                              'regi': '경북',
#                                              'seq': '15',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '1231461',
#                                              'population_female': '1614476',
#                                              'population_man': '1635700',
#                                              'population_tot': '3250176',
#                                              'regi': '경남',
#                                              'seq': '16',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '217711',
#                                              'population_female': '281344',
#                                              'population_man': '281319',
#                                              'population_tot': '562663',
#                                              'regi': '제주',
#                                              'seq': '17',
#                                              'wrttimeid': '2009'},
#                                             {'houshol': '19865179',
#                                              'population_female': '25205281',
#                                              'population_man': '25310385',
#                                              'population_tot': '50515666',
#                                              'regi': '계',
#                                              'seq': '1',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '4224181',
#                                              'population_female': '5201286',
#                                              'population_man': '5111259',
#                                              'population_tot': '10312545',
#                                              'regi': '서울',
#                                              'seq': '2',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '1371346',
#                                              'population_female': '1794740',
#                                              'population_man': '1773170',
#                                              'population_tot': '3567910',
#                                              'regi': '부산',
#                                              'seq': '3',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '934598',
#                                              'population_female': '1256431',
#                                              'population_man': '1255245',
#                                              'population_tot': '2511676',
#                                              'regi': '대구',
#                                              'seq': '4',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '1059664',
#                                              'population_female': '1367940',
#                                              'population_man': '1390356',
#                                              'population_tot': '2758296',
#                                              'regi': '인천',
#                                              'seq': '5',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '540875',
#                                              'population_female': '732856',
#                                              'population_man': '721780',
#                                              'population_tot': '1454636',
#                                              'regi': '광주',
#                                              'seq': '6',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '555768',
#                                              'population_female': '750016',
#                                              'population_man': '753648',
#                                              'population_tot': '1503664',
#                                              'regi': '대전',
#                                              'seq': '7',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '405501',
#                                              'population_female': '547227',
#                                              'population_man': '579071',
#                                              'population_tot': '1126298',
#                                              'regi': '울산',
#                                              'seq': '8',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '4527282',
#                                              'population_female': '5844168',
#                                              'population_man': '5942454',
#                                              'population_tot': '11786622',
#                                              'regi': '경기',
#                                              'seq': '9',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '639001',
#                                              'population_female': '760011',
#                                              'population_man': '769807',
#                                              'population_tot': '1529818',
#                                              'regi': '강원',
#                                              'seq': '10',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '617431',
#                                              'population_female': '768227',
#                                              'population_man': '781301',
#                                              'population_tot': '1549528',
#                                              'regi': '충북',
#                                              'seq': '11',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '854432',
#                                              'population_female': '1026151',
#                                              'population_man': '1049363',
#                                              'population_tot': '2075514',
#                                              'regi': '충남',
#                                              'seq': '12',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '740650',
#                                              'population_female': '937482',
#                                              'population_man': '931481',
#                                              'population_tot': '1868963',
#                                              'regi': '전북',
#                                              'seq': '13',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '799520',
#                                              'population_female': '959861',
#                                              'population_man': '958624',
#                                              'population_tot': '1918485',
#                                              'regi': '전남',
#                                              'seq': '14',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '1101486',
#                                              'population_female': '1338718',
#                                              'population_man': '1351202',
#                                              'population_tot': '2689920',
#                                              'regi': '경북',
#                                              'seq': '15',
#                                              'wrttimeid': '2010'},
#                                             {'houshol': '1268731',
#                                              'population_female': '1634494',
#                                              'population_man': '1656042',
#                                              'population_tot': '3290536',
#                                              'regi': '경남',
#                                              'seq': '16',
#                                              'wrttimeid': '2010'}]}}

# %%
import pandas as pd

# %%
data2 = data['RegistrationPopulationByRegion']['row']

# %%
df = pd.DataFrame(data2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   wrttimeid          50 non-null     object
#  1   seq                50 non-null     object
#  2   regi               50 non-null     object
#  3   population_tot     50 non-null     object
#  4   population_man     50 non-null     object
#  5   population_female  50 non-null     object
#  6   houshol            50 non-null     object
# dtypes: object(7)
# memory usage: 2.9+ KB
