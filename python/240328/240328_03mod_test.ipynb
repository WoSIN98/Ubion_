# %%
import dir_load as dl
import importlib

# %%
importlib.reload(dl)
# Out:
# <module 'dir_load' from 'c:\\Users\\Jws\\Documents\\ubion\\python\\240328\\dir_load.py'>

# %%
df = dl.data_load("../../csv/2017")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70132 entries, 0 to 70131
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                70132 non-null  int64
#  1   title              70132 non-null  object
#  2   url                70132 non-null  object
#  3   dept_nm_lvl_1      70132 non-null  object
#  4   dept_nm_lvl_2      70074 non-null  object
#  5   dept_nm_lvl_3      61262 non-null  object
#  6   dept_nm_lvl_4      17939 non-null  object
#  7   dept_nm_lvl_5      3474 non-null   object
#  8   exec_yr            70132 non-null  int64
#  9   exec_month         70132 non-null  int64
#  10  expense_budget     3108 non-null   float64
#  11  expense_execution  2805 non-null   float64
#  12  category           1259 non-null   object
#  13  dept_nm_full       70053 non-null  object
#  14  exec_dt            70132 non-null  object
#  15  exec_loc           69360 non-null  object
# ...

# %%
## data_load2 함수를 호출
test2 = dl.data_load2('../../csv')
# Out:
# 2014 전역변수 저장 완료
# campaign_master 전역변수 저장 완료
# class_master 전역변수 저장 완료
# corona 전역변수 저장 완료
# csv_exam 전역변수 저장 완료
# customer_master 전역변수 저장 완료
# dept 전역변수 저장 완료
# drinks 전역변수 저장 완료
# emp 전역변수 저장 완료
# example 전역변수 저장 완료
# item_master 전역변수 저장 완료
# 지원하지 않는 확장자 파일
# Koweps_Codebook 전역변수 저장 완료
# Sales Records 전역변수 저장 완료
# tran_1 전역변수 저장 완료
# tran_2 전역변수 저장 완료
# tran_d_1 전역변수 저장 완료
# tran_d_2 전역변수 저장 완료
# uriage 전역변수 저장 완료
# use_log 전역변수 저장 완료
# USM 전역변수 저장 완료
# 주민등록 전역변수 저장 완료

# %%
test2['corona']
# Out:
#      Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
# 0             0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
# 1             1  2022-06-07 09:09:00.897     24299   18174842  903  20220607
# 2             2  2022-06-06 09:00:06.734     24279   18168670  902  20220606
# 3             3  2022-06-05 08:53:19.426     24258   18163648  901  20220605
# 4             4  2022-06-04 08:56:49.219     24238   18153814  900  20220604
# ..          ...                      ...       ...        ...  ...       ...
# 815         815  2020-03-14 00:00:00.000        72       8086   55  20200314
# 816         816  2020-03-13 00:00:00.000        67       7979   54  20200313
# 817         817  2020-03-12 00:00:00.000        66       7869   53  20200312
# 818         818  2020-03-11 00:00:00.000        60       7755   52  20200311
# 819         819  2020-03-10 00:00:00.000        54       7513   51  20200310
#
# ...

# %%
test2
# Out:
# {'2014':           구분  사고(건)  사망(명)  부상(명)
#  0    2014년1월    169      7    347
#  1    2014년2월    145      3    268
#  2    2014년3월    206     12    358
#  3    2014년4월    182      4    360
#  4    2014년5월    218     17    474
#  5    2014년6월    233     13    457
#  6    2014년7월    229     14    431
#  7    2014년8월    222      9    447
#  8    2014년9월    225     15    430
#  9   2014년10월    210     14    392
#  10  2014년11월    209     10    386
#  11  2014년12월    178     12    329,
#  'campaign_master':   campaign_id campaign_name
#  0         CA1          2_일반
#  1         CA2     0_입회비반액할인
#  2         CA3       1_입회비무료,
#  'class_master':   class class_name  price
#  0   C01       0_종일  10500
#  1   C02       1_주간   7500
#  2   C03       2_야간   6000,
#  'corona':      Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
#  0             0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
# ...
