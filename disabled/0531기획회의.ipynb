# %% [markdown]
# ### 음식점 장애인 편의성 정보 (장애인 이동권 보장)
# 나 왜 또 음식점...?
# - 예약 기능
# - 모범음식점 제외 다른 음식점 추가 (확장성)
# - 빌딩에서도 경사로가 없을 수 도 있고, 등등 혼자서는 들어가기 힘들 수 있으니, 헬퍼 요청 기능
# - 헬퍼에게 포인트, 그 포인트를 장애인 모범음식점에서 사용할 수 있게.
# - but, 신뢰성 문제. 장애인이 도움을 받고 싶지 않아할 수 있다. 사용자 확보 문제.
#
#
# -
